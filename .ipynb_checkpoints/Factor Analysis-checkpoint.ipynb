# %%
# %store -r hospitals

# %%
hospitals
# Out:
#      index Σε ποιο Εργασιακό Περιβάλλον /Τομέα/ Μονάδα εργάζεστε;  \
# 0        0                               Εργαστηριακός Τομέας
# 1        1                   Μονάδα Εντατικής Θεραπείας (ΜΕΘ)
# 2        2                                               Άλλο
# 3        3                               Εργαστηριακός Τομέας
# 4        4                                 Παθολογικός Τομέας
# ..     ...                                                ...
# 98       9                   Μονάδα Εντατικής Θεραπείας (ΜΕΘ)
# 99      10                                               Άλλο
# 100     11                                               Άλλο
# 101      0                                 Ψυχιατρικός Τομέας
# 102      1                               Εργαστηριακός Τομέας
#
#     Σε ποιο τμήμα του Παθολογικού Τομέα εργάζεστε;  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# ...
