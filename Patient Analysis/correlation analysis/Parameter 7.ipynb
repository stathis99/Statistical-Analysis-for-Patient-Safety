# %%
# Libraries
import pandas as pd
import pingouin as pg
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols

from scipy.stats.stats import pearsonr
from scipy import stats
from scipy.stats import f_oneway



pd.set_option('display.max_rows', None)

# %% [markdown]
# # Error

# %%
# %store -r par_7

# %store -r patients_personalInfo

# %%
#parameter_1
my_parameter = par_7

# %%
# Relative frequences for answers of every question

relative_frequencies = my_parameter.apply(lambda x: x.value_counts(normalize=True))
relative_frequencies = relative_frequencies.sort_index()
relative_frequencies
# Out:
#          q7       q14
# 1  0.005780  0.005780
# 2  0.023121  0.023121
# 3  0.040462  0.057803
# 4  0.398844  0.393064
# 5  0.502890  0.473988
# 6  0.028902  0.046243

# %%
relative_frequencies_sum = relative_frequencies.sum(axis=1)/5
height = relative_frequencies_sum

bars = ('1', '2', '3', '4', '5','6')


# Figure Size
fig, ax= plt.subplots(figsize =(4, 4))


# Horizontal Bar Plot
ax.bar(bars, height,color=(0.0, 0.4, 0.6, 0.6))
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.9,
        alpha = 0.2)

    # Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 2)

vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

plt.savefig('distribution.png')

plt.show()
# Out:
# /var/folders/q9/jvtr2p8s6sn6wt933mh1tyfm0000gn/T/ipykernel_30485/303537056.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

# %%
my_parameter.describe()
# Out:
#                q7         q14
# count  173.000000  173.000000
# mean     4.456647    4.445087
# std      0.773563    0.816716
# min      1.000000    1.000000
# 25%      4.000000    4.000000
# 50%      5.000000    5.000000
# 75%      5.000000    5.000000
# max      6.000000    6.000000

# %%
parameter = my_parameter

individualScore = parameter.sum(axis=1)/5

# %%
individualScore.describe()
# Out:
# count    173.000000
# mean       1.780347
# std        0.262071
# min        0.600000
# 25%        1.600000
# 50%        1.800000
# 75%        2.000000
# max        2.200000
# dtype: float64

# %% [markdown]
# ### Correlation Analysis

# %% [markdown]
# ## Gender

# %%
# GENDER

gender = patients_personalInfo['sex']
gender = pd.concat([gender,individualScore],axis=1)
gender.columns = ['Gender','Score']

male = []
female = []


#create table for every category
for index, row in gender.iterrows(): 
    if row['Gender'] == 2:
        female.append(row['Score'])
    else:
        male.append(row['Score'])

# %%
from statistics import mean, pvariance
avg1 = mean(male)
var1 = pvariance(male)
avg2 = mean(female)
var2 = pvariance(female)

print("avg male =", avg1,"var male =",var1,"avg female =", avg2,"var female =",var2 )
# Out:
# avg male = 1.77319587628866 var male = 0.07804442555000532 avg female = 1.7894736842105263 var female = 0.055678670360110795

# %%
tStat, pValue = stats.ttest_ind(female, male, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.6803131324708203 T-Statistic:0.41274568867795275

# %% [markdown]
# ## Education

# %%
#EDUCATION
education = patients_personalInfo['education']

education= pd.concat([education,individualScore],axis=1)

education.columns = ['Education','Score']

education = education.dropna()

# %%
print("Mean")
education.groupby('Education')['Score'].mean()
# Out:
# Mean
# Education
# 1.0    1.840000
# 2.0    1.900000
# 3.0    1.741176
# 4.0    1.759091
# 5.0    1.811111
# 6.0    1.800000
# 7.0    1.750000
# 8.0    1.742857
# Name: Score, dtype: float64

# %%
print("Variance")
education.groupby('Education')['Score'].var()
# Out:
# Variance
# Education
# 1.0    0.075586
# 2.0    0.020000
# 3.0    0.138824
# 4.0    0.071776
# 5.0    0.030458
# 6.0    0.045714
# 7.0    0.064516
# 8.0    0.089524
# Name: Score, dtype: float64

# %%
defterovathmia = []
texnologiki = []
panepistimiaki = []


#create table for every category of profession
for index, row in education.iterrows(): 
    if row['Education'] == 1 or row['Education'] == 2 or row['Education'] == 3 or row['Education'] == 4:
        defterovathmia.append(row['Score'])
    elif row['Education'] == 5 or row['Education'] == 6:
        texnologiki.append(row['Score'])
    elif row['Education'] == 7 or row['Education'] == 8:
        panepistimiaki.append(row['Score'])

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot([defterovathmia,texnologiki,panepistimiaki])

plt.show()

# %%
f_oneway(defterovathmia,texnologiki,panepistimiaki)
# Out:
# F_onewayResult(statistic=0.46958257468088443, pvalue=0.6260765639610747)

# %% [markdown]
# ## Family

# %%
#OIKOGENIAKI KATASTASI 

family = patients_personalInfo['family']

family= pd.concat([family,individualScore],axis=1)

family.columns = ['Family','Score']

family = family.dropna()

# %%
print("Mean")
family.groupby('Family')['Score'].mean()
# Out:
# Mean
# Family
# 1.0    1.728571
# 2.0    1.694118
# 3.0    1.848780
# Name: Score, dtype: float64

# %%
print("Variance")
family.groupby('Family')['Score'].var()
# Out:
# Variance
# Family
# 1.0    0.068987
# 2.0    0.085419
# 3.0    0.053887
# Name: Score, dtype: float64

# %%
monos = []
se_gamo = []
se_gamo_me_paidia = []


#create table for every category of profession
for index, row in family.iterrows(): 
    if row['Family'] == 1:
        monos.append(row['Score'])
    elif row['Family'] == 2:
        se_gamo.append(row['Score'])
    elif row['Family'] == 3:
        se_gamo_me_paidia.append(row['Score'])

# %%
f_oneway(monos,se_gamo, se_gamo_me_paidia)
# Out:
# F_onewayResult(statistic=6.05512606914499, pvalue=0.0028856261587201578)

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot([monos,se_gamo, se_gamo_me_paidia])

plt.show()

# %% [markdown]
# ## Income

# %%
#income  

income = patients_personalInfo['income']

income= pd.concat([income,individualScore],axis=1)

income.columns = ['income','Score']

income = income.dropna()

# %%
print("Mean")
income.groupby('income')['Score'].mean()
# Out:
# Mean
# income
# 1.0    1.757143
# 2.0    1.847368
# 3.0    1.885714
# Name: Score, dtype: float64

# %%
print("Variance")
income.groupby('income')['Score'].var()
# Out:
# Variance
# income
# 1.0    0.075269
# 2.0    0.035533
# 3.0    0.064762
# Name: Score, dtype: float64

# %%
low = []
mid = []
high = []


#create table for every category of profession
for index, row in income.iterrows(): 
    if row['income'] == 1:
        low.append(row['Score'])
    elif row['income'] == 2:
        mid.append(row['Score'])
    elif row['income'] == 3:
        high.append(row['Score'])

# %%
f_oneway(low, mid, high)
# Out:
# F_onewayResult(statistic=2.384929764256909, pvalue=0.09520709913938379)

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot([low,mid,high])

plt.show()

# %% [markdown]
# ## Tomeas Nosileias

# %%
#tom nosileias  

nursing_field = patients_personalInfo['nursing field']

nursing_field= pd.concat([nursing_field,individualScore],axis=1)

nursing_field.columns = ['nursing_field','Score']

nursing_field = nursing_field.dropna()

# %%
print("Mean")
nursing_field.groupby('nursing_field')['Score'].mean()
# Out:
# Mean
# nursing_field
# 1.0    1.721569
# 2.0    1.827660
# 3.0    1.733333
# Name: Score, dtype: float64

# %%
print("Variance")
nursing_field.groupby('nursing_field')['Score'].var()
# Out:
# Variance
# nursing_field
# 1.0    0.092925
# 2.0    0.052130
# 3.0    0.070769
# Name: Score, dtype: float64

# %%
pathologiko = []
xeirourgiko = []
allo = []


#create table for every category of profession
for index, row in nursing_field.iterrows(): 
    if row['nursing_field'] == 1:
        pathologiko.append(row['Score'])
    elif row['nursing_field'] == 2:
        xeirourgiko.append(row['Score'])
    elif row['nursing_field'] == 3:
        allo.append(row['Score'])

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot([pathologiko,xeirourgiko,allo])

plt.show()

# %%
f_oneway(pathologiko,xeirourgiko,allo)
# Out:
# F_onewayResult(statistic=3.325808959154056, pvalue=0.0383106474920243)

# %% [markdown]
# ## Days in hospital

# %%
patients_personalInfo
# Out:
#      sex   age  education  family  occupation  income  nationality  \
# 0      2  30.0        8.0     3.0         1.0     2.0            2
# 1      2  72.0        4.0     3.0         3.0     1.0            1
# 2      2  58.0        3.0     3.0         1.0     1.0            1
# 3      2  71.0        1.0     3.0         3.0     1.0            1
# 4      2  72.0        1.0     3.0         3.0     1.0            1
# 5      2  58.0        3.0     1.0         3.0     1.0            1
# 6      2  45.0        4.0     3.0         3.0     2.0            2
# 7      1  60.0        3.0     2.0         1.0     2.0            1
# 8      1  60.0        1.0     1.0         2.0     1.0            1
# 9      2  30.0        5.0     1.0         2.0     1.0            1
# 10     2  60.0        1.0     3.0         3.0     1.0            1
# 11     1  71.0        1.0     1.0         3.0     1.0            1
# 12     1  58.0        8.0     1.0         3.0     1.0            1
# 13     1  58.0        5.0     3.0         1.0     1.0            2
# 14     1  50.0        4.0     3.0         1.0     1.0            1
# 15     2  30.0        5.0     1.0         2.0     1.0            1
# 16     1  60.0        1.0     3.0         1.0     1.0            1
# 17     2  44.0        4.0     3.0         1.0     1.0            1
# 18     1  60.0        3.0     1.0         1.0     1.0            1
# 19     2  60.0        5.0     3.0         2.0     1.0            1
# 20     2  45.0        5.0     NaN         1.0     1.0            1
# 21     2  49.0        4.0     2.0         1.0     NaN            2
# 22     1  79.0        8.0     1.0         3.0     NaN            1
# 23     1  59.0        5.0     1.0         1.0     1.0            1
# 24     1   NaN        NaN     2.0         3.0     1.0            1
# 129            2.0           9.0                5.0
# 130            2.0          14.0                5.0
# 131            2.0           NaN                5.0
# 132            2.0          11.0                5.0
# 133            2.0          27.0                5.0
# 134            2.0           6.0                5.0
# 135            2.0           3.0                5.0
# 136            3.0          15.0                2.0
# 137            2.0           7.0                5.0
# 138            2.0          15.0                3.0
# 139            2.0          14.0                1.0
# 140            2.0           6.0                3.0
# 141            1.0           5.0                4.0
# 142            2.0           5.0                4.0
# 143            2.0           3.0                4.0
# 144            2.0           9.0                4.0
# 145            2.0           6.0                4.0
# 146            2.0           4.0                4.0
# 147            2.0           6.0                4.0
# 148            2.0           5.0                5.0
# 149            2.0           4.0                5.0
# 150            1.0           NaN                4.0
# 151            2.0           1.0                5.0
# 152            2.0           3.0                5.0
# 153            2.0           2.0                5.0
# 154            2.0           6.0                5.0
# 155            2.0           1.0                5.0
# 156            2.0          19.0                5.0
# 157            2.0          67.0                5.0
# 158            2.0           5.0                5.0
# 159            2.0           4.0                5.0
# 160            2.0           2.0                5.0
# 161            2.0           4.0                5.0
# 162            2.0           7.0                5.0
# 163            2.0          15.0                5.0
# 164            2.0           NaN                5.0
# 165            1.0           4.0                3.0
# 166            2.0           7.0                3.0
# 167            2.0           NaN                4.0
# 168            1.0           NaN                4.0
# 169            2.0           4.0                3.0
# 170            3.0           3.0                3.0
# 171            2.0           8.0                5.0
# 172            2.0           4.0                4.0
#
#                                      comments
# 0                                         oxi
# 1                      Περιστέρια στον θάλαμο
# 2                                         oxi
# 3                     Peristeria ston thalamo
# 4                     peristeria ston thalamo
# 5                                         oxi
# 6                                         oxi
# 7                                         oxi
# 8                                         oxi
# 9                                         oxi
# 10                                        oxi
# 11                                        oxi
# 12                                        oxi
# 13                                        oxi
# 14                                        oxi
# 15                                  κουνουπια
# 16                                        οχι
# 17                                        oxi
# 18                                        oxi
# 19   polloi dianomeis diafimistikwn filladiwn
# 20                                        oxi
# 21                                        oxi
# 22                                        oxi
# 23                                        oxi
# 24                                        oxi
# 25                                        oxi
# 26                                        oxi
# 27                                        oxi
# 28                                        oxi
# 29                                        oxi
# 30                                        oxi
# 31                                        oxi
# 32                                        oxi
# 33                                        oxi
# 34                                        yes
# 35                                        oxi
# 36                                        oxi
# 37                                        oxi
# 38                                        oxi
# 39                                        oxi
# 40                            polloi sygeneis
# 41                                        oxi
# 42                          poly episkeptirio
# 43                                        oxi
# 44                                        oxi
# 45                                        oxi
# 46                                        oxi
# 47                                        oxi
# 48                                        oxi
# 49                                        oxi
# 50                                        oxi
# 51                                        oxi
# 52                                        oxi
# 53                                   kazanaki
# 54                                        oxi
# 55                                        oxi
# 56                                        oxi
# 57                                        oxi
# 58                                        oxi
# 59                                        oxi
# 60                                        oxi
# 61                                        οχι
# 62                                        oxi
# 63                                sinostismos
# 64                                        oxi
# 65                                        oxi
# 66                                        oxi
# 67                                        oxi
# 68                                        oxi
# 69                                        oxi
# 70                                        oxi
# 71                                        oxi
# 72                                        oxi
# 73                                        oxi
# 74                                        oxi
# 75                                        oxi
# 76                                        oxi
# 77                                        oxi
# 78                                        oxi
# 79                                        oxi
# 80                                        oxi
# 81                                        oxi
# 82                                        oxi
# 83                                        oxi
# 84                                        oxi
# 85                                        oxi
# 86                                        oxi
# 87                                        oxi
# 88                                        oxi
# 89                                        oxi
# 90                                        oxi
# 91                                        oxi
# 92                                        NaN
# 93                                        oxi
# 94                                        oxi
# 95                                        oxi
# 96                                        oxi
# 97                                        oxi
# 98                                        oxi
# 99                                        oxi
# 100                                       oxi
# 101                                       oxi
# 102                                       oxi
# 103                                       oxi
# 104                                       oxi
# 105                                       oxi
# 106                                       oxi
# 107                                       oxi
# 108                                       oxi
# 109                                       oxi
# 110                                       oxi
# 111                                       oxi
# 112                                       oxi
# 113                                       oxi
# 114                                       oxi
# 115                                       oxi
# 116                                       oxi
# 117                                       oxi
# 118                                       oxi
# 119                                       oxi
# 120                                       oxi
# 121                                       oxi
# 122                                       oxi
# 123                                       oci
# 124                                       oxi
# 125                                       oxi
# 126                                       oxi
# 127                                       oxi
# 128                                       oxi
# 129                                       oxi
# 130                                       oxi
# 131                                       oxi
# 132                                       oxi
# 133                                       oxi
# 134                                       oxi
# 135                                       oxi
# 136                                       oxi
# 137                                       oxi
# 138                                       oxi
# 139                                       oxi
# 140                                       oxi
# 141                                       oxi
# 142                                       oxi
# 143                                       oxi
# 144                                       oxi
# 145                                       oxi
# 146                                       oxi
# 147                                       oxi
# 148                                       oxi
# 149                                       oxi
# 150                                       oxi
# 151                                       oxi
# 152                                       oxi
# 153                                       oxi
# 154                                       οχι
# 155                                       οχι
# 156                                       οχι
# 157                                       οχι
# 158                                       οχι
# 159                                       οχι
# 160                                       οχι
# 161                                       οχι
# 162                                       οχι
# 163                                       οχι
# 164                                       oxi
# 165                                       oxi
# 166                                       oxi
# 167                                       oxi
# 168                                       NaN
# 169                                       oxi
# 170                                       oxi
# 171                                       oxi
# 172                                       oxi

# %%
days = patients_personalInfo['nursing days']
# create a frame with days and score
days = pd.concat([days,individualScore],axis=1)
days.columns = ['days','Score']
days = days.dropna()

# %%
# remove outliers
q = days['days'].quantile(0.99)
days = days[days['days'] < q]

# %%
x = days['days']
y = days['Score']
#calculation correlation coefficient and p-value between x and y
print("(corr,p-val) =",pearsonr(x, y))
# Out:
# (corr,p-val) = (-0.00796531951192185, 0.9213858006623901)

# %%
plt.plot(x, y, '.')
plt.title("age-scre correlation")
plt.xlabel("days",fontweight="bold", fontsize="15")
plt.ylabel("score",fontweight="bold", fontsize="15")

plt.show()

# %% [markdown]
# ## Age

# %%
age = patients_personalInfo['age']
# create a frame with days and score
age = pd.concat([age,individualScore],axis=1)
age.columns = ['age','Score']
age = age.dropna()

# %%
# remove outliers
q = age['age'].quantile(0.99)
age = age[age['age'] < q]

# %%
x = age['age']
y = age['Score']
#calculation correlation coefficient and p-value between x and y
print("(corr,p-val) =",pearsonr(x, y))
# Out:
# (corr,p-val) = (0.25588177822447095, 0.002452142094920847)

# %%
plt.plot(x, y, '.')
plt.title("age-scre correlation")
plt.xlabel("age",fontweight="bold", fontsize="15")
plt.ylabel("score",fontweight="bold", fontsize="15")

plt.show()
