# %%
# Libraries
import pandas as pd

# %%
PMOS = pd.read_csv('patient.csv')

# %%
PMOS
# Out:
#    q1  q2  q3  q4  q5  q6  q7  q8  q9  q10  ...  age  education  family  \
# 0   4   4   5   3   4   5   5   5   3    5  ...   30          8       3
# 1   5   5   5   2   5   4   5   4   2    5  ...   72          4       3
# 2   4   5   4   2   5   5   5   4   2    5  ...   58          3       3
# 3   5   4   5   2   5   4   5   5   5    4  ...   71          1       3
# 4   5   4   5   2   5   4   5   5   5    4  ...   72          1       3
# 5   5   4   5   3   4   5   5   5   4    5  ...   58          3       1
# 6   4   2   5   3   4   5   5   2   4    5  ...   45          4       3
# 7   4   5   5   4   5   5   5   4   5    4  ...   60          3       2
# 8   4   5   4   2   4   4   3   3   2    2  ...   60          1       1
#
#    occupation  income  nationality  nursing field  nursing days  \
# 0           1       2            2              1           5.0
# 1           3       1            1              2           7.0
# ...

# %%
print(PMOS.index)
# Out:
# RangeIndex(start=0, stop=9, step=1)
