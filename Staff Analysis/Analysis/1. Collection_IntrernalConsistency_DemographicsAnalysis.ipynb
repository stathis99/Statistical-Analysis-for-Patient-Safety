# %% [markdown]
# # Data Analysis For Hospital Patient Safety

# %% [markdown]
# ## 1. Data Collection

# %%
# Libraries
import pandas as pd
import pingouin as pg
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.mode.chained_assignment = None  # default='warn'

# %%
#Load Data
sismanoglio = pd.read_csv('../Data/Sismanoglio.csv')
evangelismos = pd.read_csv('../Data/Evagelismos.csv')
genimatas = pd.read_csv('../Data/Genimatas.csv')
thriasio = pd.read_csv('../Data/Thriasio.csv')
mpenakio = pd.read_csv('../Data/Mpenakio.csv')

frames = [sismanoglio,evangelismos,genimatas,thriasio,mpenakio]

hospitals = pd.concat(frames)
hospitals = hospitals.reset_index()

# %%
#Shape of Data
print('sismanoglio has', sismanoglio.shape[0], 'rows/answers and ',sismanoglio.shape[1], 'columns/questios')
print('evangelismos has', evangelismos.shape[0], 'rows/answers and ',evangelismos.shape[1], 'columns/questios')
print('genimatas has', genimatas.shape[0], 'rows/answers and ',genimatas.shape[1], 'columns/questios')
print('thriasio has', thriasio.shape[0], 'rows/answers and ',thriasio.shape[1], 'columns/questios')
print('mpenakio has', mpenakio.shape[0], 'rows/answers and ',mpenakio.shape[1], 'columns/questios')
# Out:
# sismanoglio has 18 rows/answers and  60 columns/questios
# evangelismos has 82 rows/answers and  60 columns/questios
# genimatas has 86 rows/answers and  60 columns/questios
# thriasio has 36 rows/answers and  60 columns/questios
# mpenakio has 22 rows/answers and  60 columns/questios

# %%
print('hospitlas have', hospitals.shape[0], 'rows/answers and ',hospitals.shape[1], 'columns/questios')
# Out:
# hospitlas have 244 rows/answers and  62 columns/questios

# %% [markdown]
# ## 2. Data cleaning

# %%
#Drop irrelevant coumns
hospitals.drop("Χρονική σήμανση", axis=1, inplace=True)

# %store hospitals
# Out:
# Stored 'hospitals' (DataFrame)

# %%
#print all questions
for index, item in enumerate(hospitals.columns, start=0):  
    print(index," ", item)
# Out:
# 0   index
# 1   Σε ποιο Εργασιακό Περιβάλλον /Τομέα/ Μονάδα εργάζεστε;
# 2   Σε ποιο τμήμα του Παθολογικού Τομέα εργάζεστε;
# 3   Σε ποιο τμήμα του Χειρουργικού Τομέα εργάζεστε;
# 4   Σε ποιο τμήμα του Εργαστηριακού Τομέα εργάζεστε;
# 5   Παρακαλώ γράψτε το όνομα του Τομέα που εργάζεστε.
# 6   1. Οι εργαζόμενοι υποστηρίζουν ο ένας τον άλλον.
# 7   2. Υπάρχει επαρκές προσωπικό για τη διεκπεραίωση της εργασίας.
# 8   3. Όταν υπάρχει μεγάλος όγκος εργασίας που πρέπει να γίνει άμεσα, το προσωπικό εργάζεται ομαδικά για την ολοκλήρωση της.
# 9   4. Υπάρχει σεβασμός ανάμεσα στους εργαζομένους.
# 10   5. Το προσωπικό εργάζεται περισσότερες ώρες από αυτές που διασφαλίζουν ασφαλή φροντίδα για τον ασθενή.
# 11   6. Το προσωπικό εργάζεται δυναμικά για τη βελτίωση της ασφάλειας του ασθενούς.
# 12   7. Αξιοποιείται περισσότερο προσωρινό προσωπικό από αυτό που διασφαλίζει την ασφαλή φροντίδα του ασθενούς.
# 13   8. Το προσωπικό αισθάνεται ότι τα λάθη του μπορεί να χρησιμοποιηθούν εναντίον του.
# 14   9. Τα λάθη οδήγησαν σε θετικές αλλαγές.
# 15   10. Από τύχη δεν συμβαίνουν σοβαρά λάθη.
# 16   11. Όταν υπάρχει μεγάλος φόρτος εργασίας παρέχεται βοήθεια από άλλες Μονάδες.
# 17   12. Όταν δηλώνεται ένα δυσμενές συμβάν, υπάρχει η αίσθηση ότι καταγράφεται το άτομο και όχι το καθαυτό συμβάν.
# 18   13. Όταν γίνονται αλλαγές για τη βελτίωση της ασφάλειας του ασθενούς, αξιολογείται η αποτελεσματικότητά τους.
# 19   14. Το προσωπικό εργάζεται σε «κατάσταση κρίσης» προσπαθώντας να κάνει πολλά πράγματα γρήγορα.
# 20   15. Η ασφάλεια του ασθενούς αποτελεί προτεραιότητα ακόμα και όταν υπάρχει φόρτος εργασίας.
# 21   16. Το προσωπικό ανησυχεί ότι τα λάθη του καταγράφονται στο προσωπικό του φάκελο.
# 22   17. Υπάρχει πρόβλημα ασφάλειας του ασθενούς.
# 23   18. Οι διαδικασίες διεκπεραίωσης της εργασίας και το σύστημα εν γένει συμβάλλει στην πρόληψη δυσμενών συμβάντων.
# 24   1. Επιβραβεύει το προσωπικό με καλά λόγια όταν τηρούνται οι διαδικασίες ασφαλούς φροντίδας του ασθενούς.
# 25   2. Λαμβάνει σοβαρά υπόψη του τις προτάσεις του προσωπικού για βελτίωση της ασφάλειας του ασθενούς.
# 26   3. Παροτρύνει το προσωπικό να εργάζεται γρηγορότερα όταν υπάρχει υπερβολικός φόρτος εργασίας και πίεση, ακόμη και όταν παραβλέπονται σημαντικές διαδικασίες ασφάλειας του ασθενούς.
# 27   4. Παραβλέπει επαναλαμβανόμενα προβλήματα ασφάλειας του ασθενούς.
# 28   1. Γίνεται συστηματική αξιολόγηση των αλλαγών που τίθενται σε εφαρμογή, βάσει δυσμενών συμβάντων που έχουν αναφερθεί.
# 29   2. Το προσωπικό μιλάει ελεύθερα όταν διαπιστώσει κάτι που επιδρά αρνητικά στη φροντίδα υγείας του ασθενούς.
# 30   3. Το προσωπικό ενημερώνεται συχνά για τα δυσμενή συμβάντα που λαμβάνουν χώρα.
# 31   4. Το προσωπικό μπορεί ελεύθερα να αμφισβητήσει τις αποφάσεις ή τις ενέργειες των ανωτέρων του.
# 32   5. Το προσωπικό συζητά τρόπους πρόληψης δυσμενών συμβάντων ώστε να μην επαναληφθούν.
# 33   6. Το προσωπικό φοβάται να ρωτήσει, όταν κάτι δεν φαίνεται σωστό.
# 34   …..αλλά εντοπιστεί και διορθωθεί πριν επηρεάσει τον ασθενή
# 35   ……αλλά δεν έχει πιθανότητα να βλάψει τον ασθενή.
# 36   …..που θα μπορούσε να βλάψει τον ασθενή, αλλά δεν τον επηρέασε
# 37   Παρακαλώ αξιολογήστε το επίπεδο ασφάλειας των ασθενών συνολικά στο Εργασιακό Περιβάλλον/Μονάδα σας επιλέγοντας με √ την απάντηση που σας εκφράζει.
# 38   1. Η Διοίκηση εξασφαλίζει εργασιακό κλίμα που προάγει την ασφάλεια του ασθενούς .
# 39   2. Υπάρχει ελλιπής συντονισμός μεταξύ των Μονάδων.
# 40   3. Η μεταφορά ασθενούς από τη μία Μονάδα στην άλλη συνήθως συνοδεύεται από προβλήματα.
# 41   4. Υπάρχει καλή συνεργασία ανάμεσα στις Μονάδες όταν αυτό απαιτείται.
# 42   5. Συχνά, σημαντικές πληροφορίες σχετικά με τη νοσηλεία του ασθενούς χάνονται κατά την αλλαγή της βάρδιας.
# 43   6. Η συνεργασία με το προσωπικό άλλων Μονάδων είναι συχνά δυσάρεστη.
# 44   7. Συχνά παρουσιάζονται διάφορα προβλήματα κατά την ανταλλαγή πληροφοριών μεταξύ των Μονάδων.
# 45   8. Η ασφάλεια του ασθενούς αποτελεί κύρια προτεραιότητα για την Διοίκηση.
# 46   9. Η Διοίκηση δείχνει να ενδιαφέρεται για την ασφάλεια του ασθενούς μόνο μετά από την αναφορά κάποιου δυσμενούς συμβάντος.
# 47   10. Οι Μονάδες συνεργάζονται καλά μεταξύ τους για την παροχή άριστης ποιοτικά φροντίδας υγείας στον ασθενή.
# 48   11. Η αλλαγή βάρδιας είναι προβληματική για τον ασθενή.
# 49   Τους τελευταίους 12 μήνες πόσα δυσμενή συμβάντα έχετε αναφέρει; (Αναφέρετε έναν αριθμό)
# 50   1. Φύλο:
# 51   2. Ηλικία…
# 52   3α. Ποια είναι η βασική σας εκπαίδευση;
# 53   3β. Άλλες σπουδές:
# 54   7. Πόσο χρονικό διάστημα εργάζεστε στο συγκεκριμένο Νοσοκομείο;
# 55   8. Πόσο χρονικό διάστημα εργάζεστε στη συγκεκριμένη μονάδα ?
# 56   9. Συνήθως πόσες ώρες την εβδομάδα εργάζεστε στο συγκεκριμένο Νοσοκομείο; …
# 57   10. Τι θέση κατέχετε στο νοσοκομείο που εργάζεστε;
# 58   12. Πόσο χρονικό διάστημα εργάζεστε στην παρούσα ειδικότητα ή επάγγελμα; (Αθροιστικά στο τρέχον νοσοκομείο και σε τυχόν άλλα)
# 59   Παρακαλώ, καταγράψτε ελεύθερα τυχόν σχόλια και παρατηρήσεις σχετικά με ζητήματα ασφάλειας των ασθενών, ιατρικών λαθών και την αναφορά δυσμενών συμβάντων εντός του νοσοκομείου σας.
# 60   5. Το προσωπικό εργάζεται περισσότερες ώρες από αυτές που διασφαλίζουν ασφαλή φροντίδα για τον ασθενή

# %%
hospitals_jobField  = hospitals.iloc[: , :5]
hospitals_personalInfo = hospitals.iloc[:, 49:58]
hospitals_questions = hospitals.iloc[:, 5:49]

# %store hospitals_personalInfo
# Out:
# Stored 'hospitals_personalInfo' (DataFrame)

# %% [markdown]
# #### Clean Personal Info

# %%
hospitals_personalInfo.dropna()
hospitals_personalInfo
# Out:
#     Τους τελευταίους 12 μήνες πόσα δυσμενή συμβάντα έχετε αναφέρει; (Αναφέρετε έναν αριθμό)  \
# 0                                                    4
# 1                                                  NaN
# 2                                                   10
# 3                                                  NaN
# 4                                                    2
# 5                                                  NaN
# 6                                                    6
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                   2
# 13                                        ΟΠΩΣΔΗΠΟΤΕ 2
# 14                                                   2
# 15                                                   3
# 16                                                 NaN
# 17                                                   3
# 18                                                  10
# 19                                              ΚΑΝΕΝΑ
# 20                                              ΚΑΝΕΝΑ
# 21                                                   1
# 22                                                   0
# 23                                                   2
# 24                                              KANENA
# 25                                                   1
# 26                                                   0
# 27                                                   3
# 28                                                   0
# 29                                                   1
# 30                                                 NaN
# 31                                                   0
# 32                                                 NaN
# 33                                        Δεν γνωριζω.
# 34                                                  50
# 35                                                   6
# 36                                                 2-3
# 37                                                 2-3
# 38                                                   2
# 39                                                   2
# 40                                               ΜΗΔΕΝ
# 41                                                   1
# 42                                                   0
# 43                                                   0
# 44                                                   0
# 45                                                 NaN
# 46                                                   5
# 47                                                   0
# 48                                                 ΕΝΑ
# 49                                              ΚΑΝΕΝΑ
# 50                                                   1
# 51                                              ΚΑΝΕΝΑ
# 52                                                   2
# 53                                                 NaN
# 54                                                   0
# 55                                                   0
# 56                                            ΔΥΟ-ΤΡΙΑ
# 57                                                   0
# 58                                                   2
# 59                                                   0
# 60                                                   0
# 61                                                   0
# 62                                                   0
# 63                                   2 πτώσεις ασθενών
# 64                                                 NaN
# 65                                                 NaN
# 66                                                  10
# 67                                                   1
# 68                                                   1
# 69                                                  10
# 70                                                   2
# 71                                              ΚΑΝΕΝΑ
# 72                                                 2-3
# 73                                                   1
# 74                                                   0
# 75                                                   2
# 76                                                   1
# 77                                              Κανενα
# 78                                                   1
# 79                                                   1
# 80                                                   1
# 81                                                   1
# 82                                                 NaN
# 83                                                   0
# 84                                                   0
# 85                                              KANENA
# 86                                                   0
# 87                                                   0
# 88                                                   1
# 89                                                   2
# 90                                                   1
# 91                                                   0
# 92                                                   0
# 93                                                   1
# 94                                                   1
# 95                                                   2
# 96                                                   6
# 97                                                 NaN
# 98                                                   1
# 99                                                   3
# 100                                                  2
# 101                                                  2
# 102                                                NaN
# 103                                                  2
# 104                                                  0
# 105                                                NaN
# 106                                                NaN
# 107                                                  2
# 108                                             Κανενα
# 109                                                  3
# 110                                              Τρία
# 111                                                  5
# 112                           Ισως 3 με 4 (οχι σοβαρα)
# 113                                                  3
# 114                                                  2
# 115                                                  3
# 116                                                NaN
# 117                                                 10
# 118                                                  3
# 119                                        Δεν απαντώ
# 120                                                  6
# 121                                                NaN
# 122                                                NaN
# 123                                             Κανενα
# 124                                                  4
# 125                                                  0
# 126                                                Ενα
# 127                                                  0
# 128                                                  0
# 129                                                  1
# 130                                                4-5
# 131                                            Κανένα
# 132                                                NaN
# 133                                                NaN
# 134                                                  6
# 135                                                NaN
# 136                                                  1
# 137                                                  0
# 138                                                NaN
# 139                                                  2
# 140                                                  0
# 141                                                  0
# 142                                                  2
# 143                                                ΟΧΙ
# 144                                                  1
# 145                                                  2
# 146                                                  0
# 147                                                  0
# 148                                                  1
# 149                                              Μηδέν
# 150                                                  2
# 151                                                  0
# 152                                                  0
# 153                                                  2
# 154                                                  0
# 155                                                  0
# 156                                                  1
# 157                                                  2
# 158                                                NaN
# 159                                                  3
# 160                                                  0
# 161                          Δεν υπάρχει καμία αλλαγή
# 162                                                  5
# 163                                                  3
# 164                                                  2
# 165                                                  0
# 166                                                  4
# 167                                                 20
# 168                                                  1
# 169                                                  5
# 170                                                  2
# 171                                                NaN
# 172                                                  3
# 173                                            Αρκετά
# 174                                                  2
# 175                                                  7
# 176                                             Κανενα
# 177                                                  0
# 178                                            Κανένα
# 179                                                  0
# 180                                                Ένα
# 181                                                  0
# 182                                                Δύο
# 183                                                NaN
# 184                                                  2
# 185                                                  0
# 186                                              ΠΕΝΤΕ
# 187                                                  3
# 188                                             Κανενα
# 189                                                  0
# 190                                                NaN
# 191                                                  1
# 192                                                  3
# 193                                               7-10
# 194                                                NaN
# 195                                                  0
# 196                                                  4
# 197                                                 40
# 198                                                  3
# 199                                                  0
# 200                                                  1
# 201                                                  2
# 202                                                 10
# 203                                             KANENA
# 204                                                  0
# 205                                             κανένα
# 206                                                  7
# 207                                                NaN
# 208                                      Απροσδιοριστο
# 209                                                  0
# 210                                                  2
# 211                                                NaN
# 212                                                  2
# 213                                                  1
# 214                                                 20
# 215                                                 10
# 216                                                  1
# 217                                                  2
# 218                                                  2
# 219                                                  1
# 220                                                NaN
# 221                                                  0
# 222                                                6.0
# 223                                                3.0
# 224                                                0.0
# 225                                                5.0
# 226                                                0.0
# 227                                                2.0
# 228                                                NaN
# 229                                                0.0
# 230                                                NaN
# 231                                                2.0
# 232                                                3.0
# 233                                                2.0
# 234                                                2.0
# 235                                                NaN
# 236                                               10.0
# 237                                                4.0
# 238                                                5.0
# 239                                                0.0
# 240                                                NaN
# 241                                                2.0
# 242                                                2.0
# 243                                                3.0
#
#     1. Φύλο:  2. Ηλικία… 3α. Ποια είναι η βασική σας εκπαίδευση;  \
# 0     Γυναίκα         23                3. Πανεπιστημιακή (Π.Ε.)
# 1     Γυναίκα         45                3. Πανεπιστημιακή (Π.Ε.)
# 2      Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 3      Άνδρας         61                3. Πανεπιστημιακή (Π.Ε.)
# 4      Άνδρας         50                   2. Τεχνολογική (Τ.Ε.)
# 5     Γυναίκα         48                3. Πανεπιστημιακή (Π.Ε.)
# 6      Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 7     Γυναίκα         39                   2. Τεχνολογική (Τ.Ε.)
# 8     Γυναίκα         40                   2. Τεχνολογική (Τ.Ε.)
# 9     Γυναίκα         55                   2. Τεχνολογική (Τ.Ε.)
# 10    Γυναίκα         56                   2. Τεχνολογική (Τ.Ε.)
# 11    Γυναίκα         38                   2. Τεχνολογική (Τ.Ε.)
# 12     Άνδρας         51                   2. Τεχνολογική (Τ.Ε.)
# 13    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 14    Γυναίκα         57                   2. Τεχνολογική (Τ.Ε.)
# 15    Γυναίκα         52                3. Πανεπιστημιακή (Π.Ε.)
# 16    Γυναίκα         44                   2. Τεχνολογική (Τ.Ε.)
# 17     Άνδρας         50                   2. Τεχνολογική (Τ.Ε.)
# 18     Άνδρας         53                   2. Τεχνολογική (Τ.Ε.)
# 19    Γυναίκα         47                   2. Τεχνολογική (Τ.Ε.)
# 20    Γυναίκα        NaN                   2. Τεχνολογική (Τ.Ε.)
# 21     Άνδρας         52                   2. Τεχνολογική (Τ.Ε.)
# 22     Άνδρας         48                   2. Τεχνολογική (Τ.Ε.)
# 23     Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 24    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 25    Γυναίκα         57                   2. Τεχνολογική (Τ.Ε.)
# 26    Γυναίκα         48                   2. Τεχνολογική (Τ.Ε.)
# 27    Γυναίκα         60                   2. Τεχνολογική (Τ.Ε.)
# 28    Γυναίκα         50                 1. Δευτεροβάθμια (Δ.Ε.)
# 29    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 30    Γυναίκα         38                3. Πανεπιστημιακή (Π.Ε.)
# 31     Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 32    Γυναίκα         39                3. Πανεπιστημιακή (Π.Ε.)
# 33    Γυναίκα         45                   2. Τεχνολογική (Τ.Ε.)
# 34    Γυναίκα         41                 1. Δευτεροβάθμια (Δ.Ε.)
# 35    Γυναίκα         37                3. Πανεπιστημιακή (Π.Ε.)
# 36    Γυναίκα         58                   2. Τεχνολογική (Τ.Ε.)
# 37    Γυναίκα         54                 1. Δευτεροβάθμια (Δ.Ε.)
# 38     Άνδρας         49                3. Πανεπιστημιακή (Π.Ε.)
# 39    Γυναίκα         52                   2. Τεχνολογική (Τ.Ε.)
# 40    Γυναίκα         62                3. Πανεπιστημιακή (Π.Ε.)
# 41    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 42    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 43    Γυναίκα         50                 1. Δευτεροβάθμια (Δ.Ε.)
# 44    Γυναίκα         39                 1. Δευτεροβάθμια (Δ.Ε.)
# 45    Γυναίκα         58                   2. Τεχνολογική (Τ.Ε.)
# 46     Άνδρας         54                   2. Τεχνολογική (Τ.Ε.)
# 47    Γυναίκα         40                   2. Τεχνολογική (Τ.Ε.)
# 48     Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 49    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 50    Γυναίκα         40                   2. Τεχνολογική (Τ.Ε.)
# 51    Γυναίκα         53                 1. Δευτεροβάθμια (Δ.Ε.)
# 52    Γυναίκα         57                   2. Τεχνολογική (Τ.Ε.)
# 53    Γυναίκα         53                   2. Τεχνολογική (Τ.Ε.)
# 54    Γυναίκα         36                   2. Τεχνολογική (Τ.Ε.)
# 55     Άνδρας          .                   2. Τεχνολογική (Τ.Ε.)
# 56    Γυναίκα        NaN                                     NaN
# 57    Γυναίκα         58                   2. Τεχνολογική (Τ.Ε.)
# 58    Γυναίκα         38                3. Πανεπιστημιακή (Π.Ε.)
# 59    Γυναίκα         55                   2. Τεχνολογική (Τ.Ε.)
# 60    Γυναίκα         48                   2. Τεχνολογική (Τ.Ε.)
# 61    Γυναίκα         47                 1. Δευτεροβάθμια (Δ.Ε.)
# 62    Γυναίκα         59                   2. Τεχνολογική (Τ.Ε.)
# 63    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 64    Γυναίκα         60                   2. Τεχνολογική (Τ.Ε.)
# 65        NaN        NaN                                     NaN
# 66    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 67    Γυναίκα         42                   2. Τεχνολογική (Τ.Ε.)
# 68    Γυναίκα         41                   2. Τεχνολογική (Τ.Ε.)
# 69    Γυναίκα         26                   2. Τεχνολογική (Τ.Ε.)
# 70     Άνδρας         40                 1. Δευτεροβάθμια (Δ.Ε.)
# 71    Γυναίκα         57                   2. Τεχνολογική (Τ.Ε.)
# 72    Γυναίκα         55                   2. Τεχνολογική (Τ.Ε.)
# 73    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 74    Γυναίκα         31                   2. Τεχνολογική (Τ.Ε.)
# 75    Γυναίκα         56                   2. Τεχνολογική (Τ.Ε.)
# 76     Άνδρας         36                   2. Τεχνολογική (Τ.Ε.)
# 77    Γυναίκα         46                   2. Τεχνολογική (Τ.Ε.)
# 78     Άνδρας         39                   2. Τεχνολογική (Τ.Ε.)
# 79    Γυναίκα         35                   2. Τεχνολογική (Τ.Ε.)
# 80    Γυναίκα         31                   2. Τεχνολογική (Τ.Ε.)
# 81    Γυναίκα         48                   2. Τεχνολογική (Τ.Ε.)
# 82        NaN        NaN                                     NaN
# 83    Γυναίκα      25-35                   2. Τεχνολογική (Τ.Ε.)
# 84    Γυναίκα         28                   2. Τεχνολογική (Τ.Ε.)
# 85    Γυναίκα         45                   2. Τεχνολογική (Τ.Ε.)
# 86    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 87    Γυναίκα         52                   2. Τεχνολογική (Τ.Ε.)
# 88    Γυναίκα         59                   2. Τεχνολογική (Τ.Ε.)
# 89    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 90    Γυναίκα         59                   2. Τεχνολογική (Τ.Ε.)
# 91    Γυναίκα         38                   2. Τεχνολογική (Τ.Ε.)
# 92        NaN         45                                     NaN
# 93    Γυναίκα         55                   2. Τεχνολογική (Τ.Ε.)
# 94    Γυναίκα         32                3. Πανεπιστημιακή (Π.Ε.)
# 95    Γυναίκα         33                3. Πανεπιστημιακή (Π.Ε.)
# 96    Γυναίκα         46                3. Πανεπιστημιακή (Π.Ε.)
# 97    Γυναίκα         42                3. Πανεπιστημιακή (Π.Ε.)
# 98    Γυναίκα         45                3. Πανεπιστημιακή (Π.Ε.)
# 99    Γυναίκα         35                3. Πανεπιστημιακή (Π.Ε.)
# 100   Γυναίκα       45.0                   2. Τεχνολογική (Τ.Ε.)
# 101   Γυναίκα       45.0                3. Πανεπιστημιακή (Π.Ε.)
# 102   Γυναίκα       54.0                   2. Τεχνολογική (Τ.Ε.)
# 103   Γυναίκα       38.0                   2. Τεχνολογική (Τ.Ε.)
# 104   Γυναίκα       47.0                   2. Τεχνολογική (Τ.Ε.)
# 105   Γυναίκα       48.0                   2. Τεχνολογική (Τ.Ε.)
# 106    Άνδρας       47.0                   2. Τεχνολογική (Τ.Ε.)
# 107   Γυναίκα       49.0                   2. Τεχνολογική (Τ.Ε.)
# 108   Γυναίκα       49.0                   2. Τεχνολογική (Τ.Ε.)
# 109    Άνδρας       54.0                   2. Τεχνολογική (Τ.Ε.)
# 110    Άνδρας       50.0                   2. Τεχνολογική (Τ.Ε.)
# 111    Άνδρας       48.0                3. Πανεπιστημιακή (Π.Ε.)
# 112   Γυναίκα       39.0                   2. Τεχνολογική (Τ.Ε.)
# 113   Γυναίκα       40.0                   2. Τεχνολογική (Τ.Ε.)
# 114   Γυναίκα       30.0                   2. Τεχνολογική (Τ.Ε.)
# 115   Γυναίκα       50.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 116   Γυναίκα       51.0                   2. Τεχνολογική (Τ.Ε.)
# 117   Γυναίκα       45.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 118   Γυναίκα       47.0                   2. Τεχνολογική (Τ.Ε.)
# 119   Γυναίκα        NaN                   2. Τεχνολογική (Τ.Ε.)
# 120       NaN        NaN                                     NaN
# 121   Γυναίκα       43.0                   2. Τεχνολογική (Τ.Ε.)
# 122   Γυναίκα       39.0                   2. Τεχνολογική (Τ.Ε.)
# 123   Γυναίκα       53.0                   2. Τεχνολογική (Τ.Ε.)
# 124   Γυναίκα       53.0                3. Πανεπιστημιακή (Π.Ε.)
# 125   Γυναίκα       55.0                   2. Τεχνολογική (Τ.Ε.)
# 126    Άνδρας       61.0                   2. Τεχνολογική (Τ.Ε.)
# 127   Γυναίκα       54.0                   2. Τεχνολογική (Τ.Ε.)
# 128    Άνδρας       55.0                   2. Τεχνολογική (Τ.Ε.)
# 129    Άνδρας       51.0                   2. Τεχνολογική (Τ.Ε.)
# 130    Άνδρας       48.0                   2. Τεχνολογική (Τ.Ε.)
# 131    Άνδρας       56.0                   2. Τεχνολογική (Τ.Ε.)
# 132    Άνδρας        NaN                   2. Τεχνολογική (Τ.Ε.)
# 133   Γυναίκα       56.0                                     NaN
# 134    Άνδρας       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 135   Γυναίκα       65.0                3. Πανεπιστημιακή (Π.Ε.)
# 136    Άνδρας       29.0                3. Πανεπιστημιακή (Π.Ε.)
# 137    Άνδρας       32.0                3. Πανεπιστημιακή (Π.Ε.)
# 138    Άνδρας        NaN                                     NaN
# 139   Γυναίκα       28.0                3. Πανεπιστημιακή (Π.Ε.)
# 140   Γυναίκα       29.0                3. Πανεπιστημιακή (Π.Ε.)
# 141    Άνδρας       34.0                3. Πανεπιστημιακή (Π.Ε.)
# 142   Γυναίκα       35.0                3. Πανεπιστημιακή (Π.Ε.)
# 143    Άνδρας       45.0                3. Πανεπιστημιακή (Π.Ε.)
# 144   Γυναίκα       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 145    Άνδρας       31.0                3. Πανεπιστημιακή (Π.Ε.)
# 146   Γυναίκα       38.0                3. Πανεπιστημιακή (Π.Ε.)
# 147   Γυναίκα       28.0                3. Πανεπιστημιακή (Π.Ε.)
# 148   Γυναίκα       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 149    Άνδρας       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 150   Γυναίκα       45.0                3. Πανεπιστημιακή (Π.Ε.)
# 151   Γυναίκα       48.0                   2. Τεχνολογική (Τ.Ε.)
# 152   Γυναίκα       40.0                3. Πανεπιστημιακή (Π.Ε.)
# 153    Άνδρας       42.0                3. Πανεπιστημιακή (Π.Ε.)
# 154   Γυναίκα       37.0                3. Πανεπιστημιακή (Π.Ε.)
# 155   Γυναίκα       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 156    Άνδρας       55.0                3. Πανεπιστημιακή (Π.Ε.)
# 157    Άνδρας       64.0                3. Πανεπιστημιακή (Π.Ε.)
# 158    Άνδρας       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 159   Γυναίκα       58.0                3. Πανεπιστημιακή (Π.Ε.)
# 160    Άνδρας       33.0                3. Πανεπιστημιακή (Π.Ε.)
# 161   Γυναίκα       43.0                3. Πανεπιστημιακή (Π.Ε.)
# 162    Άνδρας       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 163   Γυναίκα       57.0                3. Πανεπιστημιακή (Π.Ε.)
# 164    Άνδρας       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 165   Γυναίκα       60.0                3. Πανεπιστημιακή (Π.Ε.)
# 166    Άνδρας       51.0                3. Πανεπιστημιακή (Π.Ε.)
# 167   Γυναίκα       30.0                   2. Τεχνολογική (Τ.Ε.)
# 168   Γυναίκα       46.0                   2. Τεχνολογική (Τ.Ε.)
# 169   Γυναίκα       38.0                   2. Τεχνολογική (Τ.Ε.)
# 170   Γυναίκα       49.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 171   Γυναίκα       39.0                   2. Τεχνολογική (Τ.Ε.)
# 172   Γυναίκα       49.0                   2. Τεχνολογική (Τ.Ε.)
# 173   Γυναίκα       55.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 174   Γυναίκα       44.0                   2. Τεχνολογική (Τ.Ε.)
# 175   Γυναίκα       36.0                   2. Τεχνολογική (Τ.Ε.)
# 176   Γυναίκα       51.0                   2. Τεχνολογική (Τ.Ε.)
# 177   Γυναίκα       50.0                   2. Τεχνολογική (Τ.Ε.)
# 178    Άνδρας       52.0                   2. Τεχνολογική (Τ.Ε.)
# 179   Γυναίκα       50.0                   2. Τεχνολογική (Τ.Ε.)
# 180   Γυναίκα       47.0                   2. Τεχνολογική (Τ.Ε.)
# 181   Γυναίκα       28.0                3. Πανεπιστημιακή (Π.Ε.)
# 182   Γυναίκα       47.0                   2. Τεχνολογική (Τ.Ε.)
# 183   Γυναίκα       42.0                   2. Τεχνολογική (Τ.Ε.)
# 184   Γυναίκα       48.0                   2. Τεχνολογική (Τ.Ε.)
# 185   Γυναίκα       33.0                3. Πανεπιστημιακή (Π.Ε.)
# 186   Γυναίκα       56.0                   2. Τεχνολογική (Τ.Ε.)
# 187    Άνδρας       64.0                3. Πανεπιστημιακή (Π.Ε.)
# 188   Γυναίκα       51.0                   2. Τεχνολογική (Τ.Ε.)
# 189   Γυναίκα       60.0                3. Πανεπιστημιακή (Π.Ε.)
# 190   Γυναίκα       50.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 191   Γυναίκα       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 192    Άνδρας       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 193   Γυναίκα       41.0                   2. Τεχνολογική (Τ.Ε.)
# 194   Γυναίκα       37.0                   2. Τεχνολογική (Τ.Ε.)
# 195   Γυναίκα       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 196   Γυναίκα       34.0                3. Πανεπιστημιακή (Π.Ε.)
# 197   Γυναίκα       40.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 198    Άνδρας       61.0                3. Πανεπιστημιακή (Π.Ε.)
# 199    Άνδρας       56.0                   2. Τεχνολογική (Τ.Ε.)
# 200    Άνδρας       57.0                3. Πανεπιστημιακή (Π.Ε.)
# 201    Άνδρας       57.0                   2. Τεχνολογική (Τ.Ε.)
# 202    Άνδρας       60.0                   2. Τεχνολογική (Τ.Ε.)
# 203    Άνδρας       54.0                   2. Τεχνολογική (Τ.Ε.)
# 204    Άνδρας       59.0                3. Πανεπιστημιακή (Π.Ε.)
# 205   Γυναίκα       57.0                   2. Τεχνολογική (Τ.Ε.)
# 206    Άνδρας       28.0                3. Πανεπιστημιακή (Π.Ε.)
# 207   Γυναίκα       60.0                   2. Τεχνολογική (Τ.Ε.)
# 208    Άνδρας       37.0                3. Πανεπιστημιακή (Π.Ε.)
# 209   Γυναίκα       49.0                3. Πανεπιστημιακή (Π.Ε.)
# 210   Γυναίκα       52.0                   2. Τεχνολογική (Τ.Ε.)
# 211    Άνδρας        NaN                3. Πανεπιστημιακή (Π.Ε.)
# 212    Άνδρας       48.0                3. Πανεπιστημιακή (Π.Ε.)
# 213   Γυναίκα       56.0                3. Πανεπιστημιακή (Π.Ε.)
# 214   Γυναίκα       52.0                   2. Τεχνολογική (Τ.Ε.)
# 215    Άνδρας       30.0                   2. Τεχνολογική (Τ.Ε.)
# 216   Γυναίκα       48.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 217   Γυναίκα       55.0                   2. Τεχνολογική (Τ.Ε.)
# 218    Άνδρας       41.0                   2. Τεχνολογική (Τ.Ε.)
# 219   Γυναίκα       50.0                3. Πανεπιστημιακή (Π.Ε.)
# 220   Γυναίκα       36.0                3. Πανεπιστημιακή (Π.Ε.)
# 221   Γυναίκα       41.0                   2. Τεχνολογική (Τ.Ε.)
# 222   Γυναίκα         23                   2. Τεχνολογική (Τ.Ε.)
# 223   Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 224    Άνδρας         59                3. Πανεπιστημιακή (Π.Ε.)
# 225   Γυναίκα         29                3. Πανεπιστημιακή (Π.Ε.)
# 226    Άνδρας         52                3. Πανεπιστημιακή (Π.Ε.)
# 227   Γυναίκα         37                3. Πανεπιστημιακή (Π.Ε.)
# 228   Γυναίκα         45                3. Πανεπιστημιακή (Π.Ε.)
# 229    Άνδρας         55                3. Πανεπιστημιακή (Π.Ε.)
# 230    Άνδρας         52                3. Πανεπιστημιακή (Π.Ε.)
# 231   Γυναίκα         56                   2. Τεχνολογική (Τ.Ε.)
# 232   Γυναίκα         40                   2. Τεχνολογική (Τ.Ε.)
# 233   Γυναίκα         43                   2. Τεχνολογική (Τ.Ε.)
# 234    Άνδρας         58                3. Πανεπιστημιακή (Π.Ε.)
# 235    Άνδρας         34                3. Πανεπιστημιακή (Π.Ε.)
# 236    Άνδρας         41                3. Πανεπιστημιακή (Π.Ε.)
# 237   Γυναίκα         53                   2. Τεχνολογική (Τ.Ε.)
# 238    Άνδρας         58                   2. Τεχνολογική (Τ.Ε.)
# 239   Γυναίκα         47                   2. Τεχνολογική (Τ.Ε.)
# 240    Άνδρας         56                   2. Τεχνολογική (Τ.Ε.)
# 241    Άνδρας         40                3. Πανεπιστημιακή (Π.Ε.)
# 242   Γυναίκα         45                3. Πανεπιστημιακή (Π.Ε.)
# 243    Άνδρας         65                3. Πανεπιστημιακή (Π.Ε.)
#
#            3β. Άλλες σπουδές:  \
# 0      3. Διδακτορικό δίπλωμα
# 1    2. Μεταπτυχιακές σπουδές
# 2      3. Διδακτορικό δίπλωμα
# 3      3. Διδακτορικό δίπλωμα
# 4    2. Μεταπτυχιακές σπουδές
# 5    2. Μεταπτυχιακές σπουδές
# 6      3. Διδακτορικό δίπλωμα
# 7    2. Μεταπτυχιακές σπουδές
# 8    2. Μεταπτυχιακές σπουδές
# 9    2. Μεταπτυχιακές σπουδές
# 10              1. Ειδικότητα
# 11   2. Μεταπτυχιακές σπουδές
# 12   2. Μεταπτυχιακές σπουδές
# 13   2. Μεταπτυχιακές σπουδές
# 14   2. Μεταπτυχιακές σπουδές
# 15              1. Ειδικότητα
# 16              1. Ειδικότητα
# 17   2. Μεταπτυχιακές σπουδές
# 18     3. Διδακτορικό δίπλωμα
# 19                        NaN
# 20              1. Ειδικότητα
# 21     3. Διδακτορικό δίπλωμα
# 22   2. Μεταπτυχιακές σπουδές
# 23   2. Μεταπτυχιακές σπουδές
# 24              1. Ειδικότητα
# 25              1. Ειδικότητα
# 26              1. Ειδικότητα
# 27   2. Μεταπτυχιακές σπουδές
# 28                        NaN
# 29   2. Μεταπτυχιακές σπουδές
# 30     3. Διδακτορικό δίπλωμα
# 31                        NaN
# 32     3. Διδακτορικό δίπλωμα
# 33   2. Μεταπτυχιακές σπουδές
# 34                        NaN
# 35     3. Διδακτορικό δίπλωμα
# 36              1. Ειδικότητα
# 37                        NaN
# 38     3. Διδακτορικό δίπλωμα
# 39   2. Μεταπτυχιακές σπουδές
# 40   2. Μεταπτυχιακές σπουδές
# 41   2. Μεταπτυχιακές σπουδές
# 42   2. Μεταπτυχιακές σπουδές
# 43                        NaN
# 44                        NaN
# 45   2. Μεταπτυχιακές σπουδές
# 46   2. Μεταπτυχιακές σπουδές
# 47   2. Μεταπτυχιακές σπουδές
# 48              1. Ειδικότητα
# 49   2. Μεταπτυχιακές σπουδές
# 50                        NaN
# 51                        NaN
# 52              1. Ειδικότητα
# 53   2. Μεταπτυχιακές σπουδές
# 54   2. Μεταπτυχιακές σπουδές
# 55   2. Μεταπτυχιακές σπουδές
# 56                        NaN
# 57   2. Μεταπτυχιακές σπουδές
# 58   2. Μεταπτυχιακές σπουδές
# 59   2. Μεταπτυχιακές σπουδές
# 60   2. Μεταπτυχιακές σπουδές
# 61                        NaN
# 62              1. Ειδικότητα
# 63              1. Ειδικότητα
# 64              1. Ειδικότητα
# 65                        NaN
# 66   2. Μεταπτυχιακές σπουδές
# 67   2. Μεταπτυχιακές σπουδές
# 68   2. Μεταπτυχιακές σπουδές
# 69                        NaN
# 70                        NaN
# 71              1. Ειδικότητα
# 72              1. Ειδικότητα
# 73              1. Ειδικότητα
# 74   2. Μεταπτυχιακές σπουδές
# 75              1. Ειδικότητα
# 76   2. Μεταπτυχιακές σπουδές
# 77              1. Ειδικότητα
# 78     3. Διδακτορικό δίπλωμα
# 79   2. Μεταπτυχιακές σπουδές
# 80   2. Μεταπτυχιακές σπουδές
# 81   2. Μεταπτυχιακές σπουδές
# 82                        NaN
# 83                        NaN
# 84   2. Μεταπτυχιακές σπουδές
# 85              1. Ειδικότητα
# 86                        NaN
# 87                        NaN
# 88              1. Ειδικότητα
# 89              1. Ειδικότητα
# 90              1. Ειδικότητα
# 91                        NaN
# 92                        NaN
# 93              1. Ειδικότητα
# 94   2. Μεταπτυχιακές σπουδές
# 95     3. Διδακτορικό δίπλωμα
# 96              1. Ειδικότητα
# 97   2. Μεταπτυχιακές σπουδές
# 98     3. Διδακτορικό δίπλωμα
# 99   2. Μεταπτυχιακές σπουδές
# 100  2. Μεταπτυχιακές σπουδές
# 101  2. Μεταπτυχιακές σπουδές
# 102                       NaN
# 103  2. Μεταπτυχιακές σπουδές
# 104  2. Μεταπτυχιακές σπουδές
# 105  2. Μεταπτυχιακές σπουδές
# 106                       NaN
# 107  2. Μεταπτυχιακές σπουδές
# 108             1. Ειδικότητα
# 109                       NaN
# 110             1. Ειδικότητα
# 111    3. Διδακτορικό δίπλωμα
# 112                       NaN
# 113  2. Μεταπτυχιακές σπουδές
# 114  2. Μεταπτυχιακές σπουδές
# 115                       NaN
# 116             1. Ειδικότητα
# 117                       NaN
# 118                       NaN
# 119                       NaN
# 120                       NaN
# 121  2. Μεταπτυχιακές σπουδές
# 122             1. Ειδικότητα
# 123                       NaN
# 124  2. Μεταπτυχιακές σπουδές
# 125             1. Ειδικότητα
# 126             1. Ειδικότητα
# 127  2. Μεταπτυχιακές σπουδές
# 128                       NaN
# 129  2. Μεταπτυχιακές σπουδές
# 130             1. Ειδικότητα
# 131                       NaN
# 132  2. Μεταπτυχιακές σπουδές
# 133                       NaN
# 134  2. Μεταπτυχιακές σπουδές
# 135             1. Ειδικότητα
# 136    3. Διδακτορικό δίπλωμα
# 137  2. Μεταπτυχιακές σπουδές
# 138  2. Μεταπτυχιακές σπουδές
# 139             1. Ειδικότητα
# 140  2. Μεταπτυχιακές σπουδές
# 141  2. Μεταπτυχιακές σπουδές
# 142  2. Μεταπτυχιακές σπουδές
# 143                       NaN
# 144             1. Ειδικότητα
# 145             1. Ειδικότητα
# 146             1. Ειδικότητα
# 147             1. Ειδικότητα
# 148             1. Ειδικότητα
# 149  2. Μεταπτυχιακές σπουδές
# 150  2. Μεταπτυχιακές σπουδές
# 151  2. Μεταπτυχιακές σπουδές
# 152             1. Ειδικότητα
# 153  2. Μεταπτυχιακές σπουδές
# 154  2. Μεταπτυχιακές σπουδές
# 155  2. Μεταπτυχιακές σπουδές
# 156    3. Διδακτορικό δίπλωμα
# 157    3. Διδακτορικό δίπλωμα
# 158    3. Διδακτορικό δίπλωμα
# 159    3. Διδακτορικό δίπλωμα
# 160             1. Ειδικότητα
# 161             1. Ειδικότητα
# 162             1. Ειδικότητα
# 163             1. Ειδικότητα
# 164             1. Ειδικότητα
# 165  2. Μεταπτυχιακές σπουδές
# 166    3. Διδακτορικό δίπλωμα
# 167  2. Μεταπτυχιακές σπουδές
# 168  2. Μεταπτυχιακές σπουδές
# 169                       NaN
# 170                       NaN
# 171  2. Μεταπτυχιακές σπουδές
# 172  2. Μεταπτυχιακές σπουδές
# 173                       NaN
# 174  2. Μεταπτυχιακές σπουδές
# 175                       NaN
# 176  2. Μεταπτυχιακές σπουδές
# 177  2. Μεταπτυχιακές σπουδές
# 178                       NaN
# 179             1. Ειδικότητα
# 180    3. Διδακτορικό δίπλωμα
# 181             1. Ειδικότητα
# 182                       NaN
# 183  2. Μεταπτυχιακές σπουδές
# 184                       NaN
# 185             1. Ειδικότητα
# 186  2. Μεταπτυχιακές σπουδές
# 187    3. Διδακτορικό δίπλωμα
# 188             1. Ειδικότητα
# 189    3. Διδακτορικό δίπλωμα
# 190                       NaN
# 191    3. Διδακτορικό δίπλωμα
# 192  2. Μεταπτυχιακές σπουδές
# 193             1. Ειδικότητα
# 194                       NaN
# 195  2. Μεταπτυχιακές σπουδές
# 196  2. Μεταπτυχιακές σπουδές
# 197             1. Ειδικότητα
# 198    3. Διδακτορικό δίπλωμα
# 199    3. Διδακτορικό δίπλωμα
# 200    3. Διδακτορικό δίπλωμα
# 201  2. Μεταπτυχιακές σπουδές
# 202             1. Ειδικότητα
# 203  2. Μεταπτυχιακές σπουδές
# 204    3. Διδακτορικό δίπλωμα
# 205  2. Μεταπτυχιακές σπουδές
# 206  2. Μεταπτυχιακές σπουδές
# 207             1. Ειδικότητα
# 208             1. Ειδικότητα
# 209  2. Μεταπτυχιακές σπουδές
# 210                       NaN
# 211                       NaN
# 212             1. Ειδικότητα
# 213             1. Ειδικότητα
# 214  2. Μεταπτυχιακές σπουδές
# 215  2. Μεταπτυχιακές σπουδές
# 216                       NaN
# 217                       NaN
# 218    3. Διδακτορικό δίπλωμα
# 219  2. Μεταπτυχιακές σπουδές
# 220  2. Μεταπτυχιακές σπουδές
# 221  2. Μεταπτυχιακές σπουδές
# 222  2. Μεταπτυχιακές σπουδές
# 223  2. Μεταπτυχιακές σπουδές
# 224    3. Διδακτορικό δίπλωμα
# 225  2. Μεταπτυχιακές σπουδές
# 226             1. Ειδικότητα
# 227  2. Μεταπτυχιακές σπουδές
# 228    3. Διδακτορικό δίπλωμα
# 229    3. Διδακτορικό δίπλωμα
# 230             1. Ειδικότητα
# 231  2. Μεταπτυχιακές σπουδές
# 232                       NaN
# 233                       NaN
# 234  2. Μεταπτυχιακές σπουδές
# 235    3. Διδακτορικό δίπλωμα
# 236  2. Μεταπτυχιακές σπουδές
# 237                       NaN
# 238  2. Μεταπτυχιακές σπουδές
# 239  2. Μεταπτυχιακές σπουδές
# 240                       NaN
# 241  2. Μεταπτυχιακές σπουδές
# 242  2. Μεταπτυχιακές σπουδές
# ...
# 220                                                 40
# 221                                                 40
# 222                                                 34
# 223                                                 50
# 224                                                 50
# 225                                            45 ώρες
# 226                                                 56
# 227                                              70-80
# 228                                                NaN
# 229                                                 35
# 230                                              4 ΕΤΗ
# 231                                                50
# 232                                              40-45
# 233                                              40-45
# 234                                                 40
# 235                                                 50
# 236                                                 40
# 237                                                 40
# 238                                                 45
# 239                                                 40
# 240                                                 40
# 241                                                 58
# 242                                                 42
# 243                                                 50
#
#     10. Τι θέση κατέχετε στο νοσοκομείο που εργάζεστε;
# 0                                     4. ΤΕ Νοσηλευτής
# 1                                     4. ΤΕ Νοσηλευτής
# 2                                     4. ΤΕ Νοσηλευτής
# 3                                                  NaN
# 4                                     4. ΤΕ Νοσηλευτής
# 5                                    2. Ειδικός ιατρός
# 6                                     4. ΤΕ Νοσηλευτής
# 7                                     4. ΤΕ Νοσηλευτής
# 8                                     4. ΤΕ Νοσηλευτής
# 9                                     4. ΤΕ Νοσηλευτής
# 10                                    4. ΤΕ Νοσηλευτής
# 11                                    4. ΤΕ Νοσηλευτής
# 12                                    4. ΤΕ Νοσηλευτής
# 13                                    4. ΤΕ Νοσηλευτής
# 14                                    4. ΤΕ Νοσηλευτής
# 15                                    3. ΠΕ Νοσηλευτής
# 16                                    4. ΤΕ Νοσηλευτής
# 17                                    4. ΤΕ Νοσηλευτής
# 18                                    4. ΤΕ Νοσηλευτής
# 19                                    4. ΤΕ Νοσηλευτής
# 20                                    4. ΤΕ Νοσηλευτής
# 21                                    4. ΤΕ Νοσηλευτής
# 22                                    4. ΤΕ Νοσηλευτής
# 23                                    4. ΤΕ Νοσηλευτής
# 24                                    4. ΤΕ Νοσηλευτής
# 25                                    4. ΤΕ Νοσηλευτής
# 26                                    4. ΤΕ Νοσηλευτής
# 27                                    4. ΤΕ Νοσηλευτής
# 28                              5. ΔΕ Βοηθός Νοσηλευτή
# 29                                    4. ΤΕ Νοσηλευτής
# 30                                    3. ΠΕ Νοσηλευτής
# 31                                    4. ΤΕ Νοσηλευτής
# 32                                    3. ΠΕ Νοσηλευτής
# 33                              5. ΔΕ Βοηθός Νοσηλευτή
# 34                              5. ΔΕ Βοηθός Νοσηλευτή
# 35                                    3. ΠΕ Νοσηλευτής
# 36                                    4. ΤΕ Νοσηλευτής
# 37                              5. ΔΕ Βοηθός Νοσηλευτή
# 38                                   2. Ειδικός ιατρός
# 39                                    4. ΤΕ Νοσηλευτής
# 40                                    3. ΠΕ Νοσηλευτής
# 41                                    4. ΤΕ Νοσηλευτής
# 42                                    3. ΠΕ Νοσηλευτής
# 43                              5. ΔΕ Βοηθός Νοσηλευτή
# 44                              5. ΔΕ Βοηθός Νοσηλευτή
# 45                                    4. ΤΕ Νοσηλευτής
# 46                                    4. ΤΕ Νοσηλευτής
# 47                                    4. ΤΕ Νοσηλευτής
# 48                                    4. ΤΕ Νοσηλευτής
# 49                                    4. ΤΕ Νοσηλευτής
# 50                                    4. ΤΕ Νοσηλευτής
# 51                              5. ΔΕ Βοηθός Νοσηλευτή
# 52                                    4. ΤΕ Νοσηλευτής
# 53                                    4. ΤΕ Νοσηλευτής
# 54                                    4. ΤΕ Νοσηλευτής
# 55                                    3. ΠΕ Νοσηλευτής
# 56                                                 NaN
# 57                                    4. ΤΕ Νοσηλευτής
# 58                                    3. ΠΕ Νοσηλευτής
# 59                                    4. ΤΕ Νοσηλευτής
# 60                                    4. ΤΕ Νοσηλευτής
# 61                              5. ΔΕ Βοηθός Νοσηλευτή
# 62                                    4. ΤΕ Νοσηλευτής
# 63                                    4. ΤΕ Νοσηλευτής
# 64                                    4. ΤΕ Νοσηλευτής
# 65                                                 NaN
# 66                                    4. ΤΕ Νοσηλευτής
# 67                                    4. ΤΕ Νοσηλευτής
# 68                                    4. ΤΕ Νοσηλευτής
# 69                                    4. ΤΕ Νοσηλευτής
# 70                              5. ΔΕ Βοηθός Νοσηλευτή
# 71                                    4. ΤΕ Νοσηλευτής
# 72                                    4. ΤΕ Νοσηλευτής
# 73                                    4. ΤΕ Νοσηλευτής
# 74                                    4. ΤΕ Νοσηλευτής
# 75                                    4. ΤΕ Νοσηλευτής
# 76                                    4. ΤΕ Νοσηλευτής
# 77                                    4. ΤΕ Νοσηλευτής
# 78                                    4. ΤΕ Νοσηλευτής
# 79                                    4. ΤΕ Νοσηλευτής
# 80                                    4. ΤΕ Νοσηλευτής
# 81                                    4. ΤΕ Νοσηλευτής
# 82                                                 NaN
# 83                                    4. ΤΕ Νοσηλευτής
# 84                                    4. ΤΕ Νοσηλευτής
# 85                                    4. ΤΕ Νοσηλευτής
# 86                                    4. ΤΕ Νοσηλευτής
# 87                                    4. ΤΕ Νοσηλευτής
# 88                                    4. ΤΕ Νοσηλευτής
# 89                                    4. ΤΕ Νοσηλευτής
# 90                                    4. ΤΕ Νοσηλευτής
# 91                                    4. ΤΕ Νοσηλευτής
# 92                                                 NaN
# 93                                    4. ΤΕ Νοσηλευτής
# 94                                   2. Ειδικός ιατρός
# 95                                   2. Ειδικός ιατρός
# 96                                   2. Ειδικός ιατρός
# 97                             1. Ειδικευόμενος ιατρός
# 98                                   2. Ειδικός ιατρός
# 99                                   2. Ειδικός ιατρός
# 100                                   4. ΤΕ Νοσηλευτής
# 101                                   3. ΠΕ Νοσηλευτής
# 102                                   4. ΤΕ Νοσηλευτής
# 103                                   4. ΤΕ Νοσηλευτής
# 104                                   4. ΤΕ Νοσηλευτής
# 105                                   4. ΤΕ Νοσηλευτής
# 106                                   4. ΤΕ Νοσηλευτής
# 107                                   4. ΤΕ Νοσηλευτής
# 108                                   4. ΤΕ Νοσηλευτής
# 109                                   4. ΤΕ Νοσηλευτής
# 110                                   4. ΤΕ Νοσηλευτής
# 111                                  2. Ειδικός ιατρός
# 112                                   4. ΤΕ Νοσηλευτής
# 113                                   4. ΤΕ Νοσηλευτής
# 114                                   4. ΤΕ Νοσηλευτής
# 115                             5. ΔΕ Βοηθός Νοσηλευτή
# 116                                   4. ΤΕ Νοσηλευτής
# 117                             5. ΔΕ Βοηθός Νοσηλευτή
# 118                                   4. ΤΕ Νοσηλευτής
# 119                                   4. ΤΕ Νοσηλευτής
# 120                                                NaN
# 121                                   4. ΤΕ Νοσηλευτής
# 122                                                NaN
# 123                                   4. ΤΕ Νοσηλευτής
# 124                                   3. ΠΕ Νοσηλευτής
# 125                                   4. ΤΕ Νοσηλευτής
# 126                                   4. ΤΕ Νοσηλευτής
# 127                                   4. ΤΕ Νοσηλευτής
# 128                                   4. ΤΕ Νοσηλευτής
# 129                                   4. ΤΕ Νοσηλευτής
# 130                                   4. ΤΕ Νοσηλευτής
# 131                                   4. ΤΕ Νοσηλευτής
# 132                                   4. ΤΕ Νοσηλευτής
# 133                             5. ΔΕ Βοηθός Νοσηλευτή
# 134                            1. Ειδικευόμενος ιατρός
# 135                            1. Ειδικευόμενος ιατρός
# 136                            1. Ειδικευόμενος ιατρός
# 137                            1. Ειδικευόμενος ιατρός
# 138                            1. Ειδικευόμενος ιατρός
# 139                            1. Ειδικευόμενος ιατρός
# 140                            1. Ειδικευόμενος ιατρός
# 141                            1. Ειδικευόμενος ιατρός
# 142                            1. Ειδικευόμενος ιατρός
# 143                                  2. Ειδικός ιατρός
# 144                            1. Ειδικευόμενος ιατρός
# 145                            1. Ειδικευόμενος ιατρός
# 146                            1. Ειδικευόμενος ιατρός
# 147                            1. Ειδικευόμενος ιατρός
# 148                            1. Ειδικευόμενος ιατρός
# 149                            1. Ειδικευόμενος ιατρός
# 150                                  2. Ειδικός ιατρός
# 151                                   4. ΤΕ Νοσηλευτής
# 152                            1. Ειδικευόμενος ιατρός
# 153                            1. Ειδικευόμενος ιατρός
# 154                                  2. Ειδικός ιατρός
# 155                            1. Ειδικευόμενος ιατρός
# 156                            1. Ειδικευόμενος ιατρός
# 157                                  2. Ειδικός ιατρός
# 158                                  2. Ειδικός ιατρός
# 159                                  2. Ειδικός ιατρός
# 160                            1. Ειδικευόμενος ιατρός
# 161                            1. Ειδικευόμενος ιατρός
# 162                            1. Ειδικευόμενος ιατρός
# 163                                  2. Ειδικός ιατρός
# 164                            1. Ειδικευόμενος ιατρός
# 165                                  2. Ειδικός ιατρός
# 166                                  2. Ειδικός ιατρός
# 167                                   4. ΤΕ Νοσηλευτής
# 168                                   4. ΤΕ Νοσηλευτής
# 169                                   4. ΤΕ Νοσηλευτής
# 170                             5. ΔΕ Βοηθός Νοσηλευτή
# 171                                   4. ΤΕ Νοσηλευτής
# 172                                   4. ΤΕ Νοσηλευτής
# 173                             5. ΔΕ Βοηθός Νοσηλευτή
# 174                                   4. ΤΕ Νοσηλευτής
# 175                                   4. ΤΕ Νοσηλευτής
# 176                                   4. ΤΕ Νοσηλευτής
# 177                                   4. ΤΕ Νοσηλευτής
# 178                                   4. ΤΕ Νοσηλευτής
# 179                                   4. ΤΕ Νοσηλευτής
# 180                                   4. ΤΕ Νοσηλευτής
# 181                                   3. ΠΕ Νοσηλευτής
# 182                                   4. ΤΕ Νοσηλευτής
# 183                                   4. ΤΕ Νοσηλευτής
# 184                                   4. ΤΕ Νοσηλευτής
# 185                            1. Ειδικευόμενος ιατρός
# 186                                                NaN
# 187                                  2. Ειδικός ιατρός
# 188                                   4. ΤΕ Νοσηλευτής
# 189                                  2. Ειδικός ιατρός
# 190                             5. ΔΕ Βοηθός Νοσηλευτή
# 191                                  2. Ειδικός ιατρός
# 192                                  2. Ειδικός ιατρός
# 193                                   4. ΤΕ Νοσηλευτής
# 194                                   4. ΤΕ Νοσηλευτής
# 195                                  2. Ειδικός ιατρός
# 196                                   3. ΠΕ Νοσηλευτής
# 197                             5. ΔΕ Βοηθός Νοσηλευτή
# 198                                  2. Ειδικός ιατρός
# 199                                   4. ΤΕ Νοσηλευτής
# 200                                  2. Ειδικός ιατρός
# 201                                   4. ΤΕ Νοσηλευτής
# 202                                   4. ΤΕ Νοσηλευτής
# 203                                   4. ΤΕ Νοσηλευτής
# 204                                  2. Ειδικός ιατρός
# 205                                   4. ΤΕ Νοσηλευτής
# 206                            1. Ειδικευόμενος ιατρός
# 207                                   4. ΤΕ Νοσηλευτής
# 208                                  2. Ειδικός ιατρός
# 209                                  2. Ειδικός ιατρός
# 210                                   4. ΤΕ Νοσηλευτής
# 211                                                NaN
# 212                                  2. Ειδικός ιατρός
# 213                                  2. Ειδικός ιατρός
# 214                                   4. ΤΕ Νοσηλευτής
# 215                                                NaN
# 216                             5. ΔΕ Βοηθός Νοσηλευτή
# 217                                   4. ΤΕ Νοσηλευτής
# 218                                   4. ΤΕ Νοσηλευτής
# 219                                  2. Ειδικός ιατρός
# 220                                   3. ΠΕ Νοσηλευτής
# 221                                   4. ΤΕ Νοσηλευτής
# 222                                   4. ΤΕ Νοσηλευτής
# 223                                   4. ΤΕ Νοσηλευτής
# 224                                  2. Ειδικός ιατρός
# 225                            1. Ειδικευόμενος ιατρός
# 226                                  2. Ειδικός ιατρός
# 227                                  2. Ειδικός ιατρός
# 228                                  2. Ειδικός ιατρός
# 229                                  2. Ειδικός ιατρός
# 230                                  2. Ειδικός ιατρός
# 231                                   4. ΤΕ Νοσηλευτής
# 232                                   4. ΤΕ Νοσηλευτής
# 233                                   4. ΤΕ Νοσηλευτής
# 234                                   3. ΠΕ Νοσηλευτής
# 235                                   3. ΠΕ Νοσηλευτής
# 236                                   3. ΠΕ Νοσηλευτής
# 237                                   4. ΤΕ Νοσηλευτής
# 238                                   4. ΤΕ Νοσηλευτής
# 239                                   4. ΤΕ Νοσηλευτής
# 240                                                NaN
# 241                                  2. Ειδικός ιατρός
# 242                                   3. ΠΕ Νοσηλευτής
# 243                                  2. Ειδικός ιατρός

# %%
#print all questions
#for index, item in enumerate(hospitals_questions, start=0):  
#    print(index," ", item)

# %% [markdown]
# ## 3. Split Questions to 12 categories according to HSOPSC and check for internal consistency internal consistency

# %%
#helper functions

def my_reverse(table, q):
    for index in range(len(table)):
        if table[q].iloc[index] == 1:
            table[q].iloc[index] = 5
        elif table[q].iloc[index] == 2:
            table[q].iloc[index] = 4
        elif table[q].iloc[index] == 4:
            table[q].iloc[index] = 2
        elif table[q].iloc[index] == 5:
            table[q].iloc[index] = 1
    return table

# %% [markdown]
# #### Parameter of patient safety 1 : Open Communication

# %%
g4 = '4. Το προσωπικό μπορεί ελεύθερα να αμφισβητήσει τις αποφάσεις ή τις ενέργειες των ανωτέρων του.'
g2 = '2. Το προσωπικό μιλάει ελεύθερα όταν διαπιστώσει κάτι που επιδρά αρνητικά στη φροντίδα υγείας του ασθενούς.'
g6 = '6. Το προσωπικό φοβάται να ρωτήσει, όταν κάτι δεν φαίνεται σωστό.'

open_communication = hospitals_questions[:][[g4,g2,g6]]

# %%
#reverse question g6
open_communication = my_reverse(open_communication, g6)
# %store open_communication
# Out:
# Stored 'open_communication' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=open_communication)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.6743414056090667

# %% [markdown]
# #### Parameter of patient safety 2

# %%
g1 = '1. Γίνεται συστηματική αξιολόγηση των αλλαγών που τίθενται σε εφαρμογή, βάσει δυσμενών συμβάντων που έχουν αναφερθεί. '
g3 = '3. Το προσωπικό ενημερώνεται συχνά για τα δυσμενή συμβάντα που λαμβάνουν χώρα.'
g5 = '5. Το προσωπικό συζητά τρόπους πρόληψης δυσμενών συμβάντων ώστε να μην επαναληφθούν.'


parameter_2 = hospitals_questions[:][[g1,g3,g5]]
# %store parameter_2
# Out:
# Stored 'parameter_2' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_2)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.7640560884558483

# %% [markdown]
# #### Parameter of patient safety 3

# %%
a6 = '6. Το προσωπικό εργάζεται δυναμικά για τη βελτίωση της ασφάλειας του ασθενούς.'
a9 = '9. Τα λάθη οδήγησαν σε θετικές αλλαγές.'
a13 = '13. Όταν γίνονται αλλαγές για τη βελτίωση της ασφάλειας του ασθενούς, αξιολογείται η αποτελεσματικότητά τους.'

parameter_3 = hospitals_questions[:][[a6,a9,a13]]
# %store parameter_3
# Out:
# Stored 'parameter_3' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_3)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.6706998921472327

# %% [markdown]
# #### Parameter of patient safety 4

# %%
a1 = '1. Οι εργαζόμενοι υποστηρίζουν ο ένας τον άλλον.'
a3 = '3. Όταν υπάρχει μεγάλος όγκος εργασίας που πρέπει να γίνει άμεσα, το προσωπικό εργάζεται ομαδικά για την ολοκλήρωση της.'
a4 = '4. Υπάρχει σεβασμός ανάμεσα στους εργαζομένους.'
a11 = '11. Όταν υπάρχει μεγάλος φόρτος εργασίας παρέχεται βοήθεια από άλλες Μονάδες.'

parameter_4 = hospitals_questions[:][[a1,a3,a4,a11]]
# %store parameter_4
# Out:
# Stored 'parameter_4' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_4)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.6407142720453203

# %% [markdown]
# #### Parameter of patient safety 5

# %%
a8 = '8. Το προσωπικό αισθάνεται ότι τα λάθη του μπορεί να χρησιμοποιηθούν εναντίον του. '
a12 = '12. Όταν δηλώνεται ένα δυσμενές συμβάν, υπάρχει η αίσθηση ότι καταγράφεται το άτομο και όχι το καθαυτό συμβάν.'
a16 = '16. Το προσωπικό ανησυχεί ότι τα λάθη του καταγράφονται στο προσωπικό του φάκελο.'

parameter_5 = hospitals_questions[:][[a8,a12,a16]]
# %store parameter_5
# Out:
# Stored 'parameter_5' (DataFrame)

# %%
#reverse question a8 a12 a16
pd.options.mode.chained_assignment = None  # default='warn'
parameter_5 = my_reverse(parameter_5, a8)
parameter_5 = my_reverse(parameter_5, a12)
parameter_5 = my_reverse(parameter_5, a16)

# %store parameter_5
# Out:
# Stored 'parameter_5' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_5)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.6354050094932764

# %% [markdown]
# #### Parameter of patient safety 6

# %%
b1 = '1. Επιβραβεύει το προσωπικό με καλά λόγια όταν τηρούνται οι διαδικασίες ασφαλούς φροντίδας του ασθενούς.'
b2 = '2. Λαμβάνει σοβαρά υπόψη του τις προτάσεις του προσωπικού για βελτίωση της ασφάλειας του ασθενούς.'
b3 = '3. Παροτρύνει το προσωπικό να εργάζεται γρηγορότερα όταν υπάρχει υπερβολικός φόρτος εργασίας και πίεση, ακόμη και όταν παραβλέπονται σημαντικές διαδικασίες ασφάλειας του ασθενούς.'
b4 = '4. Παραβλέπει επαναλαμβανόμενα προβλήματα ασφάλειας του ασθενούς.'

parameter_6 = hospitals_questions[:][[b1,b2,b3,b4]]
# %store parameter_6
# Out:
# Stored 'parameter_6' (DataFrame)

# %%
#reverse question b3 b4
parameter_6 = my_reverse(parameter_6, b3)
parameter_6 = my_reverse(parameter_6, b4)

# %store parameter_6
# Out:
# Stored 'parameter_6' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_6)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.7575925334970262

# %% [markdown]
# #### Parameter of patient safety 7

# %%
a2 = '2. Υπάρχει επαρκές προσωπικό για τη διεκπεραίωση της εργασίας.'
a5 = '5. Το προσωπικό εργάζεται περισσότερες ώρες από αυτές που διασφαλίζουν ασφαλή φροντίδα για τον ασθενή.'
a7 = '7. Αξιοποιείται περισσότερο προσωρινό προσωπικό από αυτό που διασφαλίζει την ασφαλή φροντίδα του ασθενούς.'
a14 = '14. Το προσωπικό εργάζεται σε «κατάσταση κρίσης» προσπαθώντας να κάνει πολλά πράγματα γρήγορα.'

parameter_7 = hospitals_questions[:][[a2,a5,a7,a14]]
# %store parameter_7
# Out:
# Stored 'parameter_7' (DataFrame)

# %%
#reverse question a5 a7 a14
parameter_7 = my_reverse(parameter_7,a5)
parameter_7 = my_reverse(parameter_7,a7)
parameter_7 = my_reverse(parameter_7,a14)

# %store parameter_7
# Out:
# Stored 'parameter_7' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_7)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.5601356084262348

# %% [markdown]
# #### Parameter of patient safety 8

# %%
st1 = '1. Η Διοίκηση εξασφαλίζει εργασιακό κλίμα που προάγει την ασφάλεια του ασθενούς .'
st8 = '8. Η ασφάλεια του ασθενούς αποτελεί κύρια προτεραιότητα για την Διοίκηση.'
st9 = '9. Η Διοίκηση δείχνει να ενδιαφέρεται για την ασφάλεια του ασθενούς μόνο μετά από την αναφορά κάποιου δυσμενούς συμβάντος.'

parameter_8 = hospitals_questions[:][[st1,st8,st9]]

# %%
#reverse question st9
parameter_8 = my_reverse(parameter_8,st9)

# %store parameter_8
# Out:
# Stored 'parameter_8' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_8)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.7859727574014148

# %% [markdown]
# #### Parameter of patient safety 9

# %%
st2 = '2. Υπάρχει ελλιπής συντονισμός μεταξύ των Μονάδων.'
st4 = '4. Υπάρχει καλή συνεργασία ανάμεσα στις Μονάδες όταν αυτό απαιτείται.'
st6 = '6. Η συνεργασία με το προσωπικό άλλων Μονάδων είναι συχνά δυσάρεστη.'
st10 = '10. Οι Μονάδες συνεργάζονται καλά μεταξύ τους για την παροχή άριστης ποιοτικά φροντίδας υγείας στον ασθενή.'

parameter_9 = hospitals_questions[:][[st2,st4,st6,st10]]

# %%
#reverse question st2 st6 
parameter_9 = my_reverse(parameter_9,st2)
parameter_9 = my_reverse(parameter_9,st6)

# %store parameter_9
# Out:
# Stored 'parameter_9' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_9)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.822705930024437

# %% [markdown]
# #### Parameter of patient safety 10

# %%
st3 = '3. Η μεταφορά ασθενούς από τη μία Μονάδα στην άλλη συνήθως συνοδεύεται από προβλήματα.'
st5 = '5. Συχνά, σημαντικές πληροφορίες σχετικά με τη νοσηλεία του ασθενούς χάνονται κατά την αλλαγή της βάρδιας.'
st7 = '7. Συχνά παρουσιάζονται διάφορα προβλήματα κατά την ανταλλαγή πληροφοριών μεταξύ των Μονάδων.'
st11 = '11. Η αλλαγή βάρδιας είναι προβληματική για τον ασθενή.'

parameter_10 = hospitals_questions[:][[st3,st5,st7,st11]]

# %store parameter_10
# Out:
# Stored 'parameter_10' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_10)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.812522664562378

# %% [markdown]
# #### Parameter of patient safety 11

# %%
d1 = '…..αλλά εντοπιστεί και διορθωθεί πριν επηρεάσει τον ασθενή '
d2 = '……αλλά δεν έχει πιθανότητα να βλάψει τον ασθενή.'
d3 = '…..που θα μπορούσε να βλάψει τον ασθενή, αλλά δεν τον επηρέασε '

parameter_11 = hospitals_questions[:][[d1,d2,d3]]

# %store parameter_11
# Out:
# Stored 'parameter_11' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_11)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.8452422147078922

# %% [markdown]
# #### Parameter of patient safety 12

# %%
a10 = '10. Από τύχη δεν συμβαίνουν σοβαρά λάθη.'
a15 = '15. Η ασφάλεια του ασθενούς αποτελεί προτεραιότητα ακόμα και όταν υπάρχει φόρτος εργασίας. '
a18 = '18. Οι διαδικασίες διεκπεραίωσης της εργασίας και το σύστημα εν γένει συμβάλλει στην πρόληψη δυσμενών συμβάντων.'
a17 = '17. Υπάρχει πρόβλημα ασφάλειας του ασθενούς.'

parameter_12 = hospitals_questions[:][[a10,a15,a18,a17]]

# %%
#reverse question a10 a17
parameter_12 = my_reverse(parameter_12,a10)
parameter_12 = my_reverse(parameter_12,a17)

# %store parameter_12
# Out:
# Stored 'parameter_12' (DataFrame)

# %%
#calculate cronabachs alpha
ca = pg.cronbach_alpha(data=parameter_12)
print("Cronabachs alpha for parameter 1: ",ca[0])
# Out:
# Cronabachs alpha for parameter 1:  0.6926007210171772

# %% [markdown]
# #### Eleftheroi paramteroi

# %%
z = 'Τους τελευταίους 12 μήνες πόσα δυσμενή συμβάντα έχετε αναφέρει; (Αναφέρετε έναν αριθμό)'
#parameter_14 = hospitals_questions[:][[z]]

# %%
import numpy as np


pd.set_option('display.max_rows', None)
#parameter_14 = parameter_14.dropna()

#print(parameter_14)

#for i in range(len(parameter_14)):
 #   print(parameter_14.loc[i,z])

# %% [markdown]
# ### Parameter 13

# %%
e = 'Παρακαλώ αξιολογήστε το επίπεδο ασφάλειας των ασθενών συνολικά στο Εργασιακό Περιβάλλον/Μονάδα σας επιλέγοντας με √ την απάντηση που σας εκφράζει.'

parameter_13 = hospitals_questions[:][[e]]
parameter_13.columns = ['score']



# %store parameter_13

#parameter_13 = parameter_13.dropna()
# Out:
# Stored 'parameter_13' (DataFrame)

# %%
for index, item in enumerate(parameter_13, start=0):  
    print(index," ", item)
# Out:
# 0   score

# %% [markdown]
# ## 4. Personal Info Exploratory Analysis

# %%
#helper function that creates bar charts
def my_graph(y,x,title,sizeX,sizeY):


    # Figure Size
    fig, ax = plt.subplots(figsize =(sizeX, sizeY))

    # Horizontal Bar Plot
    ax.barh(y, x,color=(0.0, 0.4, 0.6, 0.6))

    # Remove axes splines
    for s in ['top', 'bottom', 'left', 'right']:
        ax.spines[s].set_visible(False)

    # Remove x, y Ticks
    ax.xaxis.set_ticks_position('none')
    #ax.yaxis.set_ticks_position('none')

    # Add padding between axes and labels
    ax.xaxis.set_tick_params(pad = 1)
    ax.yaxis.set_tick_params(pad = 10)
    ax.set_xticklabels([])
    
    # Add x, y gridlines
    ax.grid(b = True, color ='grey',
            linestyle ='-.', linewidth = 0.9,
            alpha = 0.2)

    # Show top values
    ax.invert_yaxis()

    # Add annotation to bars
    for i in ax.patches:
        plt.text(i.get_width()+0.01, i.get_y()+0.40,
                str(round((i.get_width()), 1))+'%',
                fontsize = 10, fontweight ='bold',
                color ='black')
    

    # Add Plot Title
    ax.set_title(title,
                loc ='left', )

    # Show Plot
    plt.show()

# %% [markdown]
# ### Analysis of Proffesion

# %%
proffesion = hospitals_personalInfo['10. Τι θέση κατέχετε στο νοσοκομείο που εργάζεστε;']

absolute_frequencies = proffesion.value_counts()
relative_frequencies = proffesion.value_counts(normalize=True)

# %%
relative_frequencies = relative_frequencies*100
relative_frequencies
# Out:
# 4. ΤΕ Νοσηλευτής           57.510730
# 2. Ειδικός ιατρός          16.309013
# 1. Ειδικευόμενος ιατρός    11.587983
# 3. ΠΕ Νοσηλευτής            7.296137
# 5. ΔΕ Βοηθός Νοσηλευτή      7.296137
# Name: 10. Τι θέση κατέχετε στο νοσοκομείο που εργάζεστε;, dtype: float64

# %%
absolute_frequencies
# Out:
# 4. ΤΕ Νοσηλευτής           134
# 2. Ειδικός ιατρός           38
# 1. Ειδικευόμενος ιατρός     27
# 3. ΠΕ Νοσηλευτής            17
# 5. ΔΕ Βοηθός Νοσηλευτή      17
# Name: 10. Τι θέση κατέχετε στο νοσοκομείο που εργάζεστε;, dtype: int64

# %%
title = ["ΤΕ Νοσηλευτής", "Ιατρός", "Ειδικευόμενος Ιατρός", "ΠΕ Νοσηλευτής", "ΔΕ Βοηθός Νοσηλευτή"]

my_graph(title,relative_frequencies,"Ποσοστιαία Κατανομή Eπαγγλεμάτων",6,3)

# %%
# pie chart (not used)

#plot relative_frequencies
colors = sns.color_palette("Paired", 3)

#define data
data = relative_frequencies
labels = relative_frequencies.index

#plt.pie(data, labels = labels, colors = colors, autopct='%0.f%%')
#plt.show()

# %% [markdown]
# ### Analysis of Age

# %%
age = hospitals_personalInfo['2. Ηλικία…']
age = age[]

age
#age["age_group"] = pd.qcut(age, q=[0, 0.4, 0.8, 1],labels=["lowest", "middle", "top"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/q9/jvtr2p8s6sn6wt933mh1tyfm0000gn/T/ipykernel_10490/2683177421.py in <module>
#       1 age = hospitals_personalInfo['2. Ηλικία…']
# ----> 2 age = age[.10]
#       3
#       4 age
#       5 #age["age_group"] = pd.qcut(age, q=[0, 0.4, 0.8, 1],labels=["lowest", "middle", "top"])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 0.1

# %%
hospitals_personalInfo
# Out:
#     Τους τελευταίους 12 μήνες πόσα δυσμενή συμβάντα έχετε αναφέρει; (Αναφέρετε έναν αριθμό)  \
# 0                                                    4
# 1                                                  NaN
# 2                                                   10
# 3                                                  NaN
# 4                                                    2
# 5                                                  NaN
# 6                                                    6
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                   2
# 13                                        ΟΠΩΣΔΗΠΟΤΕ 2
# 14                                                   2
# 15                                                   3
# 16                                                 NaN
# 17                                                   3
# 18                                                  10
# 19                                              ΚΑΝΕΝΑ
# 20                                              ΚΑΝΕΝΑ
# 21                                                   1
# 22                                                   0
# 23                                                   2
# 24                                              KANENA
# 25                                                   1
# 26                                                   0
# 27                                                   3
# 28                                                   0
# 29                                                   1
# 30                                                 NaN
# 31                                                   0
# 32                                                 NaN
# 33                                        Δεν γνωριζω.
# 34                                                  50
# 35                                                   6
# 36                                                 2-3
# 37                                                 2-3
# 38                                                   2
# 39                                                   2
# 40                                               ΜΗΔΕΝ
# 41                                                   1
# 42                                                   0
# 43                                                   0
# 44                                                   0
# 45                                                 NaN
# 46                                                   5
# 47                                                   0
# 48                                                 ΕΝΑ
# 49                                              ΚΑΝΕΝΑ
# 50                                                   1
# 51                                              ΚΑΝΕΝΑ
# 52                                                   2
# 53                                                 NaN
# 54                                                   0
# 55                                                   0
# 56                                            ΔΥΟ-ΤΡΙΑ
# 57                                                   0
# 58                                                   2
# 59                                                   0
# 60                                                   0
# 61                                                   0
# 62                                                   0
# 63                                   2 πτώσεις ασθενών
# 64                                                 NaN
# 65                                                 NaN
# 66                                                  10
# 67                                                   1
# 68                                                   1
# 69                                                  10
# 70                                                   2
# 71                                              ΚΑΝΕΝΑ
# 72                                                 2-3
# 73                                                   1
# 74                                                   0
# 75                                                   2
# 76                                                   1
# 77                                              Κανενα
# 78                                                   1
# 79                                                   1
# 80                                                   1
# 81                                                   1
# 82                                                 NaN
# 83                                                   0
# 84                                                   0
# 85                                              KANENA
# 86                                                   0
# 87                                                   0
# 88                                                   1
# 89                                                   2
# 90                                                   1
# 91                                                   0
# 92                                                   0
# 93                                                   1
# 94                                                   1
# 95                                                   2
# 96                                                   6
# 97                                                 NaN
# 98                                                   1
# 99                                                   3
# 100                                                  2
# 101                                                  2
# 102                                                NaN
# 103                                                  2
# 104                                                  0
# 105                                                NaN
# 106                                                NaN
# 107                                                  2
# 108                                             Κανενα
# 109                                                  3
# 110                                              Τρία
# 111                                                  5
# 112                           Ισως 3 με 4 (οχι σοβαρα)
# 113                                                  3
# 114                                                  2
# 115                                                  3
# 116                                                NaN
# 117                                                 10
# 118                                                  3
# 119                                        Δεν απαντώ
# 120                                                  6
# 121                                                NaN
# 122                                                NaN
# 123                                             Κανενα
# 124                                                  4
# 125                                                  0
# 126                                                Ενα
# 127                                                  0
# 128                                                  0
# 129                                                  1
# 130                                                4-5
# 131                                            Κανένα
# 132                                                NaN
# 133                                                NaN
# 134                                                  6
# 135                                                NaN
# 136                                                  1
# 137                                                  0
# 138                                                NaN
# 139                                                  2
# 140                                                  0
# 141                                                  0
# 142                                                  2
# 143                                                ΟΧΙ
# 144                                                  1
# 145                                                  2
# 146                                                  0
# 147                                                  0
# 148                                                  1
# 149                                              Μηδέν
# 150                                                  2
# 151                                                  0
# 152                                                  0
# 153                                                  2
# 154                                                  0
# 155                                                  0
# 156                                                  1
# 157                                                  2
# 158                                                NaN
# 159                                                  3
# 160                                                  0
# 161                          Δεν υπάρχει καμία αλλαγή
# 162                                                  5
# 163                                                  3
# 164                                                  2
# 165                                                  0
# 166                                                  4
# 167                                                 20
# 168                                                  1
# 169                                                  5
# 170                                                  2
# 171                                                NaN
# 172                                                  3
# 173                                            Αρκετά
# 174                                                  2
# 175                                                  7
# 176                                             Κανενα
# 177                                                  0
# 178                                            Κανένα
# 179                                                  0
# 180                                                Ένα
# 181                                                  0
# 182                                                Δύο
# 183                                                NaN
# 184                                                  2
# 185                                                  0
# 186                                              ΠΕΝΤΕ
# 187                                                  3
# 188                                             Κανενα
# 189                                                  0
# 190                                                NaN
# 191                                                  1
# 192                                                  3
# 193                                               7-10
# 194                                                NaN
# 195                                                  0
# 196                                                  4
# 197                                                 40
# 198                                                  3
# 199                                                  0
# 200                                                  1
# 201                                                  2
# 202                                                 10
# 203                                             KANENA
# 204                                                  0
# 205                                             κανένα
# 206                                                  7
# 207                                                NaN
# 208                                      Απροσδιοριστο
# 209                                                  0
# 210                                                  2
# 211                                                NaN
# 212                                                  2
# 213                                                  1
# 214                                                 20
# 215                                                 10
# 216                                                  1
# 217                                                  2
# 218                                                  2
# 219                                                  1
# 220                                                NaN
# 221                                                  0
# 222                                                6.0
# 223                                                3.0
# 224                                                0.0
# 225                                                5.0
# 226                                                0.0
# 227                                                2.0
# 228                                                NaN
# 229                                                0.0
# 230                                                NaN
# 231                                                2.0
# 232                                                3.0
# 233                                                2.0
# 234                                                2.0
# 235                                                NaN
# 236                                               10.0
# 237                                                4.0
# 238                                                5.0
# 239                                                0.0
# 240                                                NaN
# 241                                                2.0
# 242                                                2.0
# 243                                                3.0
#
#     1. Φύλο:  2. Ηλικία… 3α. Ποια είναι η βασική σας εκπαίδευση;  \
# 0     Γυναίκα         23                3. Πανεπιστημιακή (Π.Ε.)
# 1     Γυναίκα         45                3. Πανεπιστημιακή (Π.Ε.)
# 2      Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 3      Άνδρας         61                3. Πανεπιστημιακή (Π.Ε.)
# 4      Άνδρας         50                   2. Τεχνολογική (Τ.Ε.)
# 5     Γυναίκα         48                3. Πανεπιστημιακή (Π.Ε.)
# 6      Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 7     Γυναίκα         39                   2. Τεχνολογική (Τ.Ε.)
# 8     Γυναίκα         40                   2. Τεχνολογική (Τ.Ε.)
# 9     Γυναίκα         55                   2. Τεχνολογική (Τ.Ε.)
# 10    Γυναίκα         56                   2. Τεχνολογική (Τ.Ε.)
# 11    Γυναίκα         38                   2. Τεχνολογική (Τ.Ε.)
# 12     Άνδρας         51                   2. Τεχνολογική (Τ.Ε.)
# 13    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 14    Γυναίκα         57                   2. Τεχνολογική (Τ.Ε.)
# 15    Γυναίκα         52                3. Πανεπιστημιακή (Π.Ε.)
# 16    Γυναίκα         44                   2. Τεχνολογική (Τ.Ε.)
# 17     Άνδρας         50                   2. Τεχνολογική (Τ.Ε.)
# 18     Άνδρας         53                   2. Τεχνολογική (Τ.Ε.)
# 19    Γυναίκα         47                   2. Τεχνολογική (Τ.Ε.)
# 20    Γυναίκα        NaN                   2. Τεχνολογική (Τ.Ε.)
# 21     Άνδρας         52                   2. Τεχνολογική (Τ.Ε.)
# 22     Άνδρας         48                   2. Τεχνολογική (Τ.Ε.)
# 23     Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 24    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 25    Γυναίκα         57                   2. Τεχνολογική (Τ.Ε.)
# 26    Γυναίκα         48                   2. Τεχνολογική (Τ.Ε.)
# 27    Γυναίκα         60                   2. Τεχνολογική (Τ.Ε.)
# 28    Γυναίκα         50                 1. Δευτεροβάθμια (Δ.Ε.)
# 29    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 30    Γυναίκα         38                3. Πανεπιστημιακή (Π.Ε.)
# 31     Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 32    Γυναίκα         39                3. Πανεπιστημιακή (Π.Ε.)
# 33    Γυναίκα         45                   2. Τεχνολογική (Τ.Ε.)
# 34    Γυναίκα         41                 1. Δευτεροβάθμια (Δ.Ε.)
# 35    Γυναίκα         37                3. Πανεπιστημιακή (Π.Ε.)
# 36    Γυναίκα         58                   2. Τεχνολογική (Τ.Ε.)
# 37    Γυναίκα         54                 1. Δευτεροβάθμια (Δ.Ε.)
# 38     Άνδρας         49                3. Πανεπιστημιακή (Π.Ε.)
# 39    Γυναίκα         52                   2. Τεχνολογική (Τ.Ε.)
# 40    Γυναίκα         62                3. Πανεπιστημιακή (Π.Ε.)
# 41    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 42    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 43    Γυναίκα         50                 1. Δευτεροβάθμια (Δ.Ε.)
# 44    Γυναίκα         39                 1. Δευτεροβάθμια (Δ.Ε.)
# 45    Γυναίκα         58                   2. Τεχνολογική (Τ.Ε.)
# 46     Άνδρας         54                   2. Τεχνολογική (Τ.Ε.)
# 47    Γυναίκα         40                   2. Τεχνολογική (Τ.Ε.)
# 48     Άνδρας         55                   2. Τεχνολογική (Τ.Ε.)
# 49    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 50    Γυναίκα         40                   2. Τεχνολογική (Τ.Ε.)
# 51    Γυναίκα         53                 1. Δευτεροβάθμια (Δ.Ε.)
# 52    Γυναίκα         57                   2. Τεχνολογική (Τ.Ε.)
# 53    Γυναίκα         53                   2. Τεχνολογική (Τ.Ε.)
# 54    Γυναίκα         36                   2. Τεχνολογική (Τ.Ε.)
# 55     Άνδρας          .                   2. Τεχνολογική (Τ.Ε.)
# 56    Γυναίκα        NaN                                     NaN
# 57    Γυναίκα         58                   2. Τεχνολογική (Τ.Ε.)
# 58    Γυναίκα         38                3. Πανεπιστημιακή (Π.Ε.)
# 59    Γυναίκα         55                   2. Τεχνολογική (Τ.Ε.)
# 60    Γυναίκα         48                   2. Τεχνολογική (Τ.Ε.)
# 61    Γυναίκα         47                 1. Δευτεροβάθμια (Δ.Ε.)
# 62    Γυναίκα         59                   2. Τεχνολογική (Τ.Ε.)
# 63    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 64    Γυναίκα         60                   2. Τεχνολογική (Τ.Ε.)
# 65        NaN        NaN                                     NaN
# 66    Γυναίκα         54                   2. Τεχνολογική (Τ.Ε.)
# 67    Γυναίκα         42                   2. Τεχνολογική (Τ.Ε.)
# 68    Γυναίκα         41                   2. Τεχνολογική (Τ.Ε.)
# 69    Γυναίκα         26                   2. Τεχνολογική (Τ.Ε.)
# 70     Άνδρας         40                 1. Δευτεροβάθμια (Δ.Ε.)
# 71    Γυναίκα         57                   2. Τεχνολογική (Τ.Ε.)
# 72    Γυναίκα         55                   2. Τεχνολογική (Τ.Ε.)
# 73    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 74    Γυναίκα         31                   2. Τεχνολογική (Τ.Ε.)
# 75    Γυναίκα         56                   2. Τεχνολογική (Τ.Ε.)
# 76     Άνδρας         36                   2. Τεχνολογική (Τ.Ε.)
# 77    Γυναίκα         46                   2. Τεχνολογική (Τ.Ε.)
# 78     Άνδρας         39                   2. Τεχνολογική (Τ.Ε.)
# 79    Γυναίκα         35                   2. Τεχνολογική (Τ.Ε.)
# 80    Γυναίκα         31                   2. Τεχνολογική (Τ.Ε.)
# 81    Γυναίκα         48                   2. Τεχνολογική (Τ.Ε.)
# 82        NaN        NaN                                     NaN
# 83    Γυναίκα      25-35                   2. Τεχνολογική (Τ.Ε.)
# 84    Γυναίκα         28                   2. Τεχνολογική (Τ.Ε.)
# 85    Γυναίκα         45                   2. Τεχνολογική (Τ.Ε.)
# 86    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 87    Γυναίκα         52                   2. Τεχνολογική (Τ.Ε.)
# 88    Γυναίκα         59                   2. Τεχνολογική (Τ.Ε.)
# 89    Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 90    Γυναίκα         59                   2. Τεχνολογική (Τ.Ε.)
# 91    Γυναίκα         38                   2. Τεχνολογική (Τ.Ε.)
# 92        NaN         45                                     NaN
# 93    Γυναίκα         55                   2. Τεχνολογική (Τ.Ε.)
# 94    Γυναίκα         32                3. Πανεπιστημιακή (Π.Ε.)
# 95    Γυναίκα         33                3. Πανεπιστημιακή (Π.Ε.)
# 96    Γυναίκα         46                3. Πανεπιστημιακή (Π.Ε.)
# 97    Γυναίκα         42                3. Πανεπιστημιακή (Π.Ε.)
# 98    Γυναίκα         45                3. Πανεπιστημιακή (Π.Ε.)
# 99    Γυναίκα         35                3. Πανεπιστημιακή (Π.Ε.)
# 100   Γυναίκα       45.0                   2. Τεχνολογική (Τ.Ε.)
# 101   Γυναίκα       45.0                3. Πανεπιστημιακή (Π.Ε.)
# 102   Γυναίκα       54.0                   2. Τεχνολογική (Τ.Ε.)
# 103   Γυναίκα       38.0                   2. Τεχνολογική (Τ.Ε.)
# 104   Γυναίκα       47.0                   2. Τεχνολογική (Τ.Ε.)
# 105   Γυναίκα       48.0                   2. Τεχνολογική (Τ.Ε.)
# 106    Άνδρας       47.0                   2. Τεχνολογική (Τ.Ε.)
# 107   Γυναίκα       49.0                   2. Τεχνολογική (Τ.Ε.)
# 108   Γυναίκα       49.0                   2. Τεχνολογική (Τ.Ε.)
# 109    Άνδρας       54.0                   2. Τεχνολογική (Τ.Ε.)
# 110    Άνδρας       50.0                   2. Τεχνολογική (Τ.Ε.)
# 111    Άνδρας       48.0                3. Πανεπιστημιακή (Π.Ε.)
# 112   Γυναίκα       39.0                   2. Τεχνολογική (Τ.Ε.)
# 113   Γυναίκα       40.0                   2. Τεχνολογική (Τ.Ε.)
# 114   Γυναίκα       30.0                   2. Τεχνολογική (Τ.Ε.)
# 115   Γυναίκα       50.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 116   Γυναίκα       51.0                   2. Τεχνολογική (Τ.Ε.)
# 117   Γυναίκα       45.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 118   Γυναίκα       47.0                   2. Τεχνολογική (Τ.Ε.)
# 119   Γυναίκα        NaN                   2. Τεχνολογική (Τ.Ε.)
# 120       NaN        NaN                                     NaN
# 121   Γυναίκα       43.0                   2. Τεχνολογική (Τ.Ε.)
# 122   Γυναίκα       39.0                   2. Τεχνολογική (Τ.Ε.)
# 123   Γυναίκα       53.0                   2. Τεχνολογική (Τ.Ε.)
# 124   Γυναίκα       53.0                3. Πανεπιστημιακή (Π.Ε.)
# 125   Γυναίκα       55.0                   2. Τεχνολογική (Τ.Ε.)
# 126    Άνδρας       61.0                   2. Τεχνολογική (Τ.Ε.)
# 127   Γυναίκα       54.0                   2. Τεχνολογική (Τ.Ε.)
# 128    Άνδρας       55.0                   2. Τεχνολογική (Τ.Ε.)
# 129    Άνδρας       51.0                   2. Τεχνολογική (Τ.Ε.)
# 130    Άνδρας       48.0                   2. Τεχνολογική (Τ.Ε.)
# 131    Άνδρας       56.0                   2. Τεχνολογική (Τ.Ε.)
# 132    Άνδρας        NaN                   2. Τεχνολογική (Τ.Ε.)
# 133   Γυναίκα       56.0                                     NaN
# 134    Άνδρας       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 135   Γυναίκα       65.0                3. Πανεπιστημιακή (Π.Ε.)
# 136    Άνδρας       29.0                3. Πανεπιστημιακή (Π.Ε.)
# 137    Άνδρας       32.0                3. Πανεπιστημιακή (Π.Ε.)
# 138    Άνδρας        NaN                                     NaN
# 139   Γυναίκα       28.0                3. Πανεπιστημιακή (Π.Ε.)
# 140   Γυναίκα       29.0                3. Πανεπιστημιακή (Π.Ε.)
# 141    Άνδρας       34.0                3. Πανεπιστημιακή (Π.Ε.)
# 142   Γυναίκα       35.0                3. Πανεπιστημιακή (Π.Ε.)
# 143    Άνδρας       45.0                3. Πανεπιστημιακή (Π.Ε.)
# 144   Γυναίκα       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 145    Άνδρας       31.0                3. Πανεπιστημιακή (Π.Ε.)
# 146   Γυναίκα       38.0                3. Πανεπιστημιακή (Π.Ε.)
# 147   Γυναίκα       28.0                3. Πανεπιστημιακή (Π.Ε.)
# 148   Γυναίκα       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 149    Άνδρας       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 150   Γυναίκα       45.0                3. Πανεπιστημιακή (Π.Ε.)
# 151   Γυναίκα       48.0                   2. Τεχνολογική (Τ.Ε.)
# 152   Γυναίκα       40.0                3. Πανεπιστημιακή (Π.Ε.)
# 153    Άνδρας       42.0                3. Πανεπιστημιακή (Π.Ε.)
# 154   Γυναίκα       37.0                3. Πανεπιστημιακή (Π.Ε.)
# 155   Γυναίκα       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 156    Άνδρας       55.0                3. Πανεπιστημιακή (Π.Ε.)
# 157    Άνδρας       64.0                3. Πανεπιστημιακή (Π.Ε.)
# 158    Άνδρας       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 159   Γυναίκα       58.0                3. Πανεπιστημιακή (Π.Ε.)
# 160    Άνδρας       33.0                3. Πανεπιστημιακή (Π.Ε.)
# 161   Γυναίκα       43.0                3. Πανεπιστημιακή (Π.Ε.)
# 162    Άνδρας       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 163   Γυναίκα       57.0                3. Πανεπιστημιακή (Π.Ε.)
# 164    Άνδρας       30.0                3. Πανεπιστημιακή (Π.Ε.)
# 165   Γυναίκα       60.0                3. Πανεπιστημιακή (Π.Ε.)
# 166    Άνδρας       51.0                3. Πανεπιστημιακή (Π.Ε.)
# 167   Γυναίκα       30.0                   2. Τεχνολογική (Τ.Ε.)
# 168   Γυναίκα       46.0                   2. Τεχνολογική (Τ.Ε.)
# 169   Γυναίκα       38.0                   2. Τεχνολογική (Τ.Ε.)
# 170   Γυναίκα       49.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 171   Γυναίκα       39.0                   2. Τεχνολογική (Τ.Ε.)
# 172   Γυναίκα       49.0                   2. Τεχνολογική (Τ.Ε.)
# 173   Γυναίκα       55.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 174   Γυναίκα       44.0                   2. Τεχνολογική (Τ.Ε.)
# 175   Γυναίκα       36.0                   2. Τεχνολογική (Τ.Ε.)
# 176   Γυναίκα       51.0                   2. Τεχνολογική (Τ.Ε.)
# 177   Γυναίκα       50.0                   2. Τεχνολογική (Τ.Ε.)
# 178    Άνδρας       52.0                   2. Τεχνολογική (Τ.Ε.)
# 179   Γυναίκα       50.0                   2. Τεχνολογική (Τ.Ε.)
# 180   Γυναίκα       47.0                   2. Τεχνολογική (Τ.Ε.)
# 181   Γυναίκα       28.0                3. Πανεπιστημιακή (Π.Ε.)
# 182   Γυναίκα       47.0                   2. Τεχνολογική (Τ.Ε.)
# 183   Γυναίκα       42.0                   2. Τεχνολογική (Τ.Ε.)
# 184   Γυναίκα       48.0                   2. Τεχνολογική (Τ.Ε.)
# 185   Γυναίκα       33.0                3. Πανεπιστημιακή (Π.Ε.)
# 186   Γυναίκα       56.0                   2. Τεχνολογική (Τ.Ε.)
# 187    Άνδρας       64.0                3. Πανεπιστημιακή (Π.Ε.)
# 188   Γυναίκα       51.0                   2. Τεχνολογική (Τ.Ε.)
# 189   Γυναίκα       60.0                3. Πανεπιστημιακή (Π.Ε.)
# 190   Γυναίκα       50.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 191   Γυναίκα       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 192    Άνδρας       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 193   Γυναίκα       41.0                   2. Τεχνολογική (Τ.Ε.)
# 194   Γυναίκα       37.0                   2. Τεχνολογική (Τ.Ε.)
# 195   Γυναίκα       44.0                3. Πανεπιστημιακή (Π.Ε.)
# 196   Γυναίκα       34.0                3. Πανεπιστημιακή (Π.Ε.)
# 197   Γυναίκα       40.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 198    Άνδρας       61.0                3. Πανεπιστημιακή (Π.Ε.)
# 199    Άνδρας       56.0                   2. Τεχνολογική (Τ.Ε.)
# 200    Άνδρας       57.0                3. Πανεπιστημιακή (Π.Ε.)
# 201    Άνδρας       57.0                   2. Τεχνολογική (Τ.Ε.)
# 202    Άνδρας       60.0                   2. Τεχνολογική (Τ.Ε.)
# 203    Άνδρας       54.0                   2. Τεχνολογική (Τ.Ε.)
# 204    Άνδρας       59.0                3. Πανεπιστημιακή (Π.Ε.)
# 205   Γυναίκα       57.0                   2. Τεχνολογική (Τ.Ε.)
# 206    Άνδρας       28.0                3. Πανεπιστημιακή (Π.Ε.)
# 207   Γυναίκα       60.0                   2. Τεχνολογική (Τ.Ε.)
# 208    Άνδρας       37.0                3. Πανεπιστημιακή (Π.Ε.)
# 209   Γυναίκα       49.0                3. Πανεπιστημιακή (Π.Ε.)
# 210   Γυναίκα       52.0                   2. Τεχνολογική (Τ.Ε.)
# 211    Άνδρας        NaN                3. Πανεπιστημιακή (Π.Ε.)
# 212    Άνδρας       48.0                3. Πανεπιστημιακή (Π.Ε.)
# 213   Γυναίκα       56.0                3. Πανεπιστημιακή (Π.Ε.)
# 214   Γυναίκα       52.0                   2. Τεχνολογική (Τ.Ε.)
# 215    Άνδρας       30.0                   2. Τεχνολογική (Τ.Ε.)
# 216   Γυναίκα       48.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 217   Γυναίκα       55.0                   2. Τεχνολογική (Τ.Ε.)
# 218    Άνδρας       41.0                   2. Τεχνολογική (Τ.Ε.)
# 219   Γυναίκα       50.0                3. Πανεπιστημιακή (Π.Ε.)
# 220   Γυναίκα       36.0                3. Πανεπιστημιακή (Π.Ε.)
# 221   Γυναίκα       41.0                   2. Τεχνολογική (Τ.Ε.)
# 222   Γυναίκα         23                   2. Τεχνολογική (Τ.Ε.)
# 223   Γυναίκα         50                   2. Τεχνολογική (Τ.Ε.)
# 224    Άνδρας         59                3. Πανεπιστημιακή (Π.Ε.)
# 225   Γυναίκα         29                3. Πανεπιστημιακή (Π.Ε.)
# 226    Άνδρας         52                3. Πανεπιστημιακή (Π.Ε.)
# 227   Γυναίκα         37                3. Πανεπιστημιακή (Π.Ε.)
# 228   Γυναίκα         45                3. Πανεπιστημιακή (Π.Ε.)
# 229    Άνδρας         55                3. Πανεπιστημιακή (Π.Ε.)
# 230    Άνδρας         52                3. Πανεπιστημιακή (Π.Ε.)
# 231   Γυναίκα         56                   2. Τεχνολογική (Τ.Ε.)
# 232   Γυναίκα         40                   2. Τεχνολογική (Τ.Ε.)
# 233   Γυναίκα         43                   2. Τεχνολογική (Τ.Ε.)
# 234    Άνδρας         58                3. Πανεπιστημιακή (Π.Ε.)
# 235    Άνδρας         34                3. Πανεπιστημιακή (Π.Ε.)
# 236    Άνδρας         41                3. Πανεπιστημιακή (Π.Ε.)
# 237   Γυναίκα         53                   2. Τεχνολογική (Τ.Ε.)
# 238    Άνδρας         58                   2. Τεχνολογική (Τ.Ε.)
# 239   Γυναίκα         47                   2. Τεχνολογική (Τ.Ε.)
# 240    Άνδρας         56                   2. Τεχνολογική (Τ.Ε.)
# 241    Άνδρας         40                3. Πανεπιστημιακή (Π.Ε.)
# 242   Γυναίκα         45                3. Πανεπιστημιακή (Π.Ε.)
# 243    Άνδρας         65                3. Πανεπιστημιακή (Π.Ε.)
#
#            3β. Άλλες σπουδές:  \
# 0      3. Διδακτορικό δίπλωμα
# 1    2. Μεταπτυχιακές σπουδές
# 2      3. Διδακτορικό δίπλωμα
# 3      3. Διδακτορικό δίπλωμα
# 4    2. Μεταπτυχιακές σπουδές
# 5    2. Μεταπτυχιακές σπουδές
# 6      3. Διδακτορικό δίπλωμα
# 7    2. Μεταπτυχιακές σπουδές
# 8    2. Μεταπτυχιακές σπουδές
# 9    2. Μεταπτυχιακές σπουδές
# 10              1. Ειδικότητα
# 11   2. Μεταπτυχιακές σπουδές
# 12   2. Μεταπτυχιακές σπουδές
# 13   2. Μεταπτυχιακές σπουδές
# 14   2. Μεταπτυχιακές σπουδές
# 15              1. Ειδικότητα
# 16              1. Ειδικότητα
# 17   2. Μεταπτυχιακές σπουδές
# 18     3. Διδακτορικό δίπλωμα
# 19                        NaN
# 20              1. Ειδικότητα
# 21     3. Διδακτορικό δίπλωμα
# 22   2. Μεταπτυχιακές σπουδές
# 23   2. Μεταπτυχιακές σπουδές
# 24              1. Ειδικότητα
# 25              1. Ειδικότητα
# 26              1. Ειδικότητα
# 27   2. Μεταπτυχιακές σπουδές
# 28                        NaN
# 29   2. Μεταπτυχιακές σπουδές
# 30     3. Διδακτορικό δίπλωμα
# 31                        NaN
# 32     3. Διδακτορικό δίπλωμα
# 33   2. Μεταπτυχιακές σπουδές
# 34                        NaN
# 35     3. Διδακτορικό δίπλωμα
# 36              1. Ειδικότητα
# 37                        NaN
# 38     3. Διδακτορικό δίπλωμα
# 39   2. Μεταπτυχιακές σπουδές
# 40   2. Μεταπτυχιακές σπουδές
# 41   2. Μεταπτυχιακές σπουδές
# 42   2. Μεταπτυχιακές σπουδές
# 43                        NaN
# 44                        NaN
# 45   2. Μεταπτυχιακές σπουδές
# 46   2. Μεταπτυχιακές σπουδές
# 47   2. Μεταπτυχιακές σπουδές
# 48              1. Ειδικότητα
# 49   2. Μεταπτυχιακές σπουδές
# 50                        NaN
# 51                        NaN
# 52              1. Ειδικότητα
# 53   2. Μεταπτυχιακές σπουδές
# 54   2. Μεταπτυχιακές σπουδές
# 55   2. Μεταπτυχιακές σπουδές
# 56                        NaN
# 57   2. Μεταπτυχιακές σπουδές
# 58   2. Μεταπτυχιακές σπουδές
# 59   2. Μεταπτυχιακές σπουδές
# 60   2. Μεταπτυχιακές σπουδές
# 61                        NaN
# 62              1. Ειδικότητα
# 63              1. Ειδικότητα
# 64              1. Ειδικότητα
# 65                        NaN
# 66   2. Μεταπτυχιακές σπουδές
# 67   2. Μεταπτυχιακές σπουδές
# 68   2. Μεταπτυχιακές σπουδές
# 69                        NaN
# 70                        NaN
# 71              1. Ειδικότητα
# 72              1. Ειδικότητα
# 73              1. Ειδικότητα
# 74   2. Μεταπτυχιακές σπουδές
# 75              1. Ειδικότητα
# 76   2. Μεταπτυχιακές σπουδές
# 77              1. Ειδικότητα
# 78     3. Διδακτορικό δίπλωμα
# 79   2. Μεταπτυχιακές σπουδές
# 80   2. Μεταπτυχιακές σπουδές
# 81   2. Μεταπτυχιακές σπουδές
# 82                        NaN
# 83                        NaN
# 84   2. Μεταπτυχιακές σπουδές
# 85              1. Ειδικότητα
# 86                        NaN
# 87                        NaN
# 88              1. Ειδικότητα
# 89              1. Ειδικότητα
# 90              1. Ειδικότητα
# 91                        NaN
# 92                        NaN
# 93              1. Ειδικότητα
# 94   2. Μεταπτυχιακές σπουδές
# 95     3. Διδακτορικό δίπλωμα
# 96              1. Ειδικότητα
# 97   2. Μεταπτυχιακές σπουδές
# 98     3. Διδακτορικό δίπλωμα
# 99   2. Μεταπτυχιακές σπουδές
# 100  2. Μεταπτυχιακές σπουδές
# 101  2. Μεταπτυχιακές σπουδές
# 102                       NaN
# 103  2. Μεταπτυχιακές σπουδές
# 104  2. Μεταπτυχιακές σπουδές
# 105  2. Μεταπτυχιακές σπουδές
# 106                       NaN
# 107  2. Μεταπτυχιακές σπουδές
# 108             1. Ειδικότητα
# 109                       NaN
# 110             1. Ειδικότητα
# 111    3. Διδακτορικό δίπλωμα
# 112                       NaN
# 113  2. Μεταπτυχιακές σπουδές
# 114  2. Μεταπτυχιακές σπουδές
# 115                       NaN
# 116             1. Ειδικότητα
# 117                       NaN
# 118                       NaN
# 119                       NaN
# 120                       NaN
# 121  2. Μεταπτυχιακές σπουδές
# 122             1. Ειδικότητα
# 123                       NaN
# 124  2. Μεταπτυχιακές σπουδές
# 125             1. Ειδικότητα
# 126             1. Ειδικότητα
# 127  2. Μεταπτυχιακές σπουδές
# 128                       NaN
# 129  2. Μεταπτυχιακές σπουδές
# 130             1. Ειδικότητα
# 131                       NaN
# 132  2. Μεταπτυχιακές σπουδές
# 133                       NaN
# 134  2. Μεταπτυχιακές σπουδές
# 135             1. Ειδικότητα
# 136    3. Διδακτορικό δίπλωμα
# 137  2. Μεταπτυχιακές σπουδές
# 138  2. Μεταπτυχιακές σπουδές
# 139             1. Ειδικότητα
# 140  2. Μεταπτυχιακές σπουδές
# 141  2. Μεταπτυχιακές σπουδές
# 142  2. Μεταπτυχιακές σπουδές
# 143                       NaN
# 144             1. Ειδικότητα
# 145             1. Ειδικότητα
# 146             1. Ειδικότητα
# 147             1. Ειδικότητα
# 148             1. Ειδικότητα
# 149  2. Μεταπτυχιακές σπουδές
# 150  2. Μεταπτυχιακές σπουδές
# 151  2. Μεταπτυχιακές σπουδές
# 152             1. Ειδικότητα
# 153  2. Μεταπτυχιακές σπουδές
# 154  2. Μεταπτυχιακές σπουδές
# 155  2. Μεταπτυχιακές σπουδές
# 156    3. Διδακτορικό δίπλωμα
# 157    3. Διδακτορικό δίπλωμα
# 158    3. Διδακτορικό δίπλωμα
# 159    3. Διδακτορικό δίπλωμα
# 160             1. Ειδικότητα
# 161             1. Ειδικότητα
# 162             1. Ειδικότητα
# 163             1. Ειδικότητα
# 164             1. Ειδικότητα
# 165  2. Μεταπτυχιακές σπουδές
# 166    3. Διδακτορικό δίπλωμα
# 167  2. Μεταπτυχιακές σπουδές
# 168  2. Μεταπτυχιακές σπουδές
# 169                       NaN
# 170                       NaN
# 171  2. Μεταπτυχιακές σπουδές
# 172  2. Μεταπτυχιακές σπουδές
# 173                       NaN
# 174  2. Μεταπτυχιακές σπουδές
# 175                       NaN
# 176  2. Μεταπτυχιακές σπουδές
# 177  2. Μεταπτυχιακές σπουδές
# 178                       NaN
# 179             1. Ειδικότητα
# 180    3. Διδακτορικό δίπλωμα
# 181             1. Ειδικότητα
# 182                       NaN
# 183  2. Μεταπτυχιακές σπουδές
# 184                       NaN
# 185             1. Ειδικότητα
# 186  2. Μεταπτυχιακές σπουδές
# 187    3. Διδακτορικό δίπλωμα
# 188             1. Ειδικότητα
# 189    3. Διδακτορικό δίπλωμα
# 190                       NaN
# 191    3. Διδακτορικό δίπλωμα
# 192  2. Μεταπτυχιακές σπουδές
# 193             1. Ειδικότητα
# 194                       NaN
# 195  2. Μεταπτυχιακές σπουδές
# 196  2. Μεταπτυχιακές σπουδές
# 197             1. Ειδικότητα
# 198    3. Διδακτορικό δίπλωμα
# 199    3. Διδακτορικό δίπλωμα
# 200    3. Διδακτορικό δίπλωμα
# 201  2. Μεταπτυχιακές σπουδές
# 202             1. Ειδικότητα
# 203  2. Μεταπτυχιακές σπουδές
# 204    3. Διδακτορικό δίπλωμα
# 205  2. Μεταπτυχιακές σπουδές
# 206  2. Μεταπτυχιακές σπουδές
# 207             1. Ειδικότητα
# 208             1. Ειδικότητα
# 209  2. Μεταπτυχιακές σπουδές
# 210                       NaN
# 211                       NaN
# 212             1. Ειδικότητα
# 213             1. Ειδικότητα
# 214  2. Μεταπτυχιακές σπουδές
# 215  2. Μεταπτυχιακές σπουδές
# 216                       NaN
# 217                       NaN
# 218    3. Διδακτορικό δίπλωμα
# 219  2. Μεταπτυχιακές σπουδές
# 220  2. Μεταπτυχιακές σπουδές
# 221  2. Μεταπτυχιακές σπουδές
# 222  2. Μεταπτυχιακές σπουδές
# 223  2. Μεταπτυχιακές σπουδές
# 224    3. Διδακτορικό δίπλωμα
# 225  2. Μεταπτυχιακές σπουδές
# 226             1. Ειδικότητα
# 227  2. Μεταπτυχιακές σπουδές
# 228    3. Διδακτορικό δίπλωμα
# 229    3. Διδακτορικό δίπλωμα
# 230             1. Ειδικότητα
# 231  2. Μεταπτυχιακές σπουδές
# 232                       NaN
# 233                       NaN
# 234  2. Μεταπτυχιακές σπουδές
# 235    3. Διδακτορικό δίπλωμα
# 236  2. Μεταπτυχιακές σπουδές
# 237                       NaN
# 238  2. Μεταπτυχιακές σπουδές
# 239  2. Μεταπτυχιακές σπουδές
# 240                       NaN
# 241  2. Μεταπτυχιακές σπουδές
# 242  2. Μεταπτυχιακές σπουδές
# ...
# 220                                                 40
# 221                                                 40
# 222                                                 34
# 223                                                 50
# 224                                                 50
# 225                                            45 ώρες
# 226                                                 56
# 227                                              70-80
# 228                                                NaN
# 229                                                 35
# 230                                              4 ΕΤΗ
# 231                                                50
# 232                                              40-45
# 233                                              40-45
# 234                                                 40
# 235                                                 50
# 236                                                 40
# 237                                                 40
# 238                                                 45
# 239                                                 40
# 240                                                 40
# 241                                                 58
# 242                                                 42
# 243                                                 50
#
#     10. Τι θέση κατέχετε στο νοσοκομείο που εργάζεστε;
# 0                                     4. ΤΕ Νοσηλευτής
# 1                                     4. ΤΕ Νοσηλευτής
# 2                                     4. ΤΕ Νοσηλευτής
# 3                                                  NaN
# 4                                     4. ΤΕ Νοσηλευτής
# 5                                    2. Ειδικός ιατρός
# 6                                     4. ΤΕ Νοσηλευτής
# 7                                     4. ΤΕ Νοσηλευτής
# 8                                     4. ΤΕ Νοσηλευτής
# 9                                     4. ΤΕ Νοσηλευτής
# 10                                    4. ΤΕ Νοσηλευτής
# 11                                    4. ΤΕ Νοσηλευτής
# 12                                    4. ΤΕ Νοσηλευτής
# 13                                    4. ΤΕ Νοσηλευτής
# 14                                    4. ΤΕ Νοσηλευτής
# 15                                    3. ΠΕ Νοσηλευτής
# 16                                    4. ΤΕ Νοσηλευτής
# 17                                    4. ΤΕ Νοσηλευτής
# 18                                    4. ΤΕ Νοσηλευτής
# 19                                    4. ΤΕ Νοσηλευτής
# 20                                    4. ΤΕ Νοσηλευτής
# 21                                    4. ΤΕ Νοσηλευτής
# 22                                    4. ΤΕ Νοσηλευτής
# 23                                    4. ΤΕ Νοσηλευτής
# 24                                    4. ΤΕ Νοσηλευτής
# 25                                    4. ΤΕ Νοσηλευτής
# 26                                    4. ΤΕ Νοσηλευτής
# 27                                    4. ΤΕ Νοσηλευτής
# 28                              5. ΔΕ Βοηθός Νοσηλευτή
# 29                                    4. ΤΕ Νοσηλευτής
# 30                                    3. ΠΕ Νοσηλευτής
# 31                                    4. ΤΕ Νοσηλευτής
# 32                                    3. ΠΕ Νοσηλευτής
# 33                              5. ΔΕ Βοηθός Νοσηλευτή
# 34                              5. ΔΕ Βοηθός Νοσηλευτή
# 35                                    3. ΠΕ Νοσηλευτής
# 36                                    4. ΤΕ Νοσηλευτής
# 37                              5. ΔΕ Βοηθός Νοσηλευτή
# 38                                   2. Ειδικός ιατρός
# 39                                    4. ΤΕ Νοσηλευτής
# 40                                    3. ΠΕ Νοσηλευτής
# 41                                    4. ΤΕ Νοσηλευτής
# 42                                    3. ΠΕ Νοσηλευτής
# 43                              5. ΔΕ Βοηθός Νοσηλευτή
# 44                              5. ΔΕ Βοηθός Νοσηλευτή
# 45                                    4. ΤΕ Νοσηλευτής
# 46                                    4. ΤΕ Νοσηλευτής
# 47                                    4. ΤΕ Νοσηλευτής
# 48                                    4. ΤΕ Νοσηλευτής
# 49                                    4. ΤΕ Νοσηλευτής
# 50                                    4. ΤΕ Νοσηλευτής
# 51                              5. ΔΕ Βοηθός Νοσηλευτή
# 52                                    4. ΤΕ Νοσηλευτής
# 53                                    4. ΤΕ Νοσηλευτής
# 54                                    4. ΤΕ Νοσηλευτής
# 55                                    3. ΠΕ Νοσηλευτής
# 56                                                 NaN
# 57                                    4. ΤΕ Νοσηλευτής
# 58                                    3. ΠΕ Νοσηλευτής
# 59                                    4. ΤΕ Νοσηλευτής
# 60                                    4. ΤΕ Νοσηλευτής
# 61                              5. ΔΕ Βοηθός Νοσηλευτή
# 62                                    4. ΤΕ Νοσηλευτής
# 63                                    4. ΤΕ Νοσηλευτής
# 64                                    4. ΤΕ Νοσηλευτής
# 65                                                 NaN
# 66                                    4. ΤΕ Νοσηλευτής
# 67                                    4. ΤΕ Νοσηλευτής
# 68                                    4. ΤΕ Νοσηλευτής
# 69                                    4. ΤΕ Νοσηλευτής
# 70                              5. ΔΕ Βοηθός Νοσηλευτή
# 71                                    4. ΤΕ Νοσηλευτής
# 72                                    4. ΤΕ Νοσηλευτής
# 73                                    4. ΤΕ Νοσηλευτής
# 74                                    4. ΤΕ Νοσηλευτής
# 75                                    4. ΤΕ Νοσηλευτής
# 76                                    4. ΤΕ Νοσηλευτής
# 77                                    4. ΤΕ Νοσηλευτής
# 78                                    4. ΤΕ Νοσηλευτής
# 79                                    4. ΤΕ Νοσηλευτής
# 80                                    4. ΤΕ Νοσηλευτής
# 81                                    4. ΤΕ Νοσηλευτής
# 82                                                 NaN
# 83                                    4. ΤΕ Νοσηλευτής
# 84                                    4. ΤΕ Νοσηλευτής
# 85                                    4. ΤΕ Νοσηλευτής
# 86                                    4. ΤΕ Νοσηλευτής
# 87                                    4. ΤΕ Νοσηλευτής
# 88                                    4. ΤΕ Νοσηλευτής
# 89                                    4. ΤΕ Νοσηλευτής
# 90                                    4. ΤΕ Νοσηλευτής
# 91                                    4. ΤΕ Νοσηλευτής
# 92                                                 NaN
# 93                                    4. ΤΕ Νοσηλευτής
# 94                                   2. Ειδικός ιατρός
# 95                                   2. Ειδικός ιατρός
# 96                                   2. Ειδικός ιατρός
# 97                             1. Ειδικευόμενος ιατρός
# 98                                   2. Ειδικός ιατρός
# 99                                   2. Ειδικός ιατρός
# 100                                   4. ΤΕ Νοσηλευτής
# 101                                   3. ΠΕ Νοσηλευτής
# 102                                   4. ΤΕ Νοσηλευτής
# 103                                   4. ΤΕ Νοσηλευτής
# 104                                   4. ΤΕ Νοσηλευτής
# 105                                   4. ΤΕ Νοσηλευτής
# 106                                   4. ΤΕ Νοσηλευτής
# 107                                   4. ΤΕ Νοσηλευτής
# 108                                   4. ΤΕ Νοσηλευτής
# 109                                   4. ΤΕ Νοσηλευτής
# 110                                   4. ΤΕ Νοσηλευτής
# 111                                  2. Ειδικός ιατρός
# 112                                   4. ΤΕ Νοσηλευτής
# 113                                   4. ΤΕ Νοσηλευτής
# 114                                   4. ΤΕ Νοσηλευτής
# 115                             5. ΔΕ Βοηθός Νοσηλευτή
# 116                                   4. ΤΕ Νοσηλευτής
# 117                             5. ΔΕ Βοηθός Νοσηλευτή
# 118                                   4. ΤΕ Νοσηλευτής
# 119                                   4. ΤΕ Νοσηλευτής
# 120                                                NaN
# 121                                   4. ΤΕ Νοσηλευτής
# 122                                                NaN
# 123                                   4. ΤΕ Νοσηλευτής
# 124                                   3. ΠΕ Νοσηλευτής
# 125                                   4. ΤΕ Νοσηλευτής
# 126                                   4. ΤΕ Νοσηλευτής
# 127                                   4. ΤΕ Νοσηλευτής
# 128                                   4. ΤΕ Νοσηλευτής
# 129                                   4. ΤΕ Νοσηλευτής
# 130                                   4. ΤΕ Νοσηλευτής
# 131                                   4. ΤΕ Νοσηλευτής
# 132                                   4. ΤΕ Νοσηλευτής
# 133                             5. ΔΕ Βοηθός Νοσηλευτή
# 134                            1. Ειδικευόμενος ιατρός
# 135                            1. Ειδικευόμενος ιατρός
# 136                            1. Ειδικευόμενος ιατρός
# 137                            1. Ειδικευόμενος ιατρός
# 138                            1. Ειδικευόμενος ιατρός
# 139                            1. Ειδικευόμενος ιατρός
# 140                            1. Ειδικευόμενος ιατρός
# 141                            1. Ειδικευόμενος ιατρός
# 142                            1. Ειδικευόμενος ιατρός
# 143                                  2. Ειδικός ιατρός
# 144                            1. Ειδικευόμενος ιατρός
# 145                            1. Ειδικευόμενος ιατρός
# 146                            1. Ειδικευόμενος ιατρός
# 147                            1. Ειδικευόμενος ιατρός
# 148                            1. Ειδικευόμενος ιατρός
# 149                            1. Ειδικευόμενος ιατρός
# 150                                  2. Ειδικός ιατρός
# 151                                   4. ΤΕ Νοσηλευτής
# 152                            1. Ειδικευόμενος ιατρός
# 153                            1. Ειδικευόμενος ιατρός
# 154                                  2. Ειδικός ιατρός
# 155                            1. Ειδικευόμενος ιατρός
# 156                            1. Ειδικευόμενος ιατρός
# 157                                  2. Ειδικός ιατρός
# 158                                  2. Ειδικός ιατρός
# 159                                  2. Ειδικός ιατρός
# 160                            1. Ειδικευόμενος ιατρός
# 161                            1. Ειδικευόμενος ιατρός
# 162                            1. Ειδικευόμενος ιατρός
# 163                                  2. Ειδικός ιατρός
# 164                            1. Ειδικευόμενος ιατρός
# 165                                  2. Ειδικός ιατρός
# 166                                  2. Ειδικός ιατρός
# 167                                   4. ΤΕ Νοσηλευτής
# 168                                   4. ΤΕ Νοσηλευτής
# 169                                   4. ΤΕ Νοσηλευτής
# 170                             5. ΔΕ Βοηθός Νοσηλευτή
# 171                                   4. ΤΕ Νοσηλευτής
# 172                                   4. ΤΕ Νοσηλευτής
# 173                             5. ΔΕ Βοηθός Νοσηλευτή
# 174                                   4. ΤΕ Νοσηλευτής
# 175                                   4. ΤΕ Νοσηλευτής
# 176                                   4. ΤΕ Νοσηλευτής
# 177                                   4. ΤΕ Νοσηλευτής
# 178                                   4. ΤΕ Νοσηλευτής
# 179                                   4. ΤΕ Νοσηλευτής
# 180                                   4. ΤΕ Νοσηλευτής
# 181                                   3. ΠΕ Νοσηλευτής
# 182                                   4. ΤΕ Νοσηλευτής
# 183                                   4. ΤΕ Νοσηλευτής
# 184                                   4. ΤΕ Νοσηλευτής
# 185                            1. Ειδικευόμενος ιατρός
# 186                                                NaN
# 187                                  2. Ειδικός ιατρός
# 188                                   4. ΤΕ Νοσηλευτής
# 189                                  2. Ειδικός ιατρός
# 190                             5. ΔΕ Βοηθός Νοσηλευτή
# 191                                  2. Ειδικός ιατρός
# 192                                  2. Ειδικός ιατρός
# 193                                   4. ΤΕ Νοσηλευτής
# 194                                   4. ΤΕ Νοσηλευτής
# 195                                  2. Ειδικός ιατρός
# 196                                   3. ΠΕ Νοσηλευτής
# 197                             5. ΔΕ Βοηθός Νοσηλευτή
# 198                                  2. Ειδικός ιατρός
# 199                                   4. ΤΕ Νοσηλευτής
# 200                                  2. Ειδικός ιατρός
# 201                                   4. ΤΕ Νοσηλευτής
# 202                                   4. ΤΕ Νοσηλευτής
# 203                                   4. ΤΕ Νοσηλευτής
# 204                                  2. Ειδικός ιατρός
# 205                                   4. ΤΕ Νοσηλευτής
# 206                            1. Ειδικευόμενος ιατρός
# 207                                   4. ΤΕ Νοσηλευτής
# 208                                  2. Ειδικός ιατρός
# 209                                  2. Ειδικός ιατρός
# 210                                   4. ΤΕ Νοσηλευτής
# 211                                                NaN
# 212                                  2. Ειδικός ιατρός
# 213                                  2. Ειδικός ιατρός
# 214                                   4. ΤΕ Νοσηλευτής
# 215                                                NaN
# 216                             5. ΔΕ Βοηθός Νοσηλευτή
# 217                                   4. ΤΕ Νοσηλευτής
# 218                                   4. ΤΕ Νοσηλευτής
# 219                                  2. Ειδικός ιατρός
# 220                                   3. ΠΕ Νοσηλευτής
# 221                                   4. ΤΕ Νοσηλευτής
# 222                                   4. ΤΕ Νοσηλευτής
# 223                                   4. ΤΕ Νοσηλευτής
# 224                                  2. Ειδικός ιατρός
# 225                            1. Ειδικευόμενος ιατρός
# 226                                  2. Ειδικός ιατρός
# 227                                  2. Ειδικός ιατρός
# 228                                  2. Ειδικός ιατρός
# 229                                  2. Ειδικός ιατρός
# 230                                  2. Ειδικός ιατρός
# 231                                   4. ΤΕ Νοσηλευτής
# 232                                   4. ΤΕ Νοσηλευτής
# 233                                   4. ΤΕ Νοσηλευτής
# 234                                   3. ΠΕ Νοσηλευτής
# 235                                   3. ΠΕ Νοσηλευτής
# 236                                   3. ΠΕ Νοσηλευτής
# 237                                   4. ΤΕ Νοσηλευτής
# 238                                   4. ΤΕ Νοσηλευτής
# 239                                   4. ΤΕ Νοσηλευτής
# 240                                                NaN
# 241                                  2. Ειδικός ιατρός
# 242                                   3. ΠΕ Νοσηλευτής
# 243                                  2. Ειδικός ιατρός

# %% [markdown]
# ### Analysis of Gender

# %%
gender = hospitals_personalInfo['1. Φύλο: ']

absolute_frequencies = gender.value_counts()
relative_frequencies = gender.value_counts(normalize=True)

# %%
absolute_frequencies
# Out:
# Γυναίκα    169
# Άνδρας      71
# Name: 1. Φύλο: , dtype: int64

# %%
relative_frequencies
# Out:
# Γυναίκα    0.704167
# Άνδρας     0.295833
# Name: 1. Φύλο: , dtype: float64

# %%
data = relative_frequencies*100
labels = relative_frequencies.index

my_graph(labels,data,"Ποσοστιαία Κατανομή Φύλου",4.5,1.5)

# %% [markdown]
# ### Analysis of Age

# %%
age = hospitals_personalInfo['2. Ηλικία…']

df = age.describe()
print(df)

# %% [markdown]
# ### Analysis of Education

# %%
education = hospitals_personalInfo['3α. Ποια είναι η βασική σας εκπαίδευση;']

absolute_frequencies = education.value_counts()
relative_frequencies = education.value_counts(normalize=True)

# %%
#define data
data = relative_frequencies
labels = relative_frequencies.index

plt.pie(data, labels = labels, colors = colors, autopct='%0.f%%')
plt.show()

# %%
# %store hospitals
# Out:
# Stored 'hospitals' (DataFrame)
