# %%
# Libraries
import pandas as pd
import pingouin as pg
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols

from scipy.stats.stats import pearsonr
from scipy import stats
from scipy.stats import f_oneway



pd.set_option('display.max_rows', None)

# %%
# %store -r parameter_9
# %store -r hospitals_personalInfo

# %%
#parameter_4
my_parameter = parameter_9

# %%
# Relative frequences for answers of every question

relative_frequencies = my_parameter.apply(lambda x: x.value_counts(normalize=True))
relative_frequencies
# Out:
#      2. Υπάρχει ελλιπής συντονισμός μεταξύ των Μονάδων.  \
# 1.0                                           0.078838
# 2.0                                           0.261411
# 3.0                                           0.331950
# 4.0                                           0.265560
# 5.0                                           0.062241
#
#      4. Υπάρχει καλή συνεργασία ανάμεσα στις Μονάδες όταν αυτό απαιτείται.  \
# 1.0                                           0.016598
# 2.0                                           0.112033
# 3.0                                           0.273859
# 4.0                                           0.452282
# 5.0                                           0.145228
#
#      6. Η συνεργασία με το προσωπικό άλλων Μονάδων είναι συχνά δυσάρεστη.  \
# 1.0                                           0.025000
# 2.0                                           0.154167
# 3.0                                           0.304167
# 4.0                                           0.379167
# 5.0                                           0.137500
#
#      10. Οι Μονάδες συνεργάζονται καλά μεταξύ τους για την παροχή άριστης ποιοτικά φροντίδας υγείας στον ασθενή.
# 1.0                                           0.016667
# 2.0                                           0.112500
# 3.0                                           0.350000
# 4.0                                           0.379167
# 5.0                                           0.141667

# %%
relative_frequencies_sum = relative_frequencies.sum(axis=1)/3
height = relative_frequencies_sum

bars = ('1', '2', '3', '4', '5')


# Figure Size
fig, ax= plt.subplots(figsize =(4, 4))


# Horizontal Bar Plot
ax.bar(bars, height,color=(0.0, 0.4, 0.6, 0.6))
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.9,
        alpha = 0.2)

    # Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 2)

vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

plt.savefig('distribution.png')

plt.show()
# Out:
# /var/folders/q9/jvtr2p8s6sn6wt933mh1tyfm0000gn/T/ipykernel_52755/2184165003.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

# %%
height
# Out:
# 1.0    0.045701
# 2.0    0.213370
# 3.0    0.419992
# 4.0    0.492059
# 5.0    0.162212
# dtype: float64

# %%
my_parameter.describe()
# Out:
#        2. Υπάρχει ελλιπής συντονισμός μεταξύ των Μονάδων.  \
# count                                         241.000000
# mean                                            2.970954
# std                                             1.046416
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        4. Υπάρχει καλή συνεργασία ανάμεσα στις Μονάδες όταν αυτό απαιτείται.  \
# count                                         241.000000
# mean                                            3.597510
# std                                             0.926369
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        6. Η συνεργασία με το προσωπικό άλλων Μονάδων είναι συχνά δυσάρεστη.  \
# count                                          240.00000
# mean                                             3.45000
# std                                              0.99244
# min                                              1.00000
# 25%                                              3.00000
# 50%                                              4.00000
# 75%                                              4.00000
# max                                              5.00000
#
#        10. Οι Μονάδες συνεργάζονται καλά μεταξύ τους για την παροχή άριστης ποιοτικά φροντίδας υγείας στον ασθενή.
# count                                         240.000000
# mean                                            3.516667
# std                                             0.928249
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000

# %% [markdown]
# # Correlation Analysis

# %%
# individual score to parameter 

parameter = my_parameter

individualScore = parameter.sum(axis=1)/4

# %%
individualScore.describe()
# Out:
# count    244.000000
# mean       3.335041
# std        0.852068
# min        0.000000
# 25%        2.750000
# 50%        3.250000
# 75%        4.000000
# max        5.000000
# dtype: float64

# %% [markdown]
# ### Gender correlation

# %%
gender = hospitals_personalInfo['1. Φύλο: ']

# %%
# create a frame with gender and score
gender = pd.concat([gender,individualScore],axis=1)

gender = gender.dropna()

gender.columns = ['Gender','Score']

male = []
female = []


#create table for every category
for index, row in gender.iterrows(): 
    if row['Gender'] == 'Γυναίκα':
        female.append(row['Score'])
    else:
        male.append(row['Score'])

# %%
from statistics import mean, pvariance
avg1 = mean(male)
var1 = pvariance(male)
avg2 = mean(female)
var2 = pvariance(female)

print("avg male =", avg1,"var male =",var1,"avg female =", avg2,"var female =",var2 )
# Out:
# avg male = 3.140845070422535 var male = 0.4572753421940091 avg female = 3.4541420118343193 var female = 0.6868763348622247

# %%
tStat, pValue = stats.ttest_ind(female, male, equal_var = False) #run independent sample T-Test
print("P-Value:{0} T-Statistic:{1}".format(pValue,tStat)) #print the
# Out:
# P-Value:0.0027670911973652784 T-Statistic:3.0399912695589064

# %%
#create table for every category

# for index, row in gender.iterrows(): 
#     if row['Gender'] == 'Γυναίκα':
#         gender["Gender"].loc[index] = 0
#     elif row['Gender'] == 'Άνδρας':
#         gender["Gender"].loc[index] = 1

# %% [markdown]
# ### Age Correlation

# %%
age = hospitals_personalInfo['2. Ηλικία…']

# %%
# create a frame with age and score
age = pd.concat([age,individualScore],axis=1)
age.columns = ['Age','Score']
age = age.dropna()

# %%
# remove outliers
q = age['Age'].quantile(0.99)
age = age[age['Age'] < q]

# %%
x = age['Age']
y = age['Score']
#calculation correlation coefficient and p-value between x and y
print("(corr,p-val) =",pearsonr(x, y))
# Out:
# (corr,p-val) = (0.1276185310614892, 0.05326133186961466)

# %%
plt.plot(x, y, '.')
plt.title("age-scre correlation")
plt.xlabel("age",fontweight="bold", fontsize="15")
plt.ylabel("score",fontweight="bold", fontsize="15")

plt.show()

# %% [markdown]
# ### Proffesion correlation

# %%
profession = hospitals_personalInfo['10. Τι θέση κατέχετε στο νοσοκομείο που εργάζεστε;']

profession= pd.concat([profession,individualScore],axis=1)

profession.columns = ['Profession','Score']

profession = profession.dropna()

# %%
print("Mean")
profession.groupby('Profession')['Score'].mean()
# Out:
# Mean
# Profession
# 1. Ειδικευόμενος ιατρός    2.990741
# 2. Ειδικός ιατρός          3.065789
# 3. ΠΕ Νοσηλευτής           3.411765
# 4. ΤΕ Νοσηλευτής           3.488806
# 5. ΔΕ Βοηθός Νοσηλευτή     3.647059
# Name: Score, dtype: float64

# %%
print("Variance")
profession.groupby('Profession')['Score'].var()
# Out:
# Variance
# Profession
# 1. Ειδικευόμενος ιατρός    0.632123
# 2. Ειδικός ιατρός          0.505690
# 3. ΠΕ Νοσηλευτής           0.483915
# 4. ΤΕ Νοσηλευτής           0.587280
# 5. ΔΕ Βοηθός Νοσηλευτή     1.211397
# Name: Score, dtype: float64

# %%
eidikevomenos_iatros = []
eidikos_iatros = []
pe_nosileftis = []
te_nosileftis = []
de_voithos_nosilefti = []

#create table for every category of profession
for index, row in profession.iterrows(): 
    if row['Profession'] == '1. Ειδικευόμενος ιατρός':
        eidikevomenos_iatros.append(row['Score'])
    elif row['Profession'] == '2. Ειδικός ιατρός':
        eidikos_iatros.append(row['Score'])
    elif row['Profession'] == '3. ΠΕ Νοσηλευτής':
        pe_nosileftis.append(row['Score'])
    elif row['Profession'] == '4. ΤΕ Νοσηλευτής':
        te_nosileftis.append(row['Score'])
    else:
        de_voithos_nosilefti.append(row['Score'])

# %%
f_oneway(eidikevomenos_iatros, eidikos_iatros, pe_nosileftis,te_nosileftis,de_voithos_nosilefti)
# Out:
# F_onewayResult(statistic=4.314366909373632, pvalue=0.002202518786436168)

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot([eidikevomenos_iatros,eidikos_iatros,pe_nosileftis,te_nosileftis,de_voithos_nosilefti])

plt.show()

# %% [markdown]
# ### Education Correlation

# %%
education = hospitals_personalInfo['3α. Ποια είναι η βασική σας εκπαίδευση;']

education= pd.concat([education,individualScore],axis=1)

education.columns = ['Education','Score']

education = education.dropna()

# %%
print("Mean")
education.groupby('Education')['Score'].mean()
# Out:
# Mean
# Education
# 1. Δευτεροβάθμια (Δ.Ε.)     3.750000
# 2. Τεχνολογική (Τ.Ε.)       3.485612
# 3. Πανεπιστημιακή (Π.Ε.)    3.102410
# Name: Score, dtype: float64

# %%
print("Variance")
education.groupby('Education')['Score'].var()
# Out:
# Variance
# Education
# 1. Δευτεροβάθμια (Δ.Ε.)     1.178571
# 2. Τεχνολογική (Τ.Ε.)       0.585842
# 3. Πανεπιστημιακή (Π.Ε.)    0.533592
# Name: Score, dtype: float64

# %%
defterovathmia = []
texnologiki = []
panepistimiaki = []


#create table for every category of profession
for index, row in education.iterrows(): 
    if row['Education'] == '1. Δευτεροβάθμια (Δ.Ε.)':
        defterovathmia.append(row['Score'])
    elif row['Education'] == '2. Τεχνολογική (Τ.Ε.)':
        texnologiki.append(row['Score'])
    elif row['Education'] == '3. Πανεπιστημιακή (Π.Ε.)':
        panepistimiaki.append(row['Score'])

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot([defterovathmia,texnologiki,panepistimiaki])

plt.show()

# %%
f_oneway(defterovathmia,texnologiki,panepistimiaki)
# Out:
# F_onewayResult(statistic=8.263956009683119, pvalue=0.0003404782776467161)

# %% [markdown]
# ### Adverse Event

# %%
aevent = hospitals_personalInfo['Τους τελευταίους 12 μήνες πόσα δυσμενή συμβάντα έχετε αναφέρει; (Αναφέρετε έναν αριθμό)']

# %%
# create a frame with age and score
aevent = pd.concat([aevent,individualScore],axis=1)
aevent.columns = ['aevent','Score']
aevent = aevent.dropna()

# %%
# remove outliers
q = aevent['aevent'].quantile(0.99)
aevent = aevent[aevent['aevent'] < q]

# %%
x = aevent['aevent']
y = aevent['Score']
#calculation correlation coefficient and p-value between x and y
print("(corr,p-val) =",pearsonr(x, y))
# Out:
# (corr,p-val) = (-0.19842854480047012, 0.004641687501548645)

# %%
plt.plot(x, y, '.')
plt.title("age-scre correlation")
plt.xlabel("aevent",fontweight="bold", fontsize="15")
plt.ylabel("score",fontweight="bold", fontsize="15")

plt.show()

# %% [markdown]
# ### Years of work in the team

# %%
wyears = hospitals_personalInfo['8. Πόσο χρονικό διάστημα εργάζεστε στη συγκεκριμένη μονάδα ?']

# %%
# create a frame with years and score
wyears = pd.concat([wyears,individualScore],axis=1)
wyears.columns = ['wyears','Score']
wyears = wyears.dropna()

# %%
# remove outlie
q = wyears['wyears'].quantile(0.99)
wyears = wyears[wyears['wyears'] < q]

# %%
x = wyears['wyears']
y = wyears['Score']
#calculation correlation coefficient and p-value between x and y
print("(corr,p-val) =",pearsonr(x, y))
# Out:
# (corr,p-val) = (0.08641626942431478, 0.19755942574262012)

# %%
plt.plot(x, y, '.')
plt.title("age-scre correlation")
plt.xlabel("age",fontweight="bold", fontsize="15")
plt.ylabel("score",fontweight="bold", fontsize="15")

plt.show()

# %% [markdown]
# ### Years of work in the hospital

# %%
wyears = hospitals_personalInfo['7. Πόσο χρονικό διάστημα εργάζεστε στο συγκεκριμένο Νοσοκομείο;']

# %%
# create a frame with years and score
wyears = pd.concat([wyears,individualScore],axis=1)
wyears.columns = ['wyears','Score']
wyears = wyears.dropna()

# %%
# remove outliers
q = wyears['wyears'].quantile(0.99)
wyears = wyears[wyears['wyears'] < q]

# %%
x = wyears['wyears']
y = wyears['Score']
#calculation correlation coefficient and p-value between x and y
print("(corr,p-val) =",pearsonr(x, y))
# Out:
# (corr,p-val) = (0.25547765950867074, 8.291522128451984e-05)

# %%
plt.plot(x, y, '.')
plt.title("age-scre correlation")
plt.xlabel("age",fontweight="bold", fontsize="15")
plt.ylabel("score",fontweight="bold", fontsize="15")

plt.show()

# %% [markdown]
# ### Hours of Work in the hopital

# %%
whours = hospitals_personalInfo['9. Συνήθως πόσες ώρες την εβδομάδα εργάζεστε στο συγκεκριμένο Νοσοκομείο; …']

# %%
# create a frame with hours and score
whours = pd.concat([whours,individualScore],axis=1)
whours.columns = ['whours','Score']
whours = whours.dropna()

# %%
# remove outliers
q = whours['whours'].quantile(0.99)
whours = whours[whours['whours'] < q]

# %%
x = wyears['wyears']
y = wyears['Score']
#calculation correlation coefficient and p-value between x and y
print("(corr,p-val) =",pearsonr(x, y))
# Out:
# (corr,p-val) = (0.25547765950867074, 8.291522128451984e-05)

# %%
plt.plot(x, y, '.')
plt.title("age-scre correlation")
plt.xlabel("age",fontweight="bold", fontsize="15")
plt.ylabel("score",fontweight="bold", fontsize="15")

plt.show()

# %% [markdown]
# ## Multivariant linear Regression for score and variables with evidece of correlation

# %%
hospitals_personalInfo
# Out:
#      Τους τελευταίους 12 μήνες πόσα δυσμενή συμβάντα έχετε αναφέρει; (Αναφέρετε έναν αριθμό)  \
# 0                                                  4.0
# 1                                                  NaN
# 2                                                 10.0
# 3                                                  NaN
# 4                                                  2.0
# 5                                                  NaN
# 6                                                  6.0
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 2.0
# 13                                                 2.0
# 14                                                 2.0
# 15                                                 3.0
# 16                                                 NaN
# 17                                                 3.0
# 18                                                10.0
# 19                                                 0.0
# 20                                                 0.0
# 21                                                 1.0
# 22                                                 0.0
# 23                                                 2.0
# 24                                                 0.0
# 25                                                 1.0
# 26                                                 0.0
# 27                                                 3.0
# 28                                                 0.0
# 29                                                 1.0
# 30                                                 NaN
# 31                                                 0.0
# 32                                                 NaN
# 33                                                 0.0
# 34                                                50.0
# 35                                                 6.0
# 36                                                 3.0
# 37                                                 3.0
# 38                                                 2.0
# 39                                                 2.0
# 40                                                 0.0
# 41                                                 1.0
# 42                                                 0.0
# 43                                                 0.0
# 44                                                 0.0
# 45                                                 NaN
# 46                                                 5.0
# 47                                                 0.0
# 48                                                 1.0
# 49                                                 0.0
# 50                                                 1.0
# 51                                                 0.0
# 52                                                 2.0
# 53                                                 NaN
# 54                                                 0.0
# 55                                                 0.0
# 56                                                 3.0
# 57                                                 0.0
# 58                                                 2.0
# 59                                                 0.0
# 60                                                 0.0
# 61                                                 0.0
# 62                                                 0.0
# 63                                                 2.0
# 64                                                 NaN
# 65                                                 NaN
# 66                                                10.0
# 67                                                 1.0
# 68                                                 1.0
# 69                                                10.0
# 70                                                 2.0
# 71                                                 0.0
# 72                                                 3.0
# 73                                                 1.0
# 74                                                 0.0
# 75                                                 2.0
# 76                                                 1.0
# 77                                                 0.0
# 78                                                 1.0
# 79                                                 1.0
# 80                                                 1.0
# 81                                                 1.0
# 82                                                 NaN
# 83                                                 0.0
# 84                                                 0.0
# 85                                                 0.0
# 86                                                 0.0
# 87                                                 0.0
# 88                                                 1.0
# 89                                                 2.0
# 90                                                 1.0
# 91                                                 0.0
# 92                                                 0.0
# 93                                                 1.0
# 94                                                 1.0
# 95                                                 2.0
# 96                                                 6.0
# 97                                                 NaN
# 98                                                 1.0
# 99                                                 3.0
# 100                                                2.0
# 101                                                2.0
# 102                                                NaN
# 103                                                2.0
# 104                                                0.0
# 105                                                NaN
# 106                                                NaN
# 107                                                2.0
# 108                                                0.0
# 109                                                3.0
# 110                                                3.0
# 111                                                5.0
# 112                                                3.0
# 113                                                3.0
# 114                                                2.0
# 115                                                3.0
# 116                                                NaN
# 117                                               10.0
# 118                                                3.0
# 119                                                NaN
# 120                                                6.0
# 121                                                NaN
# 122                                                NaN
# 123                                                0.0
# 124                                                4.0
# 125                                                0.0
# 126                                                1.0
# 127                                                0.0
# 128                                                0.0
# 129                                                1.0
# 130                                                4.0
# 131                                                0.0
# 9     Γυναίκα        55.0                   2. Τεχνολογική (Τ.Ε.)
# 10    Γυναίκα        56.0                   2. Τεχνολογική (Τ.Ε.)
# 11    Γυναίκα        38.0                   2. Τεχνολογική (Τ.Ε.)
# 12     Άνδρας        51.0                   2. Τεχνολογική (Τ.Ε.)
# 13    Γυναίκα        54.0                   2. Τεχνολογική (Τ.Ε.)
# 14    Γυναίκα        57.0                   2. Τεχνολογική (Τ.Ε.)
# 15    Γυναίκα        52.0                3. Πανεπιστημιακή (Π.Ε.)
# 16    Γυναίκα        44.0                   2. Τεχνολογική (Τ.Ε.)
# 17     Άνδρας        50.0                   2. Τεχνολογική (Τ.Ε.)
# 18     Άνδρας        53.0                   2. Τεχνολογική (Τ.Ε.)
# 19    Γυναίκα        47.0                   2. Τεχνολογική (Τ.Ε.)
# 20    Γυναίκα         NaN                   2. Τεχνολογική (Τ.Ε.)
# 21     Άνδρας        52.0                   2. Τεχνολογική (Τ.Ε.)
# 22     Άνδρας        48.0                   2. Τεχνολογική (Τ.Ε.)
# 23     Άνδρας        55.0                   2. Τεχνολογική (Τ.Ε.)
# 24    Γυναίκα        50.0                   2. Τεχνολογική (Τ.Ε.)
# 25    Γυναίκα        57.0                   2. Τεχνολογική (Τ.Ε.)
# 26    Γυναίκα        48.0                   2. Τεχνολογική (Τ.Ε.)
# 27    Γυναίκα        60.0                   2. Τεχνολογική (Τ.Ε.)
# 28    Γυναίκα        50.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 29    Γυναίκα        50.0                   2. Τεχνολογική (Τ.Ε.)
# 30    Γυναίκα        38.0                3. Πανεπιστημιακή (Π.Ε.)
# 31     Άνδρας        55.0                   2. Τεχνολογική (Τ.Ε.)
# 32    Γυναίκα        39.0                3. Πανεπιστημιακή (Π.Ε.)
# 33    Γυναίκα        45.0                   2. Τεχνολογική (Τ.Ε.)
# 34    Γυναίκα        41.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 35    Γυναίκα        37.0                3. Πανεπιστημιακή (Π.Ε.)
# 36    Γυναίκα        58.0                   2. Τεχνολογική (Τ.Ε.)
# 37    Γυναίκα        54.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 38     Άνδρας        49.0                3. Πανεπιστημιακή (Π.Ε.)
# 39    Γυναίκα        52.0                   2. Τεχνολογική (Τ.Ε.)
# 40    Γυναίκα        62.0                3. Πανεπιστημιακή (Π.Ε.)
# 41    Γυναίκα        54.0                   2. Τεχνολογική (Τ.Ε.)
# 42    Γυναίκα        54.0                   2. Τεχνολογική (Τ.Ε.)
# 43    Γυναίκα        50.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 44    Γυναίκα        39.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 45    Γυναίκα        58.0                   2. Τεχνολογική (Τ.Ε.)
# 46     Άνδρας        54.0                   2. Τεχνολογική (Τ.Ε.)
# 47    Γυναίκα        40.0                   2. Τεχνολογική (Τ.Ε.)
# 48     Άνδρας        55.0                   2. Τεχνολογική (Τ.Ε.)
# 49    Γυναίκα        54.0                   2. Τεχνολογική (Τ.Ε.)
# 50    Γυναίκα        40.0                   2. Τεχνολογική (Τ.Ε.)
# 51    Γυναίκα        53.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 52    Γυναίκα        57.0                   2. Τεχνολογική (Τ.Ε.)
# 53    Γυναίκα        53.0                   2. Τεχνολογική (Τ.Ε.)
# 54    Γυναίκα        36.0                   2. Τεχνολογική (Τ.Ε.)
# 55     Άνδρας         NaN                   2. Τεχνολογική (Τ.Ε.)
# 56    Γυναίκα         NaN                                     NaN
# 57    Γυναίκα        58.0                   2. Τεχνολογική (Τ.Ε.)
# 58    Γυναίκα        38.0                3. Πανεπιστημιακή (Π.Ε.)
# 59    Γυναίκα        55.0                   2. Τεχνολογική (Τ.Ε.)
# 60    Γυναίκα        48.0                   2. Τεχνολογική (Τ.Ε.)
# 61    Γυναίκα        47.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 62    Γυναίκα        59.0                   2. Τεχνολογική (Τ.Ε.)
# 63    Γυναίκα        50.0                   2. Τεχνολογική (Τ.Ε.)
# 64    Γυναίκα        60.0                   2. Τεχνολογική (Τ.Ε.)
# 65        NaN         NaN                                     NaN
# 66    Γυναίκα        54.0                   2. Τεχνολογική (Τ.Ε.)
# 67    Γυναίκα        42.0                   2. Τεχνολογική (Τ.Ε.)
# 68    Γυναίκα        41.0                   2. Τεχνολογική (Τ.Ε.)
# 69    Γυναίκα        26.0                   2. Τεχνολογική (Τ.Ε.)
# 70     Άνδρας        40.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 71    Γυναίκα        57.0                   2. Τεχνολογική (Τ.Ε.)
# 72    Γυναίκα        55.0                   2. Τεχνολογική (Τ.Ε.)
# 73    Γυναίκα        50.0                   2. Τεχνολογική (Τ.Ε.)
# 74    Γυναίκα        31.0                   2. Τεχνολογική (Τ.Ε.)
# 75    Γυναίκα        56.0                   2. Τεχνολογική (Τ.Ε.)
# 76     Άνδρας        36.0                   2. Τεχνολογική (Τ.Ε.)
# 77    Γυναίκα        46.0                   2. Τεχνολογική (Τ.Ε.)
# 78     Άνδρας        39.0                   2. Τεχνολογική (Τ.Ε.)
# 79    Γυναίκα        35.0                   2. Τεχνολογική (Τ.Ε.)
# 80    Γυναίκα        31.0                   2. Τεχνολογική (Τ.Ε.)
# 81    Γυναίκα        48.0                   2. Τεχνολογική (Τ.Ε.)
# 82        NaN         NaN                                     NaN
# 83    Γυναίκα        25.0                   2. Τεχνολογική (Τ.Ε.)
# 84    Γυναίκα        28.0                   2. Τεχνολογική (Τ.Ε.)
# 85    Γυναίκα        45.0                   2. Τεχνολογική (Τ.Ε.)
# 86    Γυναίκα        50.0                   2. Τεχνολογική (Τ.Ε.)
# 87    Γυναίκα        52.0                   2. Τεχνολογική (Τ.Ε.)
# 88    Γυναίκα        59.0                   2. Τεχνολογική (Τ.Ε.)
# 89    Γυναίκα        50.0                   2. Τεχνολογική (Τ.Ε.)
# 90    Γυναίκα        59.0                   2. Τεχνολογική (Τ.Ε.)
# 91    Γυναίκα        38.0                   2. Τεχνολογική (Τ.Ε.)
# 92        NaN        45.0                                     NaN
# 93    Γυναίκα        55.0                   2. Τεχνολογική (Τ.Ε.)
# 94    Γυναίκα        32.0                3. Πανεπιστημιακή (Π.Ε.)
# 95    Γυναίκα        33.0                3. Πανεπιστημιακή (Π.Ε.)
# 96    Γυναίκα        46.0                3. Πανεπιστημιακή (Π.Ε.)
# 97    Γυναίκα        42.0                3. Πανεπιστημιακή (Π.Ε.)
# 98    Γυναίκα        45.0                3. Πανεπιστημιακή (Π.Ε.)
# 99    Γυναίκα        35.0                3. Πανεπιστημιακή (Π.Ε.)
# 100   Γυναίκα        45.0                   2. Τεχνολογική (Τ.Ε.)
# 101   Γυναίκα        45.0                3. Πανεπιστημιακή (Π.Ε.)
# 102   Γυναίκα        54.0                   2. Τεχνολογική (Τ.Ε.)
# 103   Γυναίκα        38.0                   2. Τεχνολογική (Τ.Ε.)
# 104   Γυναίκα        47.0                   2. Τεχνολογική (Τ.Ε.)
# 105   Γυναίκα        48.0                   2. Τεχνολογική (Τ.Ε.)
# 106    Άνδρας        47.0                   2. Τεχνολογική (Τ.Ε.)
# 107   Γυναίκα        49.0                   2. Τεχνολογική (Τ.Ε.)
# 108   Γυναίκα        49.0                   2. Τεχνολογική (Τ.Ε.)
# 109    Άνδρας        54.0                   2. Τεχνολογική (Τ.Ε.)
# 110    Άνδρας        50.0                   2. Τεχνολογική (Τ.Ε.)
# 111    Άνδρας        48.0                3. Πανεπιστημιακή (Π.Ε.)
# 112   Γυναίκα        39.0                   2. Τεχνολογική (Τ.Ε.)
# 113   Γυναίκα        40.0                   2. Τεχνολογική (Τ.Ε.)
# 114   Γυναίκα        30.0                   2. Τεχνολογική (Τ.Ε.)
# 115   Γυναίκα        50.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 116   Γυναίκα        51.0                   2. Τεχνολογική (Τ.Ε.)
# 117   Γυναίκα        45.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 118   Γυναίκα        47.0                   2. Τεχνολογική (Τ.Ε.)
# 119   Γυναίκα         NaN                   2. Τεχνολογική (Τ.Ε.)
# 120       NaN         NaN                                     NaN
# 121   Γυναίκα        43.0                   2. Τεχνολογική (Τ.Ε.)
# 122   Γυναίκα        39.0                   2. Τεχνολογική (Τ.Ε.)
# 123   Γυναίκα        53.0                   2. Τεχνολογική (Τ.Ε.)
# 124   Γυναίκα        53.0                3. Πανεπιστημιακή (Π.Ε.)
# 125   Γυναίκα        55.0                   2. Τεχνολογική (Τ.Ε.)
# 126    Άνδρας        61.0                   2. Τεχνολογική (Τ.Ε.)
# 127   Γυναίκα        54.0                   2. Τεχνολογική (Τ.Ε.)
# 128    Άνδρας        55.0                   2. Τεχνολογική (Τ.Ε.)
# 129    Άνδρας        51.0                   2. Τεχνολογική (Τ.Ε.)
# 130    Άνδρας        48.0                   2. Τεχνολογική (Τ.Ε.)
# 131    Άνδρας        56.0                   2. Τεχνολογική (Τ.Ε.)
# 132    Άνδρας         NaN                   2. Τεχνολογική (Τ.Ε.)
# 133   Γυναίκα        56.0                                     NaN
# 134    Άνδρας        30.0                3. Πανεπιστημιακή (Π.Ε.)
# 135   Γυναίκα        65.0                3. Πανεπιστημιακή (Π.Ε.)
# 136    Άνδρας        29.0                3. Πανεπιστημιακή (Π.Ε.)
# 137    Άνδρας        32.0                3. Πανεπιστημιακή (Π.Ε.)
# 138    Άνδρας         NaN                                     NaN
# 139   Γυναίκα        28.0                3. Πανεπιστημιακή (Π.Ε.)
# 140   Γυναίκα        29.0                3. Πανεπιστημιακή (Π.Ε.)
# 141    Άνδρας        34.0                3. Πανεπιστημιακή (Π.Ε.)
# 142   Γυναίκα        35.0                3. Πανεπιστημιακή (Π.Ε.)
# 143    Άνδρας        45.0                3. Πανεπιστημιακή (Π.Ε.)
# 144   Γυναίκα        30.0                3. Πανεπιστημιακή (Π.Ε.)
# 145    Άνδρας        31.0                3. Πανεπιστημιακή (Π.Ε.)
# 146   Γυναίκα        38.0                3. Πανεπιστημιακή (Π.Ε.)
# 147   Γυναίκα        28.0                3. Πανεπιστημιακή (Π.Ε.)
# 148   Γυναίκα        30.0                3. Πανεπιστημιακή (Π.Ε.)
# 149    Άνδρας        30.0                3. Πανεπιστημιακή (Π.Ε.)
# 150   Γυναίκα        45.0                3. Πανεπιστημιακή (Π.Ε.)
# 151   Γυναίκα        48.0                   2. Τεχνολογική (Τ.Ε.)
# 152   Γυναίκα        40.0                3. Πανεπιστημιακή (Π.Ε.)
# 153    Άνδρας        42.0                3. Πανεπιστημιακή (Π.Ε.)
# 154   Γυναίκα        37.0                3. Πανεπιστημιακή (Π.Ε.)
# 155   Γυναίκα        30.0                3. Πανεπιστημιακή (Π.Ε.)
# 156    Άνδρας        55.0                3. Πανεπιστημιακή (Π.Ε.)
# 157    Άνδρας        64.0                3. Πανεπιστημιακή (Π.Ε.)
# 158    Άνδρας        44.0                3. Πανεπιστημιακή (Π.Ε.)
# 159   Γυναίκα        58.0                3. Πανεπιστημιακή (Π.Ε.)
# 160    Άνδρας        33.0                3. Πανεπιστημιακή (Π.Ε.)
# 161   Γυναίκα        43.0                3. Πανεπιστημιακή (Π.Ε.)
# 162    Άνδρας        44.0                3. Πανεπιστημιακή (Π.Ε.)
# 163   Γυναίκα        57.0                3. Πανεπιστημιακή (Π.Ε.)
# 164    Άνδρας        30.0                3. Πανεπιστημιακή (Π.Ε.)
# 165   Γυναίκα        60.0                3. Πανεπιστημιακή (Π.Ε.)
# 166    Άνδρας        51.0                3. Πανεπιστημιακή (Π.Ε.)
# 167   Γυναίκα        30.0                   2. Τεχνολογική (Τ.Ε.)
# 168   Γυναίκα        46.0                   2. Τεχνολογική (Τ.Ε.)
# 169   Γυναίκα        38.0                   2. Τεχνολογική (Τ.Ε.)
# 170   Γυναίκα        49.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 171   Γυναίκα        39.0                   2. Τεχνολογική (Τ.Ε.)
# 172   Γυναίκα        49.0                   2. Τεχνολογική (Τ.Ε.)
# 173   Γυναίκα        55.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 174   Γυναίκα        44.0                   2. Τεχνολογική (Τ.Ε.)
# 175   Γυναίκα        36.0                   2. Τεχνολογική (Τ.Ε.)
# 176   Γυναίκα        51.0                   2. Τεχνολογική (Τ.Ε.)
# 177   Γυναίκα        50.0                   2. Τεχνολογική (Τ.Ε.)
# 178    Άνδρας        52.0                   2. Τεχνολογική (Τ.Ε.)
# 179   Γυναίκα        50.0                   2. Τεχνολογική (Τ.Ε.)
# 180   Γυναίκα        47.0                   2. Τεχνολογική (Τ.Ε.)
# 181   Γυναίκα        28.0                3. Πανεπιστημιακή (Π.Ε.)
# 182   Γυναίκα        47.0                   2. Τεχνολογική (Τ.Ε.)
# 183   Γυναίκα        42.0                   2. Τεχνολογική (Τ.Ε.)
# 184   Γυναίκα        48.0                   2. Τεχνολογική (Τ.Ε.)
# 185   Γυναίκα        33.0                3. Πανεπιστημιακή (Π.Ε.)
# 186   Γυναίκα        56.0                   2. Τεχνολογική (Τ.Ε.)
# 187    Άνδρας        64.0                3. Πανεπιστημιακή (Π.Ε.)
# 188   Γυναίκα        51.0                   2. Τεχνολογική (Τ.Ε.)
# 189   Γυναίκα        60.0                3. Πανεπιστημιακή (Π.Ε.)
# 190   Γυναίκα        50.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 191   Γυναίκα        44.0                3. Πανεπιστημιακή (Π.Ε.)
# 192    Άνδρας        44.0                3. Πανεπιστημιακή (Π.Ε.)
# 193   Γυναίκα        41.0                   2. Τεχνολογική (Τ.Ε.)
# 194   Γυναίκα        37.0                   2. Τεχνολογική (Τ.Ε.)
# 195   Γυναίκα        44.0                3. Πανεπιστημιακή (Π.Ε.)
# 196   Γυναίκα        34.0                3. Πανεπιστημιακή (Π.Ε.)
# 197   Γυναίκα        40.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 198    Άνδρας        61.0                3. Πανεπιστημιακή (Π.Ε.)
# 199    Άνδρας        56.0                   2. Τεχνολογική (Τ.Ε.)
# 200    Άνδρας        57.0                3. Πανεπιστημιακή (Π.Ε.)
# 201    Άνδρας        57.0                   2. Τεχνολογική (Τ.Ε.)
# 202    Άνδρας        60.0                   2. Τεχνολογική (Τ.Ε.)
# 203    Άνδρας        54.0                   2. Τεχνολογική (Τ.Ε.)
# 204    Άνδρας        59.0                3. Πανεπιστημιακή (Π.Ε.)
# 205   Γυναίκα        57.0                   2. Τεχνολογική (Τ.Ε.)
# 206    Άνδρας        28.0                3. Πανεπιστημιακή (Π.Ε.)
# 207   Γυναίκα        60.0                   2. Τεχνολογική (Τ.Ε.)
# 208    Άνδρας        37.0                3. Πανεπιστημιακή (Π.Ε.)
# 209   Γυναίκα        49.0                3. Πανεπιστημιακή (Π.Ε.)
# 210   Γυναίκα        52.0                   2. Τεχνολογική (Τ.Ε.)
# 211    Άνδρας         NaN                3. Πανεπιστημιακή (Π.Ε.)
# 212    Άνδρας        48.0                3. Πανεπιστημιακή (Π.Ε.)
# 213   Γυναίκα        56.0                3. Πανεπιστημιακή (Π.Ε.)
# 214   Γυναίκα        52.0                   2. Τεχνολογική (Τ.Ε.)
# 215    Άνδρας        30.0                   2. Τεχνολογική (Τ.Ε.)
# 216   Γυναίκα        48.0                 1. Δευτεροβάθμια (Δ.Ε.)
# 217   Γυναίκα        55.0                   2. Τεχνολογική (Τ.Ε.)
# 218    Άνδρας        41.0                   2. Τεχνολογική (Τ.Ε.)
# 219   Γυναίκα        50.0                3. Πανεπιστημιακή (Π.Ε.)
# 220   Γυναίκα        36.0                3. Πανεπιστημιακή (Π.Ε.)
# 221   Γυναίκα        41.0                   2. Τεχνολογική (Τ.Ε.)
# 222   Γυναίκα        23.0                   2. Τεχνολογική (Τ.Ε.)
# 223   Γυναίκα        50.0                   2. Τεχνολογική (Τ.Ε.)
# 224    Άνδρας        59.0                3. Πανεπιστημιακή (Π.Ε.)
# 225   Γυναίκα        29.0                3. Πανεπιστημιακή (Π.Ε.)
# 226    Άνδρας        52.0                3. Πανεπιστημιακή (Π.Ε.)
# 227   Γυναίκα        37.0                3. Πανεπιστημιακή (Π.Ε.)
# 228   Γυναίκα        45.0                3. Πανεπιστημιακή (Π.Ε.)
# 229    Άνδρας        55.0                3. Πανεπιστημιακή (Π.Ε.)
# 230    Άνδρας        52.0                3. Πανεπιστημιακή (Π.Ε.)
# 231   Γυναίκα        56.0                   2. Τεχνολογική (Τ.Ε.)
# 232   Γυναίκα        40.0                   2. Τεχνολογική (Τ.Ε.)
# 233   Γυναίκα        43.0                   2. Τεχνολογική (Τ.Ε.)
# 234    Άνδρας        58.0                3. Πανεπιστημιακή (Π.Ε.)
# 235    Άνδρας        34.0                3. Πανεπιστημιακή (Π.Ε.)
# 236    Άνδρας        41.0                3. Πανεπιστημιακή (Π.Ε.)
# 237   Γυναίκα        53.0                   2. Τεχνολογική (Τ.Ε.)
# 238    Άνδρας        58.0                   2. Τεχνολογική (Τ.Ε.)
# 239   Γυναίκα        47.0                   2. Τεχνολογική (Τ.Ε.)
# 240    Άνδρας        56.0                   2. Τεχνολογική (Τ.Ε.)
# 241    Άνδρας        40.0                3. Πανεπιστημιακή (Π.Ε.)
# 242   Γυναίκα        45.0                3. Πανεπιστημιακή (Π.Ε.)
# 243    Άνδρας        65.0                3. Πανεπιστημιακή (Π.Ε.)
#
#            3β. Άλλες σπουδές:  \
# 0      3. Διδακτορικό δίπλωμα
# 1    2. Μεταπτυχιακές σπουδές
# 2      3. Διδακτορικό δίπλωμα
# 3      3. Διδακτορικό δίπλωμα
# 4    2. Μεταπτυχιακές σπουδές
# 5    2. Μεταπτυχιακές σπουδές
# 6      3. Διδακτορικό δίπλωμα
# 7    2. Μεταπτυχιακές σπουδές
# 8    2. Μεταπτυχιακές σπουδές
# 9    2. Μεταπτυχιακές σπουδές
# 10              1. Ειδικότητα
# 11   2. Μεταπτυχιακές σπουδές
# 12   2. Μεταπτυχιακές σπουδές
# 13   2. Μεταπτυχιακές σπουδές
# 14   2. Μεταπτυχιακές σπουδές
# 15              1. Ειδικότητα
# 16              1. Ειδικότητα
# 17   2. Μεταπτυχιακές σπουδές
# 18     3. Διδακτορικό δίπλωμα
# 19                        NaN
# 20              1. Ειδικότητα
# 21     3. Διδακτορικό δίπλωμα
# 22   2. Μεταπτυχιακές σπουδές
# 23   2. Μεταπτυχιακές σπουδές
# 24              1. Ειδικότητα
# 25              1. Ειδικότητα
# 26              1. Ειδικότητα
# 27   2. Μεταπτυχιακές σπουδές
# 28                        NaN
# 29   2. Μεταπτυχιακές σπουδές
# 30     3. Διδακτορικό δίπλωμα
# 31                        NaN
# 32     3. Διδακτορικό δίπλωμα
# 33   2. Μεταπτυχιακές σπουδές
# 34                        NaN
# 35     3. Διδακτορικό δίπλωμα
# 36              1. Ειδικότητα
# 37                        NaN
# 38     3. Διδακτορικό δίπλωμα
# 39   2. Μεταπτυχιακές σπουδές
# 40   2. Μεταπτυχιακές σπουδές
# 41   2. Μεταπτυχιακές σπουδές
# 42   2. Μεταπτυχιακές σπουδές
# 43                        NaN
# 44                        NaN
# 45   2. Μεταπτυχιακές σπουδές
# 46   2. Μεταπτυχιακές σπουδές
# 47   2. Μεταπτυχιακές σπουδές
# 48              1. Ειδικότητα
# 49   2. Μεταπτυχιακές σπουδές
# 50                        NaN
# 51                        NaN
# 52              1. Ειδικότητα
# 53   2. Μεταπτυχιακές σπουδές
# 54   2. Μεταπτυχιακές σπουδές
# 55   2. Μεταπτυχιακές σπουδές
# 56                        NaN
# 57   2. Μεταπτυχιακές σπουδές
# 58   2. Μεταπτυχιακές σπουδές
# 59   2. Μεταπτυχιακές σπουδές
# 60   2. Μεταπτυχιακές σπουδές
# 61                        NaN
# 62              1. Ειδικότητα
# 63              1. Ειδικότητα
# 64              1. Ειδικότητα
# 65                        NaN
# 66   2. Μεταπτυχιακές σπουδές
# 67   2. Μεταπτυχιακές σπουδές
# 68   2. Μεταπτυχιακές σπουδές
# 69                        NaN
# 70                        NaN
# 71              1. Ειδικότητα
# 72              1. Ειδικότητα
# 73              1. Ειδικότητα
# 74   2. Μεταπτυχιακές σπουδές
# 75              1. Ειδικότητα
# 76   2. Μεταπτυχιακές σπουδές
# 77              1. Ειδικότητα
# 78     3. Διδακτορικό δίπλωμα
# 79   2. Μεταπτυχιακές σπουδές
# 80   2. Μεταπτυχιακές σπουδές
# 81   2. Μεταπτυχιακές σπουδές
# 82                        NaN
# 83                        NaN
# 84   2. Μεταπτυχιακές σπουδές
# 85              1. Ειδικότητα
# 86                        NaN
# 87                        NaN
# 88              1. Ειδικότητα
# 89              1. Ειδικότητα
# 90              1. Ειδικότητα
# 91                        NaN
# 92                        NaN
# 93              1. Ειδικότητα
# 94   2. Μεταπτυχιακές σπουδές
# 95     3. Διδακτορικό δίπλωμα
# 96              1. Ειδικότητα
# 97   2. Μεταπτυχιακές σπουδές
# 98     3. Διδακτορικό δίπλωμα
# 99   2. Μεταπτυχιακές σπουδές
# 100  2. Μεταπτυχιακές σπουδές
# 101  2. Μεταπτυχιακές σπουδές
# 102                       NaN
# 103  2. Μεταπτυχιακές σπουδές
# 104  2. Μεταπτυχιακές σπουδές
# 105  2. Μεταπτυχιακές σπουδές
# 106                       NaN
# 107  2. Μεταπτυχιακές σπουδές
# 108             1. Ειδικότητα
# 109                       NaN
# 110             1. Ειδικότητα
# 111    3. Διδακτορικό δίπλωμα
# 112                       NaN
# 113  2. Μεταπτυχιακές σπουδές
# 114  2. Μεταπτυχιακές σπουδές
# 115                       NaN
# 116             1. Ειδικότητα
# 117                       NaN
# 118                       NaN
# 119                       NaN
# 120                       NaN
# 121  2. Μεταπτυχιακές σπουδές
# 122             1. Ειδικότητα
# 123                       NaN
# 124  2. Μεταπτυχιακές σπουδές
# 125             1. Ειδικότητα
# 126             1. Ειδικότητα
# 127  2. Μεταπτυχιακές σπουδές
# 128                       NaN
# 129  2. Μεταπτυχιακές σπουδές
# 130             1. Ειδικότητα
# 131                       NaN
# 132  2. Μεταπτυχιακές σπουδές
# 133                       NaN
# 134  2. Μεταπτυχιακές σπουδές
# 135             1. Ειδικότητα
# 136    3. Διδακτορικό δίπλωμα
# 137  2. Μεταπτυχιακές σπουδές
# 138  2. Μεταπτυχιακές σπουδές
# 139             1. Ειδικότητα
# 140  2. Μεταπτυχιακές σπουδές
# 141  2. Μεταπτυχιακές σπουδές
# 142  2. Μεταπτυχιακές σπουδές
# 143                       NaN
# 144             1. Ειδικότητα
# 145             1. Ειδικότητα
# 146             1. Ειδικότητα
# 147             1. Ειδικότητα
# 148             1. Ειδικότητα
# 149  2. Μεταπτυχιακές σπουδές
# 150  2. Μεταπτυχιακές σπουδές
# 151  2. Μεταπτυχιακές σπουδές
# 152             1. Ειδικότητα
# 153  2. Μεταπτυχιακές σπουδές
# 154  2. Μεταπτυχιακές σπουδές
# 155  2. Μεταπτυχιακές σπουδές
# 156    3. Διδακτορικό δίπλωμα
# 157    3. Διδακτορικό δίπλωμα
# 158    3. Διδακτορικό δίπλωμα
# 159    3. Διδακτορικό δίπλωμα
# 160             1. Ειδικότητα
# 161             1. Ειδικότητα
# 162             1. Ειδικότητα
# 163             1. Ειδικότητα
# 164             1. Ειδικότητα
# 165  2. Μεταπτυχιακές σπουδές
# 166    3. Διδακτορικό δίπλωμα
# 167  2. Μεταπτυχιακές σπουδές
# 168  2. Μεταπτυχιακές σπουδές
# 169                       NaN
# 170                       NaN
# 171  2. Μεταπτυχιακές σπουδές
# 172  2. Μεταπτυχιακές σπουδές
# 173                       NaN
# 174  2. Μεταπτυχιακές σπουδές
# 175                       NaN
# 176  2. Μεταπτυχιακές σπουδές
# 177  2. Μεταπτυχιακές σπουδές
# 178                       NaN
# 179             1. Ειδικότητα
# 180    3. Διδακτορικό δίπλωμα
# 181             1. Ειδικότητα
# 182                       NaN
# 183  2. Μεταπτυχιακές σπουδές
# 184                       NaN
# 185             1. Ειδικότητα
# 186  2. Μεταπτυχιακές σπουδές
# 187    3. Διδακτορικό δίπλωμα
# 188             1. Ειδικότητα
# 189    3. Διδακτορικό δίπλωμα
# 190                       NaN
# 191    3. Διδακτορικό δίπλωμα
# 192  2. Μεταπτυχιακές σπουδές
# 193             1. Ειδικότητα
# 194                       NaN
# 195  2. Μεταπτυχιακές σπουδές
# 196  2. Μεταπτυχιακές σπουδές
# 197             1. Ειδικότητα
# 198    3. Διδακτορικό δίπλωμα
# 199    3. Διδακτορικό δίπλωμα
# 200    3. Διδακτορικό δίπλωμα
# 201  2. Μεταπτυχιακές σπουδές
# 202             1. Ειδικότητα
# 203  2. Μεταπτυχιακές σπουδές
# 204    3. Διδακτορικό δίπλωμα
# 205  2. Μεταπτυχιακές σπουδές
# 206  2. Μεταπτυχιακές σπουδές
# 207             1. Ειδικότητα
# 208             1. Ειδικότητα
# 209  2. Μεταπτυχιακές σπουδές
# 210                       NaN
# 211                       NaN
# 212             1. Ειδικότητα
# 213             1. Ειδικότητα
# 214  2. Μεταπτυχιακές σπουδές
# 215  2. Μεταπτυχιακές σπουδές
# 216                       NaN
# 217                       NaN
# 218    3. Διδακτορικό δίπλωμα
# 219  2. Μεταπτυχιακές σπουδές
# 220  2. Μεταπτυχιακές σπουδές
# 221  2. Μεταπτυχιακές σπουδές
# 222  2. Μεταπτυχιακές σπουδές
# 223  2. Μεταπτυχιακές σπουδές
# 224    3. Διδακτορικό δίπλωμα
# 225  2. Μεταπτυχιακές σπουδές
# 226             1. Ειδικότητα
# 227  2. Μεταπτυχιακές σπουδές
# ...
# 220                                               40.0
# 221                                               40.0
# 222                                               34.0
# 223                                               50.0
# 224                                               50.0
# 225                                               45.0
# 226                                               56.0
# 227                                               75.0
# 228                                                NaN
# 229                                               35.0
# 230                                                4.0
# 231                                               50.0
# 232                                               45.0
# 233                                               40.0
# 234                                               40.0
# 235                                               50.0
# 236                                               40.0
# 237                                               40.0
# 238                                               45.0
# 239                                               40.0
# 240                                               40.0
# 241                                               58.0
# 242                                               42.0
# 243                                               50.0
#
#     10. Τι θέση κατέχετε στο νοσοκομείο που εργάζεστε;
# 0                                     4. ΤΕ Νοσηλευτής
# 1                                     4. ΤΕ Νοσηλευτής
# 2                                     4. ΤΕ Νοσηλευτής
# 3                                                  NaN
# 4                                     4. ΤΕ Νοσηλευτής
# 5                                    2. Ειδικός ιατρός
# 6                                     4. ΤΕ Νοσηλευτής
# 7                                     4. ΤΕ Νοσηλευτής
# 8                                     4. ΤΕ Νοσηλευτής
# 9                                     4. ΤΕ Νοσηλευτής
# 10                                    4. ΤΕ Νοσηλευτής
# 11                                    4. ΤΕ Νοσηλευτής
# 12                                    4. ΤΕ Νοσηλευτής
# 13                                    4. ΤΕ Νοσηλευτής
# 14                                    4. ΤΕ Νοσηλευτής
# 15                                    3. ΠΕ Νοσηλευτής
# 16                                    4. ΤΕ Νοσηλευτής
# 213                                  2. Ειδικός ιατρός
# 214                                   4. ΤΕ Νοσηλευτής
# 215                                                NaN
# 216                             5. ΔΕ Βοηθός Νοσηλευτή
# 217                                   4. ΤΕ Νοσηλευτής
# 218                                   4. ΤΕ Νοσηλευτής
# 219                                  2. Ειδικός ιατρός
# 220                                   3. ΠΕ Νοσηλευτής
# 221                                   4. ΤΕ Νοσηλευτής
# 222                                   4. ΤΕ Νοσηλευτής
# 223                                   4. ΤΕ Νοσηλευτής
# 224                                  2. Ειδικός ιατρός
# 225                            1. Ειδικευόμενος ιατρός
# 226                                  2. Ειδικός ιατρός
# 227                                  2. Ειδικός ιατρός
# 228                                  2. Ειδικός ιατρός
# 229                                  2. Ειδικός ιατρός
# 230                                  2. Ειδικός ιατρός
# 231                                   4. ΤΕ Νοσηλευτής
# 232                                   4. ΤΕ Νοσηλευτής
# 233                                   4. ΤΕ Νοσηλευτής
# 234                                   3. ΠΕ Νοσηλευτής
# 235                                   3. ΠΕ Νοσηλευτής
# 236                                   3. ΠΕ Νοσηλευτής
# 237                                   4. ΤΕ Νοσηλευτής
# 238                                   4. ΤΕ Νοσηλευτής
# 239                                   4. ΤΕ Νοσηλευτής
# 240                                                NaN
# 241                                  2. Ειδικός ιατρός
# 242                                   3. ΠΕ Νοσηλευτής
# 243                                  2. Ειδικός ιατρός

# %%
data = hospitals_personalInfo[['1. Φύλο: ','2. Ηλικία…','Τους τελευταίους 12 μήνες πόσα δυσμενή συμβάντα έχετε αναφέρει; (Αναφέρετε έναν αριθμό)','7. Πόσο χρονικό διάστημα εργάζεστε στο συγκεκριμένο Νοσοκομείο;','10. Τι θέση κατέχετε στο νοσοκομείο που εργάζεστε;','9. Συνήθως πόσες ώρες την εβδομάδα εργάζεστε στο συγκεκριμένο Νοσοκομείο; …']]
data = pd.concat((data, individualScore), axis=1)
data.columns = ['gender','age','aevent','yearsHospital','position','hours','score']

# %%
#clean data
data = data.dropna()
data
# Out:
#       gender   age  aevent  yearsHospital                 position  hours  \
# 0    Γυναίκα  23.0     4.0           23.0         4. ΤΕ Νοσηλευτής   23.0
# 2     Άνδρας  55.0    10.0           33.0         4. ΤΕ Νοσηλευτής   60.0
# 4     Άνδρας  50.0     2.0           25.0         4. ΤΕ Νοσηλευτής   41.0
# 6     Άνδρας  55.0     6.0           33.0         4. ΤΕ Νοσηλευτής   40.0
# 12    Άνδρας  51.0     2.0           25.0         4. ΤΕ Νοσηλευτής   40.0
# 13   Γυναίκα  54.0     2.0           30.0         4. ΤΕ Νοσηλευτής   40.0
# 14   Γυναίκα  57.0     2.0           35.0         4. ΤΕ Νοσηλευτής   40.0
# 15   Γυναίκα  52.0     3.0           20.0         3. ΠΕ Νοσηλευτής   40.0
# 17    Άνδρας  50.0     3.0           30.0         4. ΤΕ Νοσηλευτής   40.0
# 18    Άνδρας  53.0    10.0           30.0         4. ΤΕ Νοσηλευτής   60.0
# 19   Γυναίκα  47.0     0.0           22.0         4. ΤΕ Νοσηλευτής   40.0
# 137   3.25
# 140   4.00
# 141   4.00
# 142   1.00
# 144   4.00
# 145   2.75
# 146   3.00
# 147   4.25
# 148   2.50
# 149   2.50
# 150   2.75
# 151   3.75
# 152   3.00
# 154   4.50
# 155   3.75
# 156   3.50
# 157   2.75
# 159   2.50
# 160   2.50
# 162   2.00
# 163   2.75
# 164   2.00
# 165   2.75
# 166   2.75
# 167   3.50
# 168   4.00
# 169   2.00
# 170   2.00
# 172   2.50
# 174   3.50
# 175   2.25
# 176   5.00
# 177   4.25
# 178   4.25
# 179   4.50
# 180   3.75
# 181   2.75
# 182   4.00
# 184   3.00
# 185   1.75
# 187   3.25
# 188   3.25
# 189   4.00
# 190   4.75
# 191   2.75
# 192   4.25
# 193   3.00
# 194   4.00
# 195   2.75
# 196   3.50
# 197   4.50
# 198   3.00
# 199   4.50
# 200   4.00
# 201   2.50
# 202   3.25
# 203   3.50
# 204   2.00
# 205   4.25
# 206   2.50
# 207   4.75
# 208   1.75
# 209   4.50
# 210   3.00
# 212   3.00
# 213   2.75
# 214   2.75
# 216   3.00
# 217   2.00
# 218   1.50
# 219   2.50
# 220   3.50
# 221   4.00
# 222   3.00
# 223   2.75
# 224   1.75
# 225   3.00
# 226   4.25
# 227   4.00
# 229   3.25
# 231   4.00
# 232   3.00
# 233   2.75
# 234   3.75
# 236   3.50
# 237   4.25
# 238   3.50
# 239   5.00
# 241   3.25
# 242   3.25
# 243   3.00

# %%
#remove outliers
q1 = data['aevent'].quantile(0.99)
data = data.loc[data['aevent'] < q1]

q2 = data['yearsHospital'].quantile(0.99)
data = data.loc[data['yearsHospital'] < q2]

q3 = data['hours'].quantile(0.99)
data = data.loc[data['hours'] < q2]

print(q3)
# Out:
# 75.0

# %%
#make categorical values binary

dummies = pd.get_dummies(data['gender'])
data = pd.concat((data, dummies), axis=1)

dummies = pd.get_dummies(data['position'])
data = pd.concat((data, dummies), axis=1)

# %%
data
# Out:
#       gender   age  aevent  yearsHospital                 position  hours  \
# 0    Γυναίκα  23.0     4.0           23.0         4. ΤΕ Νοσηλευτής   23.0
# 26   Γυναίκα  48.0     0.0           15.0         4. ΤΕ Νοσηλευτής    7.0
# 50   Γυναίκα  40.0     1.0           12.0         4. ΤΕ Νοσηλευτής   25.0
# 96   Γυναίκα  46.0     6.0           10.0        2. Ειδικός ιατρός   35.0
# 103  Γυναίκα  38.0     2.0           10.0         4. ΤΕ Νοσηλευτής    8.0
# 129   Άνδρας  51.0     1.0           27.0         4. ΤΕ Νοσηλευτής   24.0
# 142  Γυναίκα  35.0     2.0            1.0  1. Ειδικευόμενος ιατρός   10.0
# 150  Γυναίκα  45.0     2.0            9.0        2. Ειδικός ιατρός   36.0
# 154  Γυναίκα  37.0     0.0            7.0        2. Ειδικός ιατρός   16.0
# 164   Άνδρας  30.0     2.0            4.0  1. Ειδικευόμενος ιατρός   35.0
# 166   Άνδρας  51.0     4.0            2.0        2. Ειδικός ιατρός   35.0
# 188  Γυναίκα  51.0     0.0           26.0         4. ΤΕ Νοσηλευτής    8.0
# 194  Γυναίκα  37.0     0.0           15.0         4. ΤΕ Νοσηλευτής   10.0
# 199   Άνδρας  56.0     0.0           34.0         4. ΤΕ Νοσηλευτής    8.0
# 202   Άνδρας  60.0    10.0           26.0         4. ΤΕ Νοσηλευτής    8.0
# 216  Γυναίκα  48.0     1.0            5.0   5. ΔΕ Βοηθός Νοσηλευτή    8.0
# 222  Γυναίκα  23.0     6.0           12.0         4. ΤΕ Νοσηλευτής   34.0
# 229   Άνδρας  55.0     0.0           22.0        2. Ειδικός ιατρός   35.0
#
#      score  Άνδρας  Γυναίκα  1. Ειδικευόμενος ιατρός  2. Ειδικός ιατρός  \
# 0     3.00       0        1                        0                  0
# 26    4.00       0        1                        0                  0
# 50    3.00       0        1                        0                  0
# 96    3.00       0        1                        0                  1
# 103   3.25       0        1                        0                  0
# 129   3.25       1        0                        0                  0
# 142   1.00       0        1                        1                  0
# 150   2.75       0        1                        0                  1
# 154   4.50       0        1                        0                  1
# 164   2.00       1        0                        1                  0
# 166   2.75       1        0                        0                  1
# 188   3.25       0        1                        0                  0
# 194   4.00       0        1                        0                  0
# 199   4.50       1        0                        0                  0
# 202   3.25       1        0                        0                  0
# 216   3.00       0        1                        0                  0
# 222   3.00       0        1                        0                  0
# 229   3.25       1        0                        0                  1
#
#      4. ΤΕ Νοσηλευτής  5. ΔΕ Βοηθός Νοσηλευτή
# 0                   1                       0
# 26                  1                       0
# 50                  1                       0
# 96                  0                       0
# 103                 1                       0
# 129                 1                       0
# 142                 0                       0
# 150                 0                       0
# 154                 0                       0
# 164                 0                       0
# 166                 0                       0
# 188                 1                       0
# 194                 1                       0
# 199                 1                       0
# 202                 1                       0
# 216                 0                       1
# 222                 1                       0
# 229                 0                       0

# %%
# build model
X = data[['age','Άνδρας','aevent','1. Ειδικευόμενος ιατρός','hours']]
y = data['score']

# %%
#ols model
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.638
# Method:                 Least Squares   F-statistic:                     7.004
# Date:                Fri, 23 Dec 2022   Prob (F-statistic):            0.00280
# Time:                        11:02:45   Log-Likelihood:                -9.2309
# No. Observations:                  18   AIC:                             30.46
# Df Residuals:                      12   BIC:                             35.80
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       4.8053      0.798      6.019      0.000       3.066       6.545
# age                        -0.0220      0.016     -1.337      0.206      -0.058       0.014
# Άνδρας                      0.6643      0.349      1.903      0.081      -0.096       1.425
# aevent                     -0.0867      0.045     -1.920      0.079      -0.185       0.012
# 1. Ειδικευόμενος ιατρός    -2.2104      0.439     -5.038      0.000      -3.166      -1.254
# hours                      -0.0240      0.011     -2.095      0.058      -0.049       0.001
# ==============================================================================
# Omnibus:                        1.874   Durbin-Watson:                   1.907
# Prob(Omnibus):                  0.392   Jarque-Bera (JB):                1.494
# Skew:                           0.563   Prob(JB):                        0.474
# Kurtosis:                       2.150   Cond. No.                         362.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/stathis/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
